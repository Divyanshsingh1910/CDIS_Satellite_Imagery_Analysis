# %%
#Merging CSV of OSM and Deep Features

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('/content/POI+transport+traffic+religion.csv')
df2 = pd.read_csv('/content/deep features_100_images.csv')

# %%
df1
# Out:
#      Latitude  Longitude    Income      atm_1      atm_2      atm_3  \
# 0   28.787210  76.146069   27900.0  45.437863  45.562218  46.097825
# 1   28.189651  76.620154   43400.0   0.489043  36.552475  37.824928
# 2   29.935508  76.731632   41000.0  11.282464  37.076108  37.076108
# 3   28.059180  76.105137  102500.0  14.821963  14.821963  14.821963
# 4   30.345936  76.867567   83600.0   3.758199   3.881466   7.031157
# ..        ...        ...       ...        ...        ...        ...
# 93  29.970384  76.873701   61500.0   3.063512  31.813936  31.813936
# 94  29.543673  75.057155   80200.0  78.292542  87.834950  87.834950
# 95  29.816656  76.382539   41100.0  43.606292  47.483648  62.447822
# 96  28.360379  77.273560   18400.0   2.009627   2.038513   9.862148
# 97  28.895515  76.606611   26800.0   0.431447   0.431447   0.452939
#
#        bank_1     bank_2     bank_3   school_1  ...   parking_3   hindu_1  \
# 0   35.790841  35.875997  43.824495  14.343684  ...   80.892250  3.376210
# ...

# %%
df2
# Out:
#     Image Name       Predicted Class  Feature_1  Feature_3  Feature_8  \
# 0    har_0.png           Residential        0.0        0.0        0.0
# 1    har_1.png           Residential        0.0        0.0        0.0
# 2   har_10.png           Residential        0.0        0.0        0.0
# 3   har_11.png           Residential        0.0        0.0        0.0
# 4   har_12.png           Residential        0.0        0.0        0.0
# ..         ...                   ...        ...        ...        ...
# 93  har_93.png           Residential        0.0        0.0        0.0
# 94  har_94.png           Residential        0.0        0.0        0.0
# 95  har_95.png  HerbaceousVegetation        0.0        0.0        0.0
# 96  har_96.png           Residential        0.0        0.0        0.0
# 97  har_97.png           Residential        0.0        0.0        0.0
#
#     Feature_18  Feature_23  Feature_27  Feature_28  Feature_35  ...  \
# ...

# %%
selected_columns = ['atm_1','atm_2','atm_3','bank_1','bank_2','bank_3','hospital_1','hospital_2','hospital_3','school_1','school_2','school_3','restaurant_1','restaurant_2','restaurant_3']
#selected_columns = ['atm_1','atm_2','atm_3']
df1 = df1 [selected_columns]

# %%
df2['Image Name'] = df2['Image Name'].str.rstrip('.png')

# %%
df2
# Out:
#    Image Name       Predicted Class  Feature_1  Feature_3  Feature_8  \
# 0       har_0           Residential        0.0        0.0        0.0
# 1       har_1           Residential        0.0        0.0        0.0
# 2      har_10           Residential        0.0        0.0        0.0
# 3      har_11           Residential        0.0        0.0        0.0
# 4      har_12           Residential        0.0        0.0        0.0
# ..        ...                   ...        ...        ...        ...
# 93     har_93           Residential        0.0        0.0        0.0
# 94     har_94           Residential        0.0        0.0        0.0
# 95     har_95  HerbaceousVegetation        0.0        0.0        0.0
# 96     har_96           Residential        0.0        0.0        0.0
# 97     har_97           Residential        0.0        0.0        0.0
#
#     Feature_18  Feature_23  Feature_27  Feature_28  Feature_35  ...  \
# 0     0.030216         0.0         0.0         0.0         0.0  ...
# ...

# %%
df3 = pd.read_csv('/content/testing_lat_long.csv')

# %%
df3
# Out:
#      Latitude  Longitude Image Name
# 0   28.787210  76.146069      har_0
# 1   28.189651  76.620154      har_1
# 2   29.935508  76.731632      har_2
# 3   28.059180  76.105137      har_3
# 4   30.345936  76.867567      har_4
# ..        ...        ...        ...
# 93  29.970384  76.873701     har_93
# 94  29.543673  75.057155     har_94
# 95  29.816656  76.382539     har_95
# 96  28.360379  77.273560     har_96
# 97  28.895515  76.606611     har_97
#
# [98 rows x 3 columns]

# %%
df4 = df2.merge(df3, on='Image Name', how='left')

# %%
df4
# Out:
#    Image Name       Predicted Class  Feature_1  Feature_3  Feature_8  \
# 0       har_0           Residential        0.0        0.0        0.0
# 1       har_1           Residential        0.0        0.0        0.0
# 2      har_10           Residential        0.0        0.0        0.0
# 3      har_11           Residential        0.0        0.0        0.0
# 4      har_12           Residential        0.0        0.0        0.0
# ..        ...                   ...        ...        ...        ...
# 93     har_93           Residential        0.0        0.0        0.0
# 94     har_94           Residential        0.0        0.0        0.0
# 95     har_95  HerbaceousVegetation        0.0        0.0        0.0
# 96     har_96           Residential        0.0        0.0        0.0
# 97     har_97           Residential        0.0        0.0        0.0
#
#     Feature_18  Feature_23  Feature_27  Feature_28  Feature_35  ...  \
# 0     0.030216         0.0         0.0         0.0         0.0  ...
# ...

# %%
df4['Latitude'].nunique()
# Out:
# 93

# %%
df4['Longitude'].nunique()
# Out:
# 93

# %%
df4.to_csv('df4.csv', index=False)

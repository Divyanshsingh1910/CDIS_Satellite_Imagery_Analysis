# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# The following block is used to divide the NTL csv into 10 csvs so that each iteration doesn't have to go through all the datapoints in CSV. Division is done on the basis of latitude range.

# %%
import os
import pandas as pd

# Load ntl.csv and llong.csv into DataFrames
ntl_data = pd.read_csv('/kaggle/input/uploadfiles/NTL data of haryana.csv')
llong_data = pd.read_csv('/kaggle/input/uploadfiles/merged_output.csv')

# Define a function to partition data and save to CSVs
def partition_and_save(data, column_name, output_prefix):
    min_val = data[column_name].min()
    max_val = data[column_name].max()
    interval = (max_val - min_val) / 10
    
    for i in range(10):
        lower_bound = min_val + i * interval
        upper_bound = min_val + (i + 1) * interval
        partitioned_data = data[(data[column_name] >= lower_bound) & (data[column_name] < upper_bound)]
        
        # Save the partitioned data to CSV in /kaggle/working/ directory
        output_path = f'/kaggle/working/{output_prefix}_part_{i}.csv'
        partitioned_data.to_csv(output_path, index=False)
        print(f'Saved {output_path}')

# Partition ntl_data based on latitude
partition_and_save(ntl_data, 'latitude', 'ntl')

# Partition llong_data based on Latitude
partition_and_save(llong_data, 'Latitude', 'llong')
# Out:
# Saved /kaggle/working/ntl_part_0.csv
# Saved /kaggle/working/ntl_part_1.csv
# Saved /kaggle/working/ntl_part_2.csv
# Saved /kaggle/working/ntl_part_3.csv
# Saved /kaggle/working/ntl_part_4.csv
# Saved /kaggle/working/ntl_part_5.csv
# Saved /kaggle/working/ntl_part_6.csv
# Saved /kaggle/working/ntl_part_7.csv
# Saved /kaggle/working/ntl_part_8.csv
# Saved /kaggle/working/ntl_part_9.csv
# Saved /kaggle/working/llong_part_0.csv
# Saved /kaggle/working/llong_part_1.csv
# Saved /kaggle/working/llong_part_2.csv
# Saved /kaggle/working/llong_part_3.csv
# Saved /kaggle/working/llong_part_4.csv
# Saved /kaggle/working/llong_part_5.csv
# Saved /kaggle/working/llong_part_6.csv
# Saved /kaggle/working/llong_part_7.csv
# Saved /kaggle/working/llong_part_8.csv
# Saved /kaggle/working/llong_part_9.csv

# %% [markdown]
# The following code block calculates the closest lat-long in the NTL dataset and sets the NTL of this lat-long as the 'Closest NTL' of that patch.

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_0.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_0.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_0.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 25.0
# Processed row 2 - Closest NTL: 26.0
# Processed row 3 - Closest NTL: 25.0
# Processed row 4 - Closest NTL: 25.0
# Processed row 5 - Closest NTL: 26.0
# Processed row 6 - Closest NTL: 25.0
# Processed row 7 - Closest NTL: 25.0
# Processed row 8 - Closest NTL: 26.0
# Processed row 9 - Closest NTL: 25.0
# Processed row 10 - Closest NTL: 32.0
# Processed row 11 - Closest NTL: 30.0
# Processed row 12 - Closest NTL: 30.0
# Processed row 13 - Closest NTL: 32.0
# Processed row 14 - Closest NTL: 30.0
# Processed row 15 - Closest NTL: 30.0
# Processed row 16 - Closest NTL: 32.0
# Processed row 17 - Closest NTL: 30.0
# Processed row 18 - Closest NTL: 30.0
# Processed row 19 - Closest NTL: 34.0
# Processed row 20 - Closest NTL: 34.0
# Processed row 21 - Closest NTL: 35.0
# Processed row 22 - Closest NTL: 34.0
# Processed row 23 - Closest NTL: 34.0
# Processed row 24 - Closest NTL: 35.0
# Processed row 25 - Closest NTL: 32.0
# Processed row 26 - Closest NTL: 34.0
# Processed row 27 - Closest NTL: 33.0
# Processed row 28 - Closest NTL: 41.0
# Processed row 29 - Closest NTL: 40.0
# Processed row 30 - Closest NTL: 35.0
# Processed row 31 - Closest NTL: 41.0
# Processed row 32 - Closest NTL: 40.0
# Processed row 33 - Closest NTL: 35.0
# Processed row 34 - Closest NTL: 39.0
# Processed row 35 - Closest NTL: 39.0
# Processed row 36 - Closest NTL: 37.0
# Processed row 37 - Closest NTL: 31.0
# Processed row 38 - Closest NTL: 31.0
# Processed row 39 - Closest NTL: 31.0
# Processed row 40 - Closest NTL: 31.0
# Processed row 41 - Closest NTL: 31.0
# Processed row 42 - Closest NTL: 31.0
# Processed row 43 - Closest NTL: 33.0
# Processed row 44 - Closest NTL: 34.0
# Processed row 45 - Closest NTL: 33.0
# Processed row 46 - Closest NTL: 26.0
# Processed row 47 - Closest NTL: 27.0
# Processed row 48 - Closest NTL: 29.0
# Processed row 49 - Closest NTL: 26.0
# Processed row 50 - Closest NTL: 27.0
# Processed row 51 - Closest NTL: 29.0
# Processed row 52 - Closest NTL: 26.0
# Processed row 53 - Closest NTL: 27.0
# Processed row 54 - Closest NTL: 29.0
# Processed row 55 - Closest NTL: 39.0
# Processed row 56 - Closest NTL: 40.0
# Processed row 57 - Closest NTL: 38.0
# Processed row 58 - Closest NTL: 40.0
# Processed row 59 - Closest NTL: 40.0
# Processed row 60 - Closest NTL: 39.0
# Processed row 61 - Closest NTL: 40.0
# Processed row 62 - Closest NTL: 40.0
# Processed row 63 - Closest NTL: 39.0
# Processed row 64 - Closest NTL: 31.0
# Processed row 65 - Closest NTL: 31.0
# Processed row 66 - Closest NTL: 31.0
# Processed row 67 - Closest NTL: 32.0
# Processed row 68 - Closest NTL: 32.0
# Processed row 69 - Closest NTL: 33.0
# Processed row 70 - Closest NTL: 32.0
# Processed row 71 - Closest NTL: 32.0
# Processed row 72 - Closest NTL: 33.0
# Processed row 73 - Closest NTL: 139.0
# Processed row 74 - Closest NTL: 139.0
# Processed row 75 - Closest NTL: 141.0
# Processed row 76 - Closest NTL: 139.0
# Processed row 77 - Closest NTL: 139.0
# Processed row 78 - Closest NTL: 141.0
# Processed row 79 - Closest NTL: 138.0
# Processed row 80 - Closest NTL: 134.0
# Processed row 81 - Closest NTL: 139.0
# Processed row 82 - Closest NTL: 139.0
# Processed row 83 - Closest NTL: 141.0
# Processed row 84 - Closest NTL: 140.0
# Processed row 85 - Closest NTL: 139.0
# Processed row 86 - Closest NTL: 141.0
# Processed row 87 - Closest NTL: 140.0
# Processed row 88 - Closest NTL: 134.0
# Processed row 89 - Closest NTL: 139.0
# Processed row 90 - Closest NTL: 139.0
# Processed row 91 - Closest NTL: 35.0
# Processed row 92 - Closest NTL: 33.0
# Processed row 93 - Closest NTL: 34.0
# Processed row 94 - Closest NTL: 35.0
# Processed row 95 - Closest NTL: 33.0
# Processed row 96 - Closest NTL: 34.0
# Processed row 97 - Closest NTL: 35.0
# Processed row 98 - Closest NTL: 33.0
# Processed row 99 - Closest NTL: 34.0
# Processed row 100 - Closest NTL: 177.0
# Processed row 101 - Closest NTL: 43.0
# Processed row 102 - Closest NTL: 44.0
# Processed row 103 - Closest NTL: 177.0
# Processed row 104 - Closest NTL: 43.0
# Processed row 105 - Closest NTL: 44.0
# Processed row 106 - Closest NTL: 46.0
# Processed row 107 - Closest NTL: 45.0
# Processed row 108 - Closest NTL: 46.0
# Processed row 109 - Closest NTL: 30.0
# Processed row 110 - Closest NTL: 33.0
# Processed row 111 - Closest NTL: 32.0
# Processed row 112 - Closest NTL: 30.0
# Processed row 113 - Closest NTL: 33.0
# Processed row 114 - Closest NTL: 32.0
# Processed row 115 - Closest NTL: 30.0
# Processed row 116 - Closest NTL: 33.0
# Processed row 117 - Closest NTL: 32.0
# Processed row 118 - Closest NTL: 36.0
# Processed row 119 - Closest NTL: 35.0
# Processed row 120 - Closest NTL: 38.0
# Processed row 121 - Closest NTL: 34.0
# Processed row 122 - Closest NTL: 37.0
# Processed row 123 - Closest NTL: 38.0
# Processed row 124 - Closest NTL: 34.0
# Processed row 125 - Closest NTL: 37.0
# Processed row 126 - Closest NTL: 38.0
# Processed row 127 - Closest NTL: 26.0
# Processed row 128 - Closest NTL: 28.0
# Processed row 129 - Closest NTL: 28.0
# Processed row 130 - Closest NTL: 26.0
# Processed row 131 - Closest NTL: 28.0
# Processed row 132 - Closest NTL: 28.0
# Processed row 133 - Closest NTL: 27.0
# Processed row 134 - Closest NTL: 27.0
# Processed row 135 - Closest NTL: 26.0
# Processed row 136 - Closest NTL: 37.0
# Processed row 137 - Closest NTL: 37.0
# Processed row 138 - Closest NTL: 36.0
# Processed row 139 - Closest NTL: 37.0
# Processed row 140 - Closest NTL: 37.0
# Processed row 141 - Closest NTL: 36.0
# Processed row 142 - Closest NTL: 35.0
# Processed row 143 - Closest NTL: 36.0
# Processed row 144 - Closest NTL: 39.0
# Processed row 145 - Closest NTL: 35.0
# Processed row 146 - Closest NTL: 36.0
# Processed row 147 - Closest NTL: 39.0
# Processed row 148 - Closest NTL: 31.0
# Processed row 149 - Closest NTL: 35.0
# Processed row 150 - Closest NTL: 35.0
# Processed row 151 - Closest NTL: 31.0
# Processed row 152 - Closest NTL: 30.0
# Processed row 153 - Closest NTL: 29.0
# Processed row 154 - Closest NTL: 32.0
# Processed row 155 - Closest NTL: 31.0
# Processed row 156 - Closest NTL: 30.0
# Processed row 157 - Closest NTL: 32.0
# Processed row 158 - Closest NTL: 33.0
# Processed row 159 - Closest NTL: 32.0
# Processed row 160 - Closest NTL: 28.0
# Processed row 161 - Closest NTL: 28.0
# Processed row 162 - Closest NTL: 30.0
# Processed row 163 - Closest NTL: 28.0
# Processed row 164 - Closest NTL: 28.0
# Processed row 165 - Closest NTL: 30.0
# Processed row 166 - Closest NTL: 29.0
# Processed row 167 - Closest NTL: 27.0
# Processed row 168 - Closest NTL: 27.0
# Processed row 169 - Closest NTL: 130.0
# Processed row 170 - Closest NTL: 99.0
# Processed row 171 - Closest NTL: 99.0
# Processed row 172 - Closest NTL: 30.0
# Processed row 173 - Closest NTL: 29.0
# Processed row 174 - Closest NTL: 30.0
# Processed row 175 - Closest NTL: 30.0
# Processed row 176 - Closest NTL: 29.0
# Processed row 177 - Closest NTL: 30.0
# Processed row 178 - Closest NTL: 44.0
# Processed row 179 - Closest NTL: 44.0
# Processed row 180 - Closest NTL: 86.0
# Processed row 181 - Closest NTL: 44.0
# Processed row 182 - Closest NTL: 44.0
# Processed row 183 - Closest NTL: 86.0
# Processed row 184 - Closest NTL: 44.0
# Processed row 185 - Closest NTL: 44.0
# Processed row 186 - Closest NTL: 86.0
# Processed row 187 - Closest NTL: 29.0
# Processed row 188 - Closest NTL: 128.0
# Processed row 189 - Closest NTL: 130.0
# Processed row 190 - Closest NTL: 29.0
# Processed row 191 - Closest NTL: 128.0
# Processed row 192 - Closest NTL: 130.0
# Processed row 193 - Closest NTL: 29.0
# Processed row 194 - Closest NTL: 129.0
# Processed row 195 - Closest NTL: 130.0
# Processed row 196 - Closest NTL: 44.0
# Processed row 197 - Closest NTL: 44.0
# Processed row 198 - Closest NTL: 44.0
# Processed row 199 - Closest NTL: 44.0
# Processed row 200 - Closest NTL: 44.0
# Processed row 201 - Closest NTL: 44.0
# Processed row 202 - Closest NTL: 44.0
# Processed row 203 - Closest NTL: 44.0
# Processed row 204 - Closest NTL: 44.0
# Processed row 205 - Closest NTL: 40.0
# Processed row 206 - Closest NTL: 40.0
# Processed row 207 - Closest NTL: 39.0
# Processed row 208 - Closest NTL: 40.0
# Processed row 209 - Closest NTL: 40.0
# Processed row 210 - Closest NTL: 39.0
# Processed row 211 - Closest NTL: 39.0
# Processed row 212 - Closest NTL: 39.0
# Processed row 213 - Closest NTL: 41.0
# Processed row 214 - Closest NTL: 37.0
# Processed row 215 - Closest NTL: 35.0
# Processed row 216 - Closest NTL: 35.0
# Processed row 217 - Closest NTL: 37.0
# Processed row 218 - Closest NTL: 35.0
# Processed row 219 - Closest NTL: 35.0
# Processed row 220 - Closest NTL: 37.0
# Processed row 221 - Closest NTL: 35.0
# Processed row 222 - Closest NTL: 35.0
# Processed row 223 - Closest NTL: 39.0
# Processed row 224 - Closest NTL: 40.0
# Processed row 225 - Closest NTL: 40.0
# Processed row 226 - Closest NTL: 39.0
# Processed row 227 - Closest NTL: 40.0
# Processed row 228 - Closest NTL: 40.0
# Processed row 229 - Closest NTL: 39.0
# Processed row 230 - Closest NTL: 40.0
# Processed row 231 - Closest NTL: 40.0
# Processed row 232 - Closest NTL: 42.0
# Processed row 233 - Closest NTL: 34.0
# Processed row 234 - Closest NTL: 32.0
# Processed row 235 - Closest NTL: 42.0
# Processed row 236 - Closest NTL: 34.0
# Processed row 237 - Closest NTL: 32.0
# Processed row 238 - Closest NTL: 42.0
# Processed row 239 - Closest NTL: 34.0
# Processed row 240 - Closest NTL: 32.0
# Processed row 241 - Closest NTL: 255.0
# Processed row 242 - Closest NTL: 255.0
# Processed row 243 - Closest NTL: 46.0
# Processed row 244 - Closest NTL: 248.0
# Processed row 245 - Closest NTL: 248.0
# Processed row 246 - Closest NTL: 82.0
# Processed row 247 - Closest NTL: 248.0
# Processed row 248 - Closest NTL: 248.0
# Processed row 249 - Closest NTL: 82.0
# Processed row 250 - Closest NTL: 58.0
# Processed row 251 - Closest NTL: 56.0
# Processed row 252 - Closest NTL: 255.0
# Processed row 253 - Closest NTL: 58.0
# Processed row 254 - Closest NTL: 56.0
# Processed row 255 - Closest NTL: 255.0
# Processed row 256 - Closest NTL: 61.0
# Processed row 257 - Closest NTL: 60.0
# Processed row 258 - Closest NTL: 255.0
# Processed row 259 - Closest NTL: 34.0
# Processed row 260 - Closest NTL: 35.0
# Processed row 261 - Closest NTL: 35.0
# Processed row 262 - Closest NTL: 33.0
# Processed row 263 - Closest NTL: 33.0
# Processed row 264 - Closest NTL: 35.0
# Processed row 265 - Closest NTL: 33.0
# Processed row 266 - Closest NTL: 33.0
# Processed row 267 - Closest NTL: 35.0
# Processed row 268 - Closest NTL: 124.0
# Processed row 269 - Closest NTL: 102.0
# Processed row 270 - Closest NTL: 102.0
# Processed row 271 - Closest NTL: 124.0
# Processed row 272 - Closest NTL: 102.0
# Processed row 273 - Closest NTL: 102.0
# Processed row 274 - Closest NTL: 31.0
# Processed row 275 - Closest NTL: 30.0
# Processed row 276 - Closest NTL: 31.0
# Processed row 277 - Closest NTL: 24.0
# Processed row 278 - Closest NTL: 24.0
# Processed row 279 - Closest NTL: 23.0
# Processed row 280 - Closest NTL: 23.0
# Processed row 281 - Closest NTL: 26.0
# Processed row 282 - Closest NTL: 26.0
# Processed row 283 - Closest NTL: 23.0
# Processed row 284 - Closest NTL: 26.0
# Processed row 285 - Closest NTL: 26.0
# Processed row 286 - Closest NTL: 23.0
# Processed row 287 - Closest NTL: 26.0
# Processed row 288 - Closest NTL: 26.0
# Processed row 289 - Closest NTL: 34.0
# Processed row 290 - Closest NTL: 33.0
# Processed row 291 - Closest NTL: 32.0
# Processed row 292 - Closest NTL: 34.0
# Processed row 293 - Closest NTL: 33.0
# Processed row 294 - Closest NTL: 32.0
# Processed row 295 - Closest NTL: 34.0
# Processed row 296 - Closest NTL: 33.0
# Processed row 297 - Closest NTL: 32.0
# Processed row 298 - Closest NTL: 30.0
# Processed row 299 - Closest NTL: 30.0
# Processed row 300 - Closest NTL: 33.0
# Processed row 301 - Closest NTL: 30.0
# Processed row 302 - Closest NTL: 30.0
# Processed row 303 - Closest NTL: 33.0
# Processed row 304 - Closest NTL: 30.0
# Processed row 305 - Closest NTL: 31.0
# Processed row 306 - Closest NTL: 34.0
# Processed row 307 - Closest NTL: 23.0
# Processed row 308 - Closest NTL: 25.0
# Processed row 309 - Closest NTL: 27.0
# Processed row 310 - Closest NTL: 24.0
# Processed row 311 - Closest NTL: 24.0
# Processed row 312 - Closest NTL: 25.0
# Processed row 313 - Closest NTL: 24.0
# Processed row 314 - Closest NTL: 24.0
# Processed row 315 - Closest NTL: 25.0
# Processed row 316 - Closest NTL: 59.0
# Processed row 317 - Closest NTL: 56.0
# Processed row 318 - Closest NTL: 220.0
# Processed row 319 - Closest NTL: 59.0
# Processed row 320 - Closest NTL: 56.0
# Processed row 321 - Closest NTL: 220.0
# Processed row 322 - Closest NTL: 59.0
# Processed row 323 - Closest NTL: 56.0
# Processed row 324 - Closest NTL: 220.0
# Processed row 325 - Closest NTL: 43.0
# Processed row 326 - Closest NTL: 44.0
# Processed row 327 - Closest NTL: 44.0
# Processed row 328 - Closest NTL: 43.0
# Processed row 329 - Closest NTL: 44.0
# Processed row 330 - Closest NTL: 44.0
# Processed row 331 - Closest NTL: 44.0
# Processed row 332 - Closest NTL: 44.0
# Processed row 333 - Closest NTL: 43.0
# Processed row 334 - Closest NTL: 46.0
# Processed row 335 - Closest NTL: 46.0
# Processed row 336 - Closest NTL: 44.0
# Processed row 337 - Closest NTL: 45.0
# Processed row 338 - Closest NTL: 44.0
# Processed row 339 - Closest NTL: 45.0
# Processed row 340 - Closest NTL: 45.0
# Processed row 341 - Closest NTL: 44.0
# Processed row 342 - Closest NTL: 45.0
# Processed row 343 - Closest NTL: 26.0
# Processed row 344 - Closest NTL: 26.0
# Processed row 345 - Closest NTL: 25.0
# Processed row 346 - Closest NTL: 26.0
# Processed row 347 - Closest NTL: 26.0
# Processed row 348 - Closest NTL: 25.0
# Processed row 349 - Closest NTL: 29.0
# Processed row 350 - Closest NTL: 30.0
# Processed row 351 - Closest NTL: 30.0
# Processed row 352 - Closest NTL: 29.0
# Processed row 353 - Closest NTL: 30.0
# Processed row 354 - Closest NTL: 30.0
# Processed row 355 - Closest NTL: 31.0
# Processed row 356 - Closest NTL: 30.0
# Processed row 357 - Closest NTL: 31.0
# Processed row 358 - Closest NTL: 25.0
# Processed row 359 - Closest NTL: 26.0
# Processed row 360 - Closest NTL: 25.0
# Processed row 361 - Closest NTL: 25.0
# Processed row 362 - Closest NTL: 26.0
# Processed row 363 - Closest NTL: 25.0
# Processed row 364 - Closest NTL: 24.0
# Processed row 365 - Closest NTL: 24.0
# Processed row 366 - Closest NTL: 25.0
# Processed row 367 - Closest NTL: 29.0
# Processed row 368 - Closest NTL: 27.0
# Processed row 369 - Closest NTL: 27.0
# Processed row 370 - Closest NTL: 24.0
# Processed row 371 - Closest NTL: 25.0
# Processed row 372 - Closest NTL: 26.0
# Processed row 373 - Closest NTL: 24.0
# Processed row 374 - Closest NTL: 25.0
# Processed row 375 - Closest NTL: 26.0
# Processed row 376 - Closest NTL: 24.0
# Processed row 377 - Closest NTL: 27.0
# Processed row 378 - Closest NTL: 25.0
# Processed row 379 - Closest NTL: 100.0
# Processed row 380 - Closest NTL: 25.0
# Processed row 381 - Closest NTL: 25.0
# Processed row 382 - Closest NTL: 100.0
# Processed row 383 - Closest NTL: 25.0
# Processed row 384 - Closest NTL: 25.0
# Processed row 385 - Closest NTL: 165.0
# Processed row 386 - Closest NTL: 163.0
# Processed row 387 - Closest NTL: 42.0
# Processed row 388 - Closest NTL: 165.0
# Processed row 389 - Closest NTL: 163.0
# Processed row 390 - Closest NTL: 42.0
# Processed row 391 - Closest NTL: 165.0
# Processed row 392 - Closest NTL: 163.0
# Processed row 393 - Closest NTL: 42.0
# Processed row 394 - Closest NTL: 32.0
# Processed row 395 - Closest NTL: 31.0
# Processed row 396 - Closest NTL: 29.0
# Processed row 397 - Closest NTL: 34.0
# Processed row 398 - Closest NTL: 33.0
# Processed row 399 - Closest NTL: 30.0
# Processed row 400 - Closest NTL: 34.0
# Processed row 401 - Closest NTL: 33.0
# Processed row 402 - Closest NTL: 30.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_0.csv
# Number of closest NTLs assigned: 402

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_1.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_1.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_1.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 97.0
# Processed row 2 - Closest NTL: 96.0
# Processed row 3 - Closest NTL: 80.0
# Processed row 4 - Closest NTL: 97.0
# Processed row 5 - Closest NTL: 96.0
# Processed row 6 - Closest NTL: 80.0
# Processed row 7 - Closest NTL: 96.0
# Processed row 8 - Closest NTL: 95.0
# Processed row 9 - Closest NTL: 80.0
# Processed row 10 - Closest NTL: 255.0
# Processed row 11 - Closest NTL: 255.0
# Processed row 12 - Closest NTL: 255.0
# Processed row 13 - Closest NTL: 255.0
# Processed row 14 - Closest NTL: 255.0
# Processed row 15 - Closest NTL: 255.0
# Processed row 16 - Closest NTL: 229.0
# Processed row 17 - Closest NTL: 255.0
# Processed row 18 - Closest NTL: 255.0
# Processed row 19 - Closest NTL: 41.0
# Processed row 20 - Closest NTL: 36.0
# Processed row 21 - Closest NTL: 35.0
# Processed row 22 - Closest NTL: 41.0
# Processed row 23 - Closest NTL: 36.0
# Processed row 24 - Closest NTL: 35.0
# Processed row 25 - Closest NTL: 41.0
# Processed row 26 - Closest NTL: 37.0
# Processed row 27 - Closest NTL: 34.0
# Processed row 28 - Closest NTL: 244.0
# Processed row 29 - Closest NTL: 244.0
# Processed row 30 - Closest NTL: 216.0
# Processed row 31 - Closest NTL: 242.0
# Processed row 32 - Closest NTL: 243.0
# Processed row 33 - Closest NTL: 217.0
# Processed row 34 - Closest NTL: 242.0
# Processed row 35 - Closest NTL: 243.0
# Processed row 36 - Closest NTL: 217.0
# Processed row 37 - Closest NTL: 28.0
# Processed row 38 - Closest NTL: 28.0
# Processed row 39 - Closest NTL: 27.0
# Processed row 40 - Closest NTL: 28.0
# Processed row 41 - Closest NTL: 28.0
# Processed row 42 - Closest NTL: 27.0
# Processed row 43 - Closest NTL: 28.0
# Processed row 44 - Closest NTL: 28.0
# Processed row 45 - Closest NTL: 27.0
# Processed row 46 - Closest NTL: 27.0
# Processed row 47 - Closest NTL: 29.0
# Processed row 48 - Closest NTL: 30.0
# Processed row 49 - Closest NTL: 28.0
# Processed row 50 - Closest NTL: 30.0
# Processed row 51 - Closest NTL: 29.0
# Processed row 52 - Closest NTL: 27.0
# Processed row 53 - Closest NTL: 28.0
# Processed row 54 - Closest NTL: 28.0
# Processed row 55 - Closest NTL: 114.0
# Processed row 56 - Closest NTL: 113.0
# Processed row 57 - Closest NTL: 117.0
# Processed row 58 - Closest NTL: 171.0
# Processed row 59 - Closest NTL: 94.0
# Processed row 60 - Closest NTL: 97.0
# Processed row 61 - Closest NTL: 171.0
# Processed row 62 - Closest NTL: 94.0
# Processed row 63 - Closest NTL: 97.0
# Processed row 64 - Closest NTL: 255.0
# Processed row 65 - Closest NTL: 255.0
# Processed row 66 - Closest NTL: 255.0
# Processed row 67 - Closest NTL: 255.0
# Processed row 68 - Closest NTL: 255.0
# Processed row 69 - Closest NTL: 255.0
# Processed row 70 - Closest NTL: 255.0
# Processed row 71 - Closest NTL: 255.0
# Processed row 72 - Closest NTL: 255.0
# Processed row 73 - Closest NTL: 184.0
# Processed row 74 - Closest NTL: 186.0
# Processed row 75 - Closest NTL: 142.0
# Processed row 76 - Closest NTL: 184.0
# Processed row 77 - Closest NTL: 186.0
# Processed row 78 - Closest NTL: 142.0
# Processed row 79 - Closest NTL: 110.0
# Processed row 80 - Closest NTL: 115.0
# Processed row 81 - Closest NTL: 124.0
# Processed row 82 - Closest NTL: 26.0
# Processed row 83 - Closest NTL: 27.0
# Processed row 84 - Closest NTL: 27.0
# Processed row 85 - Closest NTL: 27.0
# Processed row 86 - Closest NTL: 27.0
# Processed row 87 - Closest NTL: 28.0
# Processed row 88 - Closest NTL: 27.0
# Processed row 89 - Closest NTL: 27.0
# Processed row 90 - Closest NTL: 28.0
# Processed row 91 - Closest NTL: 60.0
# Processed row 92 - Closest NTL: 62.0
# Processed row 93 - Closest NTL: 60.0
# Processed row 94 - Closest NTL: 61.0
# Processed row 95 - Closest NTL: 56.0
# Processed row 96 - Closest NTL: 52.0
# Processed row 97 - Closest NTL: 61.0
# Processed row 98 - Closest NTL: 56.0
# Processed row 99 - Closest NTL: 52.0
# Processed row 100 - Closest NTL: 77.0
# Processed row 101 - Closest NTL: 78.0
# Processed row 102 - Closest NTL: 56.0
# Processed row 103 - Closest NTL: 75.0
# Processed row 104 - Closest NTL: 76.0
# Processed row 105 - Closest NTL: 59.0
# Processed row 106 - Closest NTL: 75.0
# Processed row 107 - Closest NTL: 76.0
# Processed row 108 - Closest NTL: 59.0
# Processed row 109 - Closest NTL: 255.0
# Processed row 110 - Closest NTL: 255.0
# Processed row 111 - Closest NTL: 255.0
# Processed row 112 - Closest NTL: 255.0
# Processed row 113 - Closest NTL: 255.0
# Processed row 114 - Closest NTL: 255.0
# Processed row 115 - Closest NTL: 255.0
# Processed row 116 - Closest NTL: 255.0
# Processed row 117 - Closest NTL: 255.0
# Processed row 118 - Closest NTL: 43.0
# Processed row 119 - Closest NTL: 46.0
# Processed row 120 - Closest NTL: 44.0
# Processed row 121 - Closest NTL: 115.0
# Processed row 122 - Closest NTL: 126.0
# Processed row 123 - Closest NTL: 119.0
# Processed row 124 - Closest NTL: 145.0
# Processed row 125 - Closest NTL: 159.0
# Processed row 126 - Closest NTL: 157.0
# Processed row 127 - Closest NTL: 145.0
# Processed row 128 - Closest NTL: 159.0
# Processed row 129 - Closest NTL: 157.0
# Processed row 130 - Closest NTL: 32.0
# Processed row 131 - Closest NTL: 149.0
# Processed row 132 - Closest NTL: 149.0
# Processed row 133 - Closest NTL: 32.0
# Processed row 134 - Closest NTL: 149.0
# Processed row 135 - Closest NTL: 149.0
# Processed row 136 - Closest NTL: 31.0
# Processed row 137 - Closest NTL: 150.0
# Processed row 138 - Closest NTL: 149.0
# Processed row 139 - Closest NTL: 228.0
# Processed row 140 - Closest NTL: 255.0
# Processed row 141 - Closest NTL: 255.0
# Processed row 142 - Closest NTL: 228.0
# Processed row 143 - Closest NTL: 255.0
# Processed row 144 - Closest NTL: 255.0
# Processed row 145 - Closest NTL: 228.0
# Processed row 146 - Closest NTL: 255.0
# Processed row 147 - Closest NTL: 255.0
# Processed row 148 - Closest NTL: 255.0
# Processed row 149 - Closest NTL: 255.0
# Processed row 150 - Closest NTL: 255.0
# Processed row 151 - Closest NTL: 255.0
# Processed row 152 - Closest NTL: 255.0
# Processed row 153 - Closest NTL: 255.0
# Processed row 154 - Closest NTL: 255.0
# Processed row 155 - Closest NTL: 255.0
# Processed row 156 - Closest NTL: 255.0
# Processed row 157 - Closest NTL: 196.0
# Processed row 158 - Closest NTL: 195.0
# Processed row 159 - Closest NTL: 223.0
# Processed row 160 - Closest NTL: 195.0
# Processed row 161 - Closest NTL: 195.0
# Processed row 162 - Closest NTL: 225.0
# Processed row 163 - Closest NTL: 195.0
# Processed row 164 - Closest NTL: 195.0
# Processed row 165 - Closest NTL: 225.0
# Processed row 166 - Closest NTL: 255.0
# Processed row 167 - Closest NTL: 255.0
# Processed row 168 - Closest NTL: 247.0
# Processed row 169 - Closest NTL: 255.0
# Processed row 170 - Closest NTL: 255.0
# Processed row 171 - Closest NTL: 246.0
# Processed row 172 - Closest NTL: 255.0
# Processed row 173 - Closest NTL: 255.0
# Processed row 174 - Closest NTL: 246.0
# Processed row 175 - Closest NTL: 26.0
# Processed row 176 - Closest NTL: 27.0
# Processed row 177 - Closest NTL: 27.0
# Processed row 178 - Closest NTL: 26.0
# Processed row 179 - Closest NTL: 27.0
# Processed row 180 - Closest NTL: 27.0
# Processed row 181 - Closest NTL: 26.0
# Processed row 182 - Closest NTL: 27.0
# Processed row 183 - Closest NTL: 27.0
# Processed row 184 - Closest NTL: 45.0
# Processed row 185 - Closest NTL: 46.0
# Processed row 186 - Closest NTL: 46.0
# Processed row 187 - Closest NTL: 46.0
# Processed row 188 - Closest NTL: 45.0
# Processed row 189 - Closest NTL: 48.0
# Processed row 190 - Closest NTL: 46.0
# Processed row 191 - Closest NTL: 45.0
# Processed row 192 - Closest NTL: 48.0
# Processed row 193 - Closest NTL: 222.0
# Processed row 194 - Closest NTL: 255.0
# Processed row 195 - Closest NTL: 255.0
# Processed row 196 - Closest NTL: 209.0
# Processed row 197 - Closest NTL: 237.0
# Processed row 198 - Closest NTL: 238.0
# Processed row 199 - Closest NTL: 209.0
# Processed row 200 - Closest NTL: 237.0
# Processed row 201 - Closest NTL: 238.0
# Processed row 202 - Closest NTL: 255.0
# Processed row 203 - Closest NTL: 255.0
# Processed row 204 - Closest NTL: 255.0
# Processed row 205 - Closest NTL: 255.0
# Processed row 206 - Closest NTL: 255.0
# Processed row 207 - Closest NTL: 255.0
# Processed row 208 - Closest NTL: 203.0
# Processed row 209 - Closest NTL: 203.0
# Processed row 210 - Closest NTL: 33.0
# Processed row 211 - Closest NTL: 132.0
# Processed row 212 - Closest NTL: 142.0
# Processed row 213 - Closest NTL: 142.0
# Processed row 214 - Closest NTL: 101.0
# Processed row 215 - Closest NTL: 134.0
# Processed row 216 - Closest NTL: 135.0
# Processed row 217 - Closest NTL: 101.0
# Processed row 218 - Closest NTL: 134.0
# Processed row 219 - Closest NTL: 135.0
# Processed row 220 - Closest NTL: 255.0
# Processed row 221 - Closest NTL: 255.0
# Processed row 222 - Closest NTL: 255.0
# Processed row 223 - Closest NTL: 162.0
# Processed row 224 - Closest NTL: 172.0
# Processed row 225 - Closest NTL: 173.0
# Processed row 226 - Closest NTL: 162.0
# Processed row 227 - Closest NTL: 172.0
# Processed row 228 - Closest NTL: 173.0
# Processed row 229 - Closest NTL: 23.0
# Processed row 230 - Closest NTL: 23.0
# Processed row 231 - Closest NTL: 23.0
# Processed row 232 - Closest NTL: 23.0
# Processed row 233 - Closest NTL: 23.0
# Processed row 234 - Closest NTL: 23.0
# Processed row 235 - Closest NTL: 24.0
# Processed row 236 - Closest NTL: 24.0
# Processed row 237 - Closest NTL: 24.0
# Processed row 238 - Closest NTL: 50.0
# Processed row 239 - Closest NTL: 50.0
# Processed row 240 - Closest NTL: 51.0
# Processed row 241 - Closest NTL: 47.0
# Processed row 242 - Closest NTL: 46.0
# Processed row 243 - Closest NTL: 47.0
# Processed row 244 - Closest NTL: 47.0
# Processed row 245 - Closest NTL: 46.0
# Processed row 246 - Closest NTL: 47.0
# Processed row 247 - Closest NTL: 28.0
# Processed row 248 - Closest NTL: 28.0
# Processed row 249 - Closest NTL: 29.0
# Processed row 250 - Closest NTL: 27.0
# Processed row 251 - Closest NTL: 26.0
# Processed row 252 - Closest NTL: 29.0
# Processed row 253 - Closest NTL: 27.0
# Processed row 254 - Closest NTL: 26.0
# Processed row 255 - Closest NTL: 29.0
# Processed row 256 - Closest NTL: 25.0
# Processed row 257 - Closest NTL: 24.0
# Processed row 258 - Closest NTL: 24.0
# Processed row 259 - Closest NTL: 25.0
# Processed row 260 - Closest NTL: 24.0
# Processed row 261 - Closest NTL: 24.0
# Processed row 262 - Closest NTL: 25.0
# Processed row 263 - Closest NTL: 24.0
# Processed row 264 - Closest NTL: 24.0
# Processed row 265 - Closest NTL: 28.0
# Processed row 266 - Closest NTL: 28.0
# Processed row 267 - Closest NTL: 26.0
# Processed row 268 - Closest NTL: 29.0
# Processed row 269 - Closest NTL: 28.0
# Processed row 270 - Closest NTL: 26.0
# Processed row 271 - Closest NTL: 29.0
# Processed row 272 - Closest NTL: 28.0
# Processed row 273 - Closest NTL: 26.0
# Processed row 274 - Closest NTL: 27.0
# Processed row 275 - Closest NTL: 26.0
# Processed row 276 - Closest NTL: 26.0
# Processed row 277 - Closest NTL: 27.0
# Processed row 278 - Closest NTL: 27.0
# Processed row 279 - Closest NTL: 27.0
# Processed row 280 - Closest NTL: 27.0
# Processed row 281 - Closest NTL: 27.0
# Processed row 282 - Closest NTL: 27.0
# Processed row 283 - Closest NTL: 184.0
# Processed row 284 - Closest NTL: 100.0
# Processed row 285 - Closest NTL: 104.0
# Processed row 286 - Closest NTL: 183.0
# Processed row 287 - Closest NTL: 101.0
# Processed row 288 - Closest NTL: 104.0
# Processed row 289 - Closest NTL: 183.0
# Processed row 290 - Closest NTL: 101.0
# Processed row 291 - Closest NTL: 104.0
# Processed row 292 - Closest NTL: 44.0
# Processed row 293 - Closest NTL: 45.0
# Processed row 294 - Closest NTL: 45.0
# Processed row 295 - Closest NTL: 44.0
# Processed row 296 - Closest NTL: 44.0
# Processed row 297 - Closest NTL: 47.0
# Processed row 298 - Closest NTL: 44.0
# Processed row 299 - Closest NTL: 44.0
# Processed row 300 - Closest NTL: 47.0
# Processed row 301 - Closest NTL: 31.0
# Processed row 302 - Closest NTL: 29.0
# Processed row 303 - Closest NTL: 29.0
# Processed row 304 - Closest NTL: 29.0
# Processed row 305 - Closest NTL: 29.0
# Processed row 306 - Closest NTL: 29.0
# Processed row 307 - Closest NTL: 29.0
# Processed row 308 - Closest NTL: 29.0
# Processed row 309 - Closest NTL: 29.0
# Processed row 310 - Closest NTL: 174.0
# Processed row 311 - Closest NTL: 176.0
# Processed row 312 - Closest NTL: 49.0
# Processed row 313 - Closest NTL: 174.0
# Processed row 314 - Closest NTL: 176.0
# Processed row 315 - Closest NTL: 49.0
# Processed row 316 - Closest NTL: 177.0
# Processed row 317 - Closest NTL: 176.0
# Processed row 318 - Closest NTL: 47.0
# Processed row 319 - Closest NTL: 60.0
# Processed row 320 - Closest NTL: 61.0
# Processed row 321 - Closest NTL: 60.0
# Processed row 322 - Closest NTL: 63.0
# Processed row 323 - Closest NTL: 63.0
# Processed row 324 - Closest NTL: 63.0
# Processed row 325 - Closest NTL: 90.0
# Processed row 326 - Closest NTL: 84.0
# Processed row 327 - Closest NTL: 78.0
# Processed row 328 - Closest NTL: 89.0
# Processed row 329 - Closest NTL: 85.0
# Processed row 330 - Closest NTL: 80.0
# Processed row 331 - Closest NTL: 94.0
# Processed row 332 - Closest NTL: 87.0
# Processed row 333 - Closest NTL: 83.0
# Processed row 334 - Closest NTL: 124.0
# Processed row 335 - Closest NTL: 45.0
# Processed row 336 - Closest NTL: 44.0
# Processed row 337 - Closest NTL: 44.0
# Processed row 338 - Closest NTL: 106.0
# Processed row 339 - Closest NTL: 108.0
# Processed row 340 - Closest NTL: 44.0
# Processed row 341 - Closest NTL: 106.0
# Processed row 342 - Closest NTL: 108.0
# Processed row 343 - Closest NTL: 59.0
# Processed row 344 - Closest NTL: 55.0
# Processed row 345 - Closest NTL: 52.0
# Processed row 346 - Closest NTL: 58.0
# Processed row 347 - Closest NTL: 54.0
# Processed row 348 - Closest NTL: 53.0
# Processed row 349 - Closest NTL: 58.0
# Processed row 350 - Closest NTL: 54.0
# Processed row 351 - Closest NTL: 53.0
# Processed row 352 - Closest NTL: 107.0
# Processed row 353 - Closest NTL: 102.0
# Processed row 354 - Closest NTL: 97.0
# Processed row 355 - Closest NTL: 107.0
# Processed row 356 - Closest NTL: 102.0
# Processed row 357 - Closest NTL: 97.0
# Processed row 358 - Closest NTL: 102.0
# Processed row 359 - Closest NTL: 99.0
# Processed row 360 - Closest NTL: 93.0
# Processed row 361 - Closest NTL: 24.0
# Processed row 362 - Closest NTL: 24.0
# Processed row 363 - Closest NTL: 23.0
# Processed row 364 - Closest NTL: 24.0
# Processed row 365 - Closest NTL: 24.0
# Processed row 366 - Closest NTL: 23.0
# Processed row 367 - Closest NTL: 24.0
# Processed row 368 - Closest NTL: 24.0
# Processed row 369 - Closest NTL: 23.0
# Processed row 370 - Closest NTL: 78.0
# Processed row 371 - Closest NTL: 75.0
# Processed row 372 - Closest NTL: 74.0
# Processed row 373 - Closest NTL: 77.0
# Processed row 374 - Closest NTL: 74.0
# Processed row 375 - Closest NTL: 71.0
# Processed row 376 - Closest NTL: 77.0
# Processed row 377 - Closest NTL: 74.0
# Processed row 378 - Closest NTL: 71.0
# Processed row 379 - Closest NTL: 160.0
# Processed row 380 - Closest NTL: 161.0
# Processed row 381 - Closest NTL: 161.0
# Processed row 382 - Closest NTL: 90.0
# Processed row 383 - Closest NTL: 93.0
# Processed row 384 - Closest NTL: 93.0
# Processed row 385 - Closest NTL: 90.0
# Processed row 386 - Closest NTL: 93.0
# Processed row 387 - Closest NTL: 93.0
# Processed row 388 - Closest NTL: 21.0
# Processed row 389 - Closest NTL: 24.0
# Processed row 390 - Closest NTL: 23.0
# Processed row 391 - Closest NTL: 25.0
# Processed row 392 - Closest NTL: 23.0
# Processed row 393 - Closest NTL: 24.0
# Processed row 394 - Closest NTL: 25.0
# Processed row 395 - Closest NTL: 22.0
# Processed row 396 - Closest NTL: 24.0
# Processed row 397 - Closest NTL: 25.0
# Processed row 398 - Closest NTL: 22.0
# Processed row 399 - Closest NTL: 24.0
# Processed row 400 - Closest NTL: 229.0
# Processed row 401 - Closest NTL: 229.0
# Processed row 402 - Closest NTL: 95.0
# Processed row 403 - Closest NTL: 229.0
# Processed row 404 - Closest NTL: 229.0
# Processed row 405 - Closest NTL: 95.0
# Processed row 406 - Closest NTL: 229.0
# Processed row 407 - Closest NTL: 229.0
# Processed row 408 - Closest NTL: 95.0
# Processed row 409 - Closest NTL: 255.0
# Processed row 410 - Closest NTL: 255.0
# Processed row 411 - Closest NTL: 255.0
# Processed row 412 - Closest NTL: 255.0
# Processed row 413 - Closest NTL: 255.0
# Processed row 414 - Closest NTL: 255.0
# Processed row 415 - Closest NTL: 255.0
# Processed row 416 - Closest NTL: 255.0
# Processed row 417 - Closest NTL: 255.0
# Processed row 418 - Closest NTL: 35.0
# Processed row 419 - Closest NTL: 35.0
# Processed row 420 - Closest NTL: 33.0
# Processed row 421 - Closest NTL: 36.0
# Processed row 422 - Closest NTL: 37.0
# Processed row 423 - Closest NTL: 36.0
# Processed row 424 - Closest NTL: 36.0
# Processed row 425 - Closest NTL: 37.0
# Processed row 426 - Closest NTL: 36.0
# Processed row 427 - Closest NTL: 103.0
# Processed row 428 - Closest NTL: 104.0
# Processed row 429 - Closest NTL: 108.0
# Processed row 430 - Closest NTL: 101.0
# Processed row 431 - Closest NTL: 104.0
# Processed row 432 - Closest NTL: 104.0
# Processed row 433 - Closest NTL: 101.0
# Processed row 434 - Closest NTL: 104.0
# Processed row 435 - Closest NTL: 104.0
# Processed row 436 - Closest NTL: 108.0
# Processed row 437 - Closest NTL: 59.0
# Processed row 438 - Closest NTL: 59.0
# Processed row 439 - Closest NTL: 107.0
# Processed row 440 - Closest NTL: 58.0
# Processed row 441 - Closest NTL: 61.0
# Processed row 442 - Closest NTL: 107.0
# Processed row 443 - Closest NTL: 58.0
# Processed row 444 - Closest NTL: 61.0
# Processed row 445 - Closest NTL: 184.0
# Processed row 446 - Closest NTL: 24.0
# Processed row 447 - Closest NTL: 22.0
# Processed row 448 - Closest NTL: 184.0
# Processed row 449 - Closest NTL: 24.0
# Processed row 450 - Closest NTL: 22.0
# Processed row 451 - Closest NTL: 184.0
# Processed row 452 - Closest NTL: 23.0
# Processed row 453 - Closest NTL: 24.0
# Processed row 454 - Closest NTL: 170.0
# Processed row 455 - Closest NTL: 170.0
# Processed row 456 - Closest NTL: 90.0
# Processed row 457 - Closest NTL: 170.0
# Processed row 458 - Closest NTL: 170.0
# Processed row 459 - Closest NTL: 90.0
# Processed row 460 - Closest NTL: 54.0
# Processed row 461 - Closest NTL: 53.0
# Processed row 462 - Closest NTL: 56.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_1.csv
# Number of closest NTLs assigned: 462

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_2.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_2.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_2.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 255.0
# Processed row 2 - Closest NTL: 164.0
# Processed row 3 - Closest NTL: 164.0
# Processed row 4 - Closest NTL: 255.0
# Processed row 5 - Closest NTL: 163.0
# Processed row 6 - Closest NTL: 163.0
# Processed row 7 - Closest NTL: 255.0
# Processed row 8 - Closest NTL: 163.0
# Processed row 9 - Closest NTL: 163.0
# Processed row 10 - Closest NTL: 26.0
# Processed row 11 - Closest NTL: 26.0
# Processed row 12 - Closest NTL: 27.0
# Processed row 13 - Closest NTL: 26.0
# Processed row 14 - Closest NTL: 25.0
# Processed row 15 - Closest NTL: 26.0
# Processed row 16 - Closest NTL: 26.0
# Processed row 17 - Closest NTL: 25.0
# Processed row 18 - Closest NTL: 26.0
# Processed row 19 - Closest NTL: 26.0
# Processed row 20 - Closest NTL: 27.0
# Processed row 21 - Closest NTL: 28.0
# Processed row 22 - Closest NTL: 26.0
# Processed row 23 - Closest NTL: 26.0
# Processed row 24 - Closest NTL: 27.0
# Processed row 25 - Closest NTL: 26.0
# Processed row 26 - Closest NTL: 26.0
# Processed row 27 - Closest NTL: 27.0
# Processed row 28 - Closest NTL: 27.0
# Processed row 29 - Closest NTL: 28.0
# Processed row 30 - Closest NTL: 27.0
# Processed row 31 - Closest NTL: 27.0
# Processed row 32 - Closest NTL: 28.0
# Processed row 33 - Closest NTL: 27.0
# Processed row 34 - Closest NTL: 27.0
# Processed row 35 - Closest NTL: 28.0
# Processed row 36 - Closest NTL: 27.0
# Processed row 37 - Closest NTL: 24.0
# Processed row 38 - Closest NTL: 24.0
# Processed row 39 - Closest NTL: 25.0
# Processed row 40 - Closest NTL: 24.0
# Processed row 41 - Closest NTL: 24.0
# Processed row 42 - Closest NTL: 25.0
# Processed row 43 - Closest NTL: 24.0
# Processed row 44 - Closest NTL: 24.0
# Processed row 45 - Closest NTL: 25.0
# Processed row 46 - Closest NTL: 24.0
# Processed row 47 - Closest NTL: 24.0
# Processed row 48 - Closest NTL: 24.0
# Processed row 49 - Closest NTL: 23.0
# Processed row 50 - Closest NTL: 24.0
# Processed row 51 - Closest NTL: 25.0
# Processed row 52 - Closest NTL: 23.0
# Processed row 53 - Closest NTL: 24.0
# Processed row 54 - Closest NTL: 25.0
# Processed row 55 - Closest NTL: 24.0
# Processed row 56 - Closest NTL: 25.0
# Processed row 57 - Closest NTL: 23.0
# Processed row 58 - Closest NTL: 24.0
# Processed row 59 - Closest NTL: 25.0
# Processed row 60 - Closest NTL: 23.0
# Processed row 61 - Closest NTL: 23.0
# Processed row 62 - Closest NTL: 23.0
# Processed row 63 - Closest NTL: 23.0
# Processed row 64 - Closest NTL: 23.0
# Processed row 65 - Closest NTL: 24.0
# Processed row 66 - Closest NTL: 23.0
# Processed row 67 - Closest NTL: 23.0
# Processed row 68 - Closest NTL: 24.0
# Processed row 69 - Closest NTL: 23.0
# Processed row 70 - Closest NTL: 23.0
# Processed row 71 - Closest NTL: 22.0
# Processed row 72 - Closest NTL: 23.0
# Processed row 73 - Closest NTL: 55.0
# Processed row 74 - Closest NTL: 25.0
# Processed row 75 - Closest NTL: 26.0
# Processed row 76 - Closest NTL: 55.0
# Processed row 77 - Closest NTL: 25.0
# Processed row 78 - Closest NTL: 26.0
# Processed row 79 - Closest NTL: 56.0
# Processed row 80 - Closest NTL: 25.0
# Processed row 81 - Closest NTL: 26.0
# Processed row 82 - Closest NTL: 255.0
# Processed row 83 - Closest NTL: 255.0
# Processed row 84 - Closest NTL: 255.0
# Processed row 85 - Closest NTL: 255.0
# Processed row 86 - Closest NTL: 255.0
# Processed row 87 - Closest NTL: 255.0
# Processed row 88 - Closest NTL: 255.0
# Processed row 89 - Closest NTL: 255.0
# Processed row 90 - Closest NTL: 255.0
# Processed row 91 - Closest NTL: 255.0
# Processed row 92 - Closest NTL: 255.0
# Processed row 93 - Closest NTL: 255.0
# Processed row 94 - Closest NTL: 255.0
# Processed row 95 - Closest NTL: 255.0
# Processed row 96 - Closest NTL: 255.0
# Processed row 97 - Closest NTL: 255.0
# Processed row 98 - Closest NTL: 255.0
# Processed row 99 - Closest NTL: 255.0
# Processed row 100 - Closest NTL: 25.0
# Processed row 101 - Closest NTL: 25.0
# Processed row 102 - Closest NTL: 26.0
# Processed row 103 - Closest NTL: 25.0
# Processed row 104 - Closest NTL: 26.0
# Processed row 105 - Closest NTL: 26.0
# Processed row 106 - Closest NTL: 25.0
# Processed row 107 - Closest NTL: 26.0
# Processed row 108 - Closest NTL: 26.0
# Processed row 109 - Closest NTL: 25.0
# Processed row 110 - Closest NTL: 26.0
# Processed row 111 - Closest NTL: 25.0
# Processed row 112 - Closest NTL: 25.0
# Processed row 113 - Closest NTL: 26.0
# Processed row 114 - Closest NTL: 25.0
# Processed row 115 - Closest NTL: 23.0
# Processed row 116 - Closest NTL: 24.0
# Processed row 117 - Closest NTL: 24.0
# Processed row 118 - Closest NTL: 30.0
# Processed row 119 - Closest NTL: 134.0
# Processed row 120 - Closest NTL: 134.0
# Processed row 121 - Closest NTL: 27.0
# Processed row 122 - Closest NTL: 134.0
# Processed row 123 - Closest NTL: 134.0
# Processed row 124 - Closest NTL: 27.0
# Processed row 125 - Closest NTL: 134.0
# Processed row 126 - Closest NTL: 134.0
# Processed row 127 - Closest NTL: 255.0
# Processed row 128 - Closest NTL: 255.0
# Processed row 129 - Closest NTL: 255.0
# Processed row 130 - Closest NTL: 255.0
# Processed row 131 - Closest NTL: 255.0
# Processed row 132 - Closest NTL: 255.0
# Processed row 133 - Closest NTL: 255.0
# Processed row 134 - Closest NTL: 255.0
# Processed row 135 - Closest NTL: 255.0
# Processed row 136 - Closest NTL: 26.0
# Processed row 137 - Closest NTL: 26.0
# Processed row 138 - Closest NTL: 27.0
# Processed row 139 - Closest NTL: 26.0
# Processed row 140 - Closest NTL: 26.0
# Processed row 141 - Closest NTL: 27.0
# Processed row 142 - Closest NTL: 27.0
# Processed row 143 - Closest NTL: 26.0
# Processed row 144 - Closest NTL: 27.0
# Processed row 145 - Closest NTL: 20.0
# Processed row 146 - Closest NTL: 21.0
# Processed row 147 - Closest NTL: 20.0
# Processed row 148 - Closest NTL: 20.0
# Processed row 149 - Closest NTL: 21.0
# Processed row 150 - Closest NTL: 20.0
# Processed row 151 - Closest NTL: 22.0
# Processed row 152 - Closest NTL: 22.0
# Processed row 153 - Closest NTL: 21.0
# Processed row 154 - Closest NTL: 26.0
# Processed row 155 - Closest NTL: 27.0
# Processed row 156 - Closest NTL: 25.0
# Processed row 157 - Closest NTL: 26.0
# Processed row 158 - Closest NTL: 27.0
# Processed row 159 - Closest NTL: 25.0
# Processed row 160 - Closest NTL: 29.0
# Processed row 161 - Closest NTL: 28.0
# Processed row 162 - Closest NTL: 28.0
# Processed row 163 - Closest NTL: 25.0
# Processed row 164 - Closest NTL: 23.0
# Processed row 165 - Closest NTL: 25.0
# Processed row 166 - Closest NTL: 24.0
# Processed row 167 - Closest NTL: 24.0
# Processed row 168 - Closest NTL: 24.0
# Processed row 169 - Closest NTL: 24.0
# Processed row 170 - Closest NTL: 24.0
# Processed row 171 - Closest NTL: 24.0
# Processed row 172 - Closest NTL: 255.0
# Processed row 173 - Closest NTL: 255.0
# Processed row 174 - Closest NTL: 255.0
# Processed row 175 - Closest NTL: 255.0
# Processed row 176 - Closest NTL: 255.0
# Processed row 177 - Closest NTL: 255.0
# Processed row 178 - Closest NTL: 255.0
# Processed row 179 - Closest NTL: 255.0
# Processed row 180 - Closest NTL: 255.0
# Processed row 181 - Closest NTL: 255.0
# Processed row 182 - Closest NTL: 255.0
# Processed row 183 - Closest NTL: 255.0
# Processed row 184 - Closest NTL: 255.0
# Processed row 185 - Closest NTL: 255.0
# Processed row 186 - Closest NTL: 255.0
# Processed row 187 - Closest NTL: 255.0
# Processed row 188 - Closest NTL: 255.0
# Processed row 189 - Closest NTL: 255.0
# Processed row 190 - Closest NTL: 242.0
# Processed row 191 - Closest NTL: 216.0
# Processed row 192 - Closest NTL: 210.0
# Processed row 193 - Closest NTL: 242.0
# Processed row 194 - Closest NTL: 216.0
# Processed row 195 - Closest NTL: 210.0
# Processed row 196 - Closest NTL: 242.0
# Processed row 197 - Closest NTL: 216.0
# Processed row 198 - Closest NTL: 210.0
# Processed row 199 - Closest NTL: 56.0
# Processed row 200 - Closest NTL: 25.0
# Processed row 201 - Closest NTL: 26.0
# Processed row 202 - Closest NTL: 27.0
# Processed row 203 - Closest NTL: 27.0
# Processed row 204 - Closest NTL: 26.0
# Processed row 205 - Closest NTL: 27.0
# Processed row 206 - Closest NTL: 27.0
# Processed row 207 - Closest NTL: 26.0
# Processed row 208 - Closest NTL: 23.0
# Processed row 209 - Closest NTL: 23.0
# Processed row 210 - Closest NTL: 22.0
# Processed row 211 - Closest NTL: 23.0
# Processed row 212 - Closest NTL: 23.0
# Processed row 213 - Closest NTL: 22.0
# Processed row 214 - Closest NTL: 23.0
# Processed row 215 - Closest NTL: 23.0
# Processed row 216 - Closest NTL: 22.0
# Processed row 217 - Closest NTL: 23.0
# Processed row 218 - Closest NTL: 24.0
# Processed row 219 - Closest NTL: 23.0
# Processed row 220 - Closest NTL: 23.0
# Processed row 221 - Closest NTL: 24.0
# Processed row 222 - Closest NTL: 23.0
# Processed row 223 - Closest NTL: 23.0
# Processed row 224 - Closest NTL: 24.0
# Processed row 225 - Closest NTL: 23.0
# Processed row 226 - Closest NTL: 49.0
# Processed row 227 - Closest NTL: 49.0
# Processed row 228 - Closest NTL: 32.0
# Processed row 229 - Closest NTL: 49.0
# Processed row 230 - Closest NTL: 49.0
# Processed row 231 - Closest NTL: 32.0
# Processed row 232 - Closest NTL: 34.0
# Processed row 233 - Closest NTL: 34.0
# Processed row 234 - Closest NTL: 33.0
# Processed row 235 - Closest NTL: 255.0
# Processed row 236 - Closest NTL: 255.0
# Processed row 237 - Closest NTL: 255.0
# Processed row 238 - Closest NTL: 255.0
# Processed row 239 - Closest NTL: 255.0
# Processed row 240 - Closest NTL: 255.0
# Processed row 241 - Closest NTL: 255.0
# Processed row 242 - Closest NTL: 255.0
# Processed row 243 - Closest NTL: 255.0
# Processed row 244 - Closest NTL: 175.0
# Processed row 245 - Closest NTL: 175.0
# Processed row 246 - Closest NTL: 25.0
# Processed row 247 - Closest NTL: 26.0
# Processed row 248 - Closest NTL: 25.0
# Processed row 249 - Closest NTL: 25.0
# Processed row 250 - Closest NTL: 26.0
# Processed row 251 - Closest NTL: 25.0
# Processed row 252 - Closest NTL: 25.0
# Processed row 253 - Closest NTL: 175.0
# Processed row 254 - Closest NTL: 26.0
# Processed row 255 - Closest NTL: 26.0
# Processed row 256 - Closest NTL: 175.0
# Processed row 257 - Closest NTL: 25.0
# Processed row 258 - Closest NTL: 24.0
# Processed row 259 - Closest NTL: 175.0
# Processed row 260 - Closest NTL: 25.0
# Processed row 261 - Closest NTL: 24.0
# Processed row 262 - Closest NTL: 95.0
# Processed row 263 - Closest NTL: 25.0
# Processed row 264 - Closest NTL: 25.0
# Processed row 265 - Closest NTL: 95.0
# Processed row 266 - Closest NTL: 25.0
# Processed row 267 - Closest NTL: 25.0
# Processed row 268 - Closest NTL: 95.0
# Processed row 269 - Closest NTL: 27.0
# Processed row 270 - Closest NTL: 27.0
# Processed row 271 - Closest NTL: 33.0
# Processed row 272 - Closest NTL: 34.0
# Processed row 273 - Closest NTL: 31.0
# Processed row 274 - Closest NTL: 33.0
# Processed row 275 - Closest NTL: 34.0
# Processed row 276 - Closest NTL: 31.0
# Processed row 277 - Closest NTL: 32.0
# Processed row 278 - Closest NTL: 32.0
# Processed row 279 - Closest NTL: 33.0
# Processed row 280 - Closest NTL: 27.0
# Processed row 281 - Closest NTL: 25.0
# Processed row 282 - Closest NTL: 23.0
# Processed row 283 - Closest NTL: 27.0
# Processed row 284 - Closest NTL: 25.0
# Processed row 285 - Closest NTL: 23.0
# Processed row 286 - Closest NTL: 26.0
# Processed row 287 - Closest NTL: 25.0
# Processed row 288 - Closest NTL: 21.0
# Processed row 289 - Closest NTL: 26.0
# Processed row 290 - Closest NTL: 25.0
# Processed row 291 - Closest NTL: 25.0
# Processed row 292 - Closest NTL: 25.0
# Processed row 293 - Closest NTL: 25.0
# Processed row 294 - Closest NTL: 25.0
# Processed row 295 - Closest NTL: 25.0
# Processed row 296 - Closest NTL: 25.0
# Processed row 297 - Closest NTL: 26.0
# Processed row 298 - Closest NTL: 21.0
# Processed row 299 - Closest NTL: 20.0
# Processed row 300 - Closest NTL: 21.0
# Processed row 301 - Closest NTL: 21.0
# Processed row 302 - Closest NTL: 20.0
# Processed row 303 - Closest NTL: 21.0
# Processed row 304 - Closest NTL: 21.0
# Processed row 305 - Closest NTL: 19.0
# Processed row 306 - Closest NTL: 18.0
# Processed row 307 - Closest NTL: 113.0
# Processed row 308 - Closest NTL: 155.0
# Processed row 309 - Closest NTL: 156.0
# Processed row 310 - Closest NTL: 47.0
# Processed row 311 - Closest NTL: 46.0
# Processed row 312 - Closest NTL: 46.0
# Processed row 313 - Closest NTL: 47.0
# Processed row 314 - Closest NTL: 46.0
# Processed row 315 - Closest NTL: 46.0
# Processed row 316 - Closest NTL: 255.0
# Processed row 317 - Closest NTL: 153.0
# Processed row 318 - Closest NTL: 154.0
# Processed row 319 - Closest NTL: 255.0
# Processed row 320 - Closest NTL: 153.0
# Processed row 321 - Closest NTL: 153.0
# Processed row 322 - Closest NTL: 255.0
# Processed row 323 - Closest NTL: 153.0
# Processed row 324 - Closest NTL: 153.0
# Processed row 325 - Closest NTL: 29.0
# Processed row 326 - Closest NTL: 27.0
# Processed row 327 - Closest NTL: 26.0
# Processed row 328 - Closest NTL: 29.0
# Processed row 329 - Closest NTL: 27.0
# Processed row 330 - Closest NTL: 26.0
# Processed row 331 - Closest NTL: 29.0
# Processed row 332 - Closest NTL: 28.0
# Processed row 333 - Closest NTL: 26.0
# Processed row 334 - Closest NTL: 255.0
# Processed row 335 - Closest NTL: 255.0
# Processed row 336 - Closest NTL: 255.0
# Processed row 337 - Closest NTL: 255.0
# Processed row 338 - Closest NTL: 255.0
# Processed row 339 - Closest NTL: 255.0
# Processed row 340 - Closest NTL: 255.0
# Processed row 341 - Closest NTL: 255.0
# Processed row 342 - Closest NTL: 255.0
# Processed row 343 - Closest NTL: 24.0
# Processed row 344 - Closest NTL: 25.0
# Processed row 345 - Closest NTL: 24.0
# Processed row 346 - Closest NTL: 24.0
# Processed row 347 - Closest NTL: 25.0
# Processed row 348 - Closest NTL: 24.0
# Processed row 349 - Closest NTL: 24.0
# Processed row 350 - Closest NTL: 24.0
# Processed row 351 - Closest NTL: 24.0
# Processed row 352 - Closest NTL: 49.0
# Processed row 353 - Closest NTL: 50.0
# Processed row 354 - Closest NTL: 53.0
# Processed row 355 - Closest NTL: 49.0
# Processed row 356 - Closest NTL: 50.0
# Processed row 357 - Closest NTL: 53.0
# Processed row 358 - Closest NTL: 51.0
# Processed row 359 - Closest NTL: 53.0
# Processed row 360 - Closest NTL: 55.0
# Processed row 361 - Closest NTL: 255.0
# Processed row 362 - Closest NTL: 255.0
# Processed row 363 - Closest NTL: 255.0
# Processed row 364 - Closest NTL: 255.0
# Processed row 365 - Closest NTL: 255.0
# Processed row 366 - Closest NTL: 255.0
# Processed row 367 - Closest NTL: 255.0
# Processed row 368 - Closest NTL: 255.0
# Processed row 369 - Closest NTL: 255.0
# Processed row 370 - Closest NTL: 195.0
# Processed row 371 - Closest NTL: 195.0
# Processed row 372 - Closest NTL: 255.0
# Processed row 373 - Closest NTL: 195.0
# Processed row 374 - Closest NTL: 195.0
# Processed row 375 - Closest NTL: 255.0
# Processed row 376 - Closest NTL: 143.0
# Processed row 377 - Closest NTL: 144.0
# Processed row 378 - Closest NTL: 158.0
# Processed row 379 - Closest NTL: 27.0
# Processed row 380 - Closest NTL: 27.0
# Processed row 381 - Closest NTL: 27.0
# Processed row 382 - Closest NTL: 27.0
# Processed row 383 - Closest NTL: 27.0
# Processed row 384 - Closest NTL: 27.0
# Processed row 385 - Closest NTL: 29.0
# Processed row 386 - Closest NTL: 28.0
# Processed row 387 - Closest NTL: 26.0
# Processed row 388 - Closest NTL: 255.0
# Processed row 389 - Closest NTL: 255.0
# Processed row 390 - Closest NTL: 255.0
# Processed row 391 - Closest NTL: 255.0
# Processed row 392 - Closest NTL: 255.0
# Processed row 393 - Closest NTL: 255.0
# Processed row 394 - Closest NTL: 255.0
# Processed row 395 - Closest NTL: 255.0
# Processed row 396 - Closest NTL: 255.0
# Processed row 397 - Closest NTL: 35.0
# Processed row 398 - Closest NTL: 33.0
# Processed row 399 - Closest NTL: 32.0
# Processed row 400 - Closest NTL: 34.0
# Processed row 401 - Closest NTL: 33.0
# Processed row 402 - Closest NTL: 32.0
# Processed row 403 - Closest NTL: 34.0
# Processed row 404 - Closest NTL: 33.0
# Processed row 405 - Closest NTL: 32.0
# Processed row 406 - Closest NTL: 73.0
# Processed row 407 - Closest NTL: 75.0
# Processed row 408 - Closest NTL: 29.0
# Processed row 409 - Closest NTL: 73.0
# Processed row 410 - Closest NTL: 75.0
# Processed row 411 - Closest NTL: 29.0
# Processed row 412 - Closest NTL: 31.0
# Processed row 413 - Closest NTL: 32.0
# Processed row 414 - Closest NTL: 29.0
# Processed row 415 - Closest NTL: 25.0
# Processed row 416 - Closest NTL: 25.0
# Processed row 417 - Closest NTL: 25.0
# Processed row 418 - Closest NTL: 25.0
# Processed row 419 - Closest NTL: 25.0
# Processed row 420 - Closest NTL: 24.0
# Processed row 421 - Closest NTL: 25.0
# Processed row 422 - Closest NTL: 25.0
# Processed row 423 - Closest NTL: 24.0
# Processed row 424 - Closest NTL: 23.0
# Processed row 425 - Closest NTL: 24.0
# Processed row 426 - Closest NTL: 24.0
# Processed row 427 - Closest NTL: 24.0
# Processed row 428 - Closest NTL: 23.0
# Processed row 429 - Closest NTL: 24.0
# Processed row 430 - Closest NTL: 24.0
# Processed row 431 - Closest NTL: 23.0
# Processed row 432 - Closest NTL: 24.0
# Processed row 433 - Closest NTL: 190.0
# Processed row 434 - Closest NTL: 194.0
# Processed row 435 - Closest NTL: 188.0
# Processed row 436 - Closest NTL: 190.0
# Processed row 437 - Closest NTL: 194.0
# Processed row 438 - Closest NTL: 188.0
# Processed row 439 - Closest NTL: 188.0
# Processed row 440 - Closest NTL: 193.0
# Processed row 441 - Closest NTL: 187.0
# Processed row 442 - Closest NTL: 25.0
# Processed row 443 - Closest NTL: 25.0
# Processed row 444 - Closest NTL: 26.0
# Processed row 445 - Closest NTL: 25.0
# Processed row 446 - Closest NTL: 25.0
# Processed row 447 - Closest NTL: 26.0
# Processed row 448 - Closest NTL: 26.0
# Processed row 449 - Closest NTL: 25.0
# Processed row 450 - Closest NTL: 27.0
# Processed row 451 - Closest NTL: 43.0
# Processed row 452 - Closest NTL: 44.0
# Processed row 453 - Closest NTL: 47.0
# Processed row 454 - Closest NTL: 43.0
# Processed row 455 - Closest NTL: 45.0
# Processed row 456 - Closest NTL: 48.0
# Processed row 457 - Closest NTL: 43.0
# Processed row 458 - Closest NTL: 45.0
# Processed row 459 - Closest NTL: 48.0
# Processed row 460 - Closest NTL: 32.0
# Processed row 461 - Closest NTL: 32.0
# Processed row 462 - Closest NTL: 32.0
# Processed row 463 - Closest NTL: 32.0
# Processed row 464 - Closest NTL: 32.0
# Processed row 465 - Closest NTL: 32.0
# Processed row 466 - Closest NTL: 32.0
# Processed row 467 - Closest NTL: 32.0
# Processed row 468 - Closest NTL: 32.0
# Processed row 469 - Closest NTL: 26.0
# Processed row 470 - Closest NTL: 27.0
# Processed row 471 - Closest NTL: 26.0
# Processed row 472 - Closest NTL: 26.0
# Processed row 473 - Closest NTL: 27.0
# Processed row 474 - Closest NTL: 26.0
# Processed row 475 - Closest NTL: 26.0
# Processed row 476 - Closest NTL: 28.0
# Processed row 477 - Closest NTL: 28.0
# Processed row 478 - Closest NTL: 28.0
# Processed row 479 - Closest NTL: 26.0
# Processed row 480 - Closest NTL: 27.0
# Processed row 481 - Closest NTL: 31.0
# Processed row 482 - Closest NTL: 29.0
# Processed row 483 - Closest NTL: 32.0
# Processed row 484 - Closest NTL: 31.0
# Processed row 485 - Closest NTL: 29.0
# Processed row 486 - Closest NTL: 32.0
# Processed row 487 - Closest NTL: 30.0
# Processed row 488 - Closest NTL: 32.0
# Processed row 489 - Closest NTL: 31.0
# Processed row 490 - Closest NTL: 27.0
# Processed row 491 - Closest NTL: 27.0
# Processed row 492 - Closest NTL: 27.0
# Processed row 493 - Closest NTL: 27.0
# Processed row 494 - Closest NTL: 27.0
# Processed row 495 - Closest NTL: 26.0
# Processed row 496 - Closest NTL: 27.0
# Processed row 497 - Closest NTL: 27.0
# Processed row 498 - Closest NTL: 26.0
# Processed row 499 - Closest NTL: 114.0
# Processed row 500 - Closest NTL: 116.0
# Processed row 501 - Closest NTL: 68.0
# Processed row 502 - Closest NTL: 114.0
# Processed row 503 - Closest NTL: 116.0
# Processed row 504 - Closest NTL: 68.0
# Processed row 505 - Closest NTL: 114.0
# Processed row 506 - Closest NTL: 116.0
# Processed row 507 - Closest NTL: 68.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_2.csv
# Number of closest NTLs assigned: 507

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_3.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_3.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_3.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 104.0
# Processed row 2 - Closest NTL: 99.0
# Processed row 3 - Closest NTL: 73.0
# Processed row 4 - Closest NTL: 104.0
# Processed row 5 - Closest NTL: 99.0
# Processed row 6 - Closest NTL: 73.0
# Processed row 7 - Closest NTL: 113.0
# Processed row 8 - Closest NTL: 111.0
# Processed row 9 - Closest NTL: 76.0
# Processed row 10 - Closest NTL: 28.0
# Processed row 11 - Closest NTL: 26.0
# Processed row 12 - Closest NTL: 24.0
# Processed row 13 - Closest NTL: 26.0
# Processed row 14 - Closest NTL: 23.0
# Processed row 15 - Closest NTL: 23.0
# Processed row 16 - Closest NTL: 26.0
# Processed row 17 - Closest NTL: 23.0
# Processed row 18 - Closest NTL: 23.0
# Processed row 19 - Closest NTL: 255.0
# Processed row 20 - Closest NTL: 255.0
# Processed row 21 - Closest NTL: 255.0
# Processed row 22 - Closest NTL: 255.0
# Processed row 23 - Closest NTL: 255.0
# Processed row 24 - Closest NTL: 255.0
# Processed row 25 - Closest NTL: 255.0
# Processed row 26 - Closest NTL: 255.0
# Processed row 27 - Closest NTL: 255.0
# Processed row 28 - Closest NTL: 21.0
# Processed row 29 - Closest NTL: 21.0
# Processed row 30 - Closest NTL: 22.0
# Processed row 31 - Closest NTL: 21.0
# Processed row 32 - Closest NTL: 21.0
# Processed row 33 - Closest NTL: 22.0
# Processed row 34 - Closest NTL: 21.0
# Processed row 35 - Closest NTL: 21.0
# Processed row 36 - Closest NTL: 22.0
# Processed row 37 - Closest NTL: 28.0
# Processed row 38 - Closest NTL: 29.0
# Processed row 39 - Closest NTL: 30.0
# Processed row 40 - Closest NTL: 28.0
# Processed row 41 - Closest NTL: 29.0
# Processed row 42 - Closest NTL: 30.0
# Processed row 43 - Closest NTL: 32.0
# Processed row 44 - Closest NTL: 32.0
# Processed row 45 - Closest NTL: 32.0
# Processed row 46 - Closest NTL: 255.0
# Processed row 47 - Closest NTL: 218.0
# Processed row 48 - Closest NTL: 213.0
# Processed row 49 - Closest NTL: 255.0
# Processed row 50 - Closest NTL: 220.0
# Processed row 51 - Closest NTL: 216.0
# Processed row 52 - Closest NTL: 255.0
# Processed row 53 - Closest NTL: 220.0
# Processed row 54 - Closest NTL: 216.0
# Processed row 55 - Closest NTL: 49.0
# Processed row 56 - Closest NTL: 53.0
# Processed row 57 - Closest NTL: 60.0
# Processed row 58 - Closest NTL: 52.0
# Processed row 59 - Closest NTL: 56.0
# Processed row 60 - Closest NTL: 64.0
# Processed row 61 - Closest NTL: 52.0
# Processed row 62 - Closest NTL: 56.0
# Processed row 63 - Closest NTL: 64.0
# Processed row 64 - Closest NTL: 197.0
# Processed row 65 - Closest NTL: 82.0
# Processed row 66 - Closest NTL: 92.0
# Processed row 67 - Closest NTL: 202.0
# Processed row 68 - Closest NTL: 91.0
# Processed row 69 - Closest NTL: 91.0
# Processed row 70 - Closest NTL: 202.0
# Processed row 71 - Closest NTL: 91.0
# Processed row 72 - Closest NTL: 91.0
# Processed row 73 - Closest NTL: 162.0
# Processed row 74 - Closest NTL: 162.0
# Processed row 75 - Closest NTL: 162.0
# Processed row 76 - Closest NTL: 162.0
# Processed row 77 - Closest NTL: 162.0
# Processed row 78 - Closest NTL: 162.0
# Processed row 79 - Closest NTL: 161.0
# Processed row 80 - Closest NTL: 162.0
# Processed row 81 - Closest NTL: 162.0
# Processed row 82 - Closest NTL: 23.0
# Processed row 83 - Closest NTL: 23.0
# Processed row 84 - Closest NTL: 23.0
# Processed row 85 - Closest NTL: 23.0
# Processed row 86 - Closest NTL: 23.0
# Processed row 87 - Closest NTL: 23.0
# Processed row 88 - Closest NTL: 166.0
# Processed row 89 - Closest NTL: 166.0
# Processed row 90 - Closest NTL: 195.0
# Processed row 91 - Closest NTL: 166.0
# Processed row 92 - Closest NTL: 166.0
# Processed row 93 - Closest NTL: 195.0
# Processed row 94 - Closest NTL: 166.0
# Processed row 95 - Closest NTL: 166.0
# Processed row 96 - Closest NTL: 195.0
# Processed row 97 - Closest NTL: 166.0
# Processed row 98 - Closest NTL: 195.0
# Processed row 99 - Closest NTL: 193.0
# Processed row 100 - Closest NTL: 166.0
# Processed row 101 - Closest NTL: 195.0
# Processed row 102 - Closest NTL: 193.0
# Processed row 103 - Closest NTL: 81.0
# Processed row 104 - Closest NTL: 80.0
# Processed row 105 - Closest NTL: 82.0
# Processed row 106 - Closest NTL: 255.0
# Processed row 107 - Closest NTL: 255.0
# Processed row 108 - Closest NTL: 255.0
# Processed row 109 - Closest NTL: 255.0
# Processed row 110 - Closest NTL: 255.0
# Processed row 111 - Closest NTL: 255.0
# Processed row 112 - Closest NTL: 255.0
# Processed row 113 - Closest NTL: 255.0
# Processed row 114 - Closest NTL: 255.0
# Processed row 115 - Closest NTL: 222.0
# Processed row 116 - Closest NTL: 55.0
# Processed row 117 - Closest NTL: 52.0
# Processed row 118 - Closest NTL: 222.0
# Processed row 119 - Closest NTL: 55.0
# Processed row 120 - Closest NTL: 52.0
# Processed row 121 - Closest NTL: 221.0
# Processed row 122 - Closest NTL: 55.0
# Processed row 123 - Closest NTL: 51.0
# Processed row 124 - Closest NTL: 42.0
# Processed row 125 - Closest NTL: 39.0
# Processed row 126 - Closest NTL: 36.0
# Processed row 127 - Closest NTL: 41.0
# Processed row 128 - Closest NTL: 38.0
# Processed row 129 - Closest NTL: 36.0
# Processed row 130 - Closest NTL: 41.0
# Processed row 131 - Closest NTL: 38.0
# Processed row 132 - Closest NTL: 36.0
# Processed row 133 - Closest NTL: 255.0
# Processed row 134 - Closest NTL: 255.0
# Processed row 135 - Closest NTL: 255.0
# Processed row 136 - Closest NTL: 255.0
# Processed row 137 - Closest NTL: 255.0
# Processed row 138 - Closest NTL: 255.0
# Processed row 139 - Closest NTL: 255.0
# Processed row 140 - Closest NTL: 255.0
# Processed row 141 - Closest NTL: 255.0
# Processed row 142 - Closest NTL: 35.0
# Processed row 143 - Closest NTL: 35.0
# Processed row 144 - Closest NTL: 37.0
# Processed row 145 - Closest NTL: 35.0
# Processed row 146 - Closest NTL: 35.0
# Processed row 147 - Closest NTL: 37.0
# Processed row 148 - Closest NTL: 33.0
# Processed row 149 - Closest NTL: 36.0
# Processed row 150 - Closest NTL: 39.0
# Processed row 151 - Closest NTL: 255.0
# Processed row 152 - Closest NTL: 255.0
# Processed row 153 - Closest NTL: 255.0
# Processed row 154 - Closest NTL: 255.0
# Processed row 155 - Closest NTL: 255.0
# Processed row 156 - Closest NTL: 255.0
# Processed row 157 - Closest NTL: 255.0
# Processed row 158 - Closest NTL: 255.0
# Processed row 159 - Closest NTL: 255.0
# Processed row 160 - Closest NTL: 255.0
# Processed row 161 - Closest NTL: 255.0
# Processed row 162 - Closest NTL: 103.0
# Processed row 163 - Closest NTL: 178.0
# Processed row 164 - Closest NTL: 177.0
# Processed row 165 - Closest NTL: 70.0
# Processed row 166 - Closest NTL: 178.0
# Processed row 167 - Closest NTL: 177.0
# Processed row 168 - Closest NTL: 70.0
# Processed row 169 - Closest NTL: 255.0
# Processed row 170 - Closest NTL: 255.0
# Processed row 171 - Closest NTL: 80.0
# Processed row 172 - Closest NTL: 255.0
# Processed row 173 - Closest NTL: 255.0
# Processed row 174 - Closest NTL: 82.0
# Processed row 175 - Closest NTL: 255.0
# Processed row 176 - Closest NTL: 255.0
# Processed row 177 - Closest NTL: 82.0
# Processed row 178 - Closest NTL: 45.0
# Processed row 179 - Closest NTL: 45.0
# Processed row 180 - Closest NTL: 45.0
# Processed row 181 - Closest NTL: 45.0
# Processed row 182 - Closest NTL: 45.0
# Processed row 183 - Closest NTL: 45.0
# Processed row 184 - Closest NTL: 38.0
# Processed row 185 - Closest NTL: 37.0
# Processed row 186 - Closest NTL: 39.0
# Processed row 187 - Closest NTL: 21.0
# Processed row 188 - Closest NTL: 22.0
# Processed row 189 - Closest NTL: 22.0
# Processed row 190 - Closest NTL: 21.0
# Processed row 191 - Closest NTL: 22.0
# Processed row 192 - Closest NTL: 22.0
# Processed row 193 - Closest NTL: 21.0
# Processed row 194 - Closest NTL: 22.0
# Processed row 195 - Closest NTL: 22.0
# Processed row 196 - Closest NTL: 24.0
# Processed row 197 - Closest NTL: 24.0
# Processed row 198 - Closest NTL: 24.0
# Processed row 199 - Closest NTL: 24.0
# Processed row 200 - Closest NTL: 24.0
# Processed row 201 - Closest NTL: 24.0
# Processed row 202 - Closest NTL: 24.0
# Processed row 203 - Closest NTL: 24.0
# Processed row 204 - Closest NTL: 24.0
# Processed row 205 - Closest NTL: 83.0
# Processed row 206 - Closest NTL: 82.0
# Processed row 207 - Closest NTL: 82.0
# Processed row 208 - Closest NTL: 83.0
# Processed row 209 - Closest NTL: 82.0
# Processed row 210 - Closest NTL: 82.0
# Processed row 211 - Closest NTL: 83.0
# Processed row 212 - Closest NTL: 83.0
# Processed row 213 - Closest NTL: 83.0
# Processed row 214 - Closest NTL: 196.0
# Processed row 215 - Closest NTL: 187.0
# Processed row 216 - Closest NTL: 188.0
# Processed row 217 - Closest NTL: 255.0
# Processed row 218 - Closest NTL: 32.0
# Processed row 219 - Closest NTL: 33.0
# Processed row 220 - Closest NTL: 255.0
# Processed row 221 - Closest NTL: 32.0
# Processed row 222 - Closest NTL: 33.0
# Processed row 223 - Closest NTL: 154.0
# Processed row 224 - Closest NTL: 153.0
# Processed row 225 - Closest NTL: 69.0
# Processed row 226 - Closest NTL: 178.0
# Processed row 227 - Closest NTL: 176.0
# Processed row 228 - Closest NTL: 88.0
# Processed row 229 - Closest NTL: 177.0
# Processed row 230 - Closest NTL: 176.0
# Processed row 231 - Closest NTL: 87.0
# Processed row 232 - Closest NTL: 23.0
# Processed row 233 - Closest NTL: 25.0
# Processed row 234 - Closest NTL: 25.0
# Processed row 235 - Closest NTL: 23.0
# Processed row 236 - Closest NTL: 25.0
# Processed row 237 - Closest NTL: 25.0
# Processed row 238 - Closest NTL: 21.0
# Processed row 239 - Closest NTL: 25.0
# Processed row 240 - Closest NTL: 26.0
# Processed row 241 - Closest NTL: 255.0
# Processed row 242 - Closest NTL: 184.0
# Processed row 243 - Closest NTL: 183.0
# Processed row 244 - Closest NTL: 255.0
# Processed row 245 - Closest NTL: 255.0
# Processed row 246 - Closest NTL: 255.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_3.csv
# Number of closest NTLs assigned: 246

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_4.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_4.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_4.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 255.0
# Processed row 2 - Closest NTL: 255.0
# Processed row 3 - Closest NTL: 37.0
# Processed row 4 - Closest NTL: 255.0
# Processed row 5 - Closest NTL: 255.0
# Processed row 6 - Closest NTL: 37.0
# Processed row 7 - Closest NTL: 255.0
# Processed row 8 - Closest NTL: 255.0
# Processed row 9 - Closest NTL: 35.0
# Processed row 10 - Closest NTL: 255.0
# Processed row 11 - Closest NTL: 255.0
# Processed row 12 - Closest NTL: 124.0
# Processed row 13 - Closest NTL: 181.0
# Processed row 14 - Closest NTL: 179.0
# Processed row 15 - Closest NTL: 98.0
# Processed row 16 - Closest NTL: 178.0
# Processed row 17 - Closest NTL: 178.0
# Processed row 18 - Closest NTL: 97.0
# Processed row 19 - Closest NTL: 21.0
# Processed row 20 - Closest NTL: 21.0
# Processed row 21 - Closest NTL: 23.0
# Processed row 22 - Closest NTL: 21.0
# Processed row 23 - Closest NTL: 21.0
# Processed row 24 - Closest NTL: 23.0
# Processed row 25 - Closest NTL: 21.0
# Processed row 26 - Closest NTL: 21.0
# Processed row 27 - Closest NTL: 23.0
# Processed row 28 - Closest NTL: 248.0
# Processed row 29 - Closest NTL: 247.0
# Processed row 30 - Closest NTL: 50.0
# Processed row 31 - Closest NTL: 151.0
# Processed row 32 - Closest NTL: 150.0
# Processed row 33 - Closest NTL: 50.0
# Processed row 34 - Closest NTL: 151.0
# Processed row 35 - Closest NTL: 150.0
# Processed row 36 - Closest NTL: 50.0
# Processed row 37 - Closest NTL: 26.0
# Processed row 38 - Closest NTL: 27.0
# Processed row 39 - Closest NTL: 29.0
# Processed row 40 - Closest NTL: 69.0
# Processed row 41 - Closest NTL: 69.0
# Processed row 42 - Closest NTL: 31.0
# Processed row 43 - Closest NTL: 69.0
# Processed row 44 - Closest NTL: 69.0
# Processed row 45 - Closest NTL: 31.0
# Processed row 46 - Closest NTL: 18.0
# Processed row 47 - Closest NTL: 18.0
# Processed row 48 - Closest NTL: 19.0
# Processed row 49 - Closest NTL: 18.0
# Processed row 50 - Closest NTL: 17.0
# Processed row 51 - Closest NTL: 18.0
# Processed row 52 - Closest NTL: 18.0
# Processed row 53 - Closest NTL: 17.0
# Processed row 54 - Closest NTL: 18.0
# Processed row 55 - Closest NTL: 29.0
# Processed row 56 - Closest NTL: 29.0
# Processed row 57 - Closest NTL: 28.0
# Processed row 58 - Closest NTL: 29.0
# Processed row 59 - Closest NTL: 29.0
# Processed row 60 - Closest NTL: 28.0
# Processed row 61 - Closest NTL: 30.0
# Processed row 62 - Closest NTL: 30.0
# Processed row 63 - Closest NTL: 29.0
# Processed row 64 - Closest NTL: 26.0
# Processed row 65 - Closest NTL: 26.0
# Processed row 66 - Closest NTL: 25.0
# Processed row 67 - Closest NTL: 24.0
# Processed row 68 - Closest NTL: 24.0
# Processed row 69 - Closest NTL: 23.0
# Processed row 70 - Closest NTL: 24.0
# Processed row 71 - Closest NTL: 24.0
# Processed row 72 - Closest NTL: 23.0
# Processed row 73 - Closest NTL: 115.0
# Processed row 74 - Closest NTL: 113.0
# Processed row 75 - Closest NTL: 23.0
# Processed row 76 - Closest NTL: 115.0
# Processed row 77 - Closest NTL: 113.0
# Processed row 78 - Closest NTL: 23.0
# Processed row 79 - Closest NTL: 112.0
# Processed row 80 - Closest NTL: 113.0
# Processed row 81 - Closest NTL: 23.0
# Processed row 82 - Closest NTL: 29.0
# Processed row 83 - Closest NTL: 28.0
# Processed row 84 - Closest NTL: 29.0
# Processed row 85 - Closest NTL: 29.0
# Processed row 86 - Closest NTL: 28.0
# Processed row 87 - Closest NTL: 29.0
# Processed row 88 - Closest NTL: 29.0
# Processed row 89 - Closest NTL: 28.0
# Processed row 90 - Closest NTL: 29.0
# Processed row 91 - Closest NTL: 132.0
# Processed row 92 - Closest NTL: 64.0
# Processed row 93 - Closest NTL: 63.0
# Processed row 94 - Closest NTL: 132.0
# Processed row 95 - Closest NTL: 64.0
# Processed row 96 - Closest NTL: 63.0
# Processed row 97 - Closest NTL: 127.0
# Processed row 98 - Closest NTL: 61.0
# Processed row 99 - Closest NTL: 59.0
# Processed row 100 - Closest NTL: 63.0
# Processed row 101 - Closest NTL: 66.0
# Processed row 102 - Closest NTL: 64.0
# Processed row 103 - Closest NTL: 63.0
# Processed row 104 - Closest NTL: 66.0
# Processed row 105 - Closest NTL: 64.0
# Processed row 106 - Closest NTL: 67.0
# Processed row 107 - Closest NTL: 69.0
# Processed row 108 - Closest NTL: 72.0
# Processed row 109 - Closest NTL: 27.0
# Processed row 110 - Closest NTL: 27.0
# Processed row 111 - Closest NTL: 25.0
# Processed row 112 - Closest NTL: 255.0
# Processed row 113 - Closest NTL: 153.0
# Processed row 114 - Closest NTL: 157.0
# Processed row 115 - Closest NTL: 255.0
# Processed row 116 - Closest NTL: 153.0
# Processed row 117 - Closest NTL: 157.0
# Processed row 118 - Closest NTL: 255.0
# Processed row 119 - Closest NTL: 153.0
# Processed row 120 - Closest NTL: 157.0
# Processed row 121 - Closest NTL: 24.0
# Processed row 122 - Closest NTL: 23.0
# Processed row 123 - Closest NTL: 24.0
# Processed row 124 - Closest NTL: 24.0
# Processed row 125 - Closest NTL: 23.0
# Processed row 126 - Closest NTL: 24.0
# Processed row 127 - Closest NTL: 24.0
# Processed row 128 - Closest NTL: 23.0
# Processed row 129 - Closest NTL: 24.0
# Processed row 130 - Closest NTL: 186.0
# Processed row 131 - Closest NTL: 186.0
# Processed row 132 - Closest NTL: 118.0
# Processed row 133 - Closest NTL: 186.0
# Processed row 134 - Closest NTL: 186.0
# Processed row 135 - Closest NTL: 118.0
# Processed row 136 - Closest NTL: 186.0
# Processed row 137 - Closest NTL: 186.0
# Processed row 138 - Closest NTL: 118.0
# Processed row 139 - Closest NTL: 24.0
# Processed row 140 - Closest NTL: 21.0
# Processed row 141 - Closest NTL: 21.0
# Processed row 142 - Closest NTL: 24.0
# Processed row 143 - Closest NTL: 21.0
# Processed row 144 - Closest NTL: 21.0
# Processed row 145 - Closest NTL: 21.0
# Processed row 146 - Closest NTL: 21.0
# Processed row 147 - Closest NTL: 21.0
# Processed row 148 - Closest NTL: 157.0
# Processed row 149 - Closest NTL: 155.0
# Processed row 150 - Closest NTL: 41.0
# Processed row 151 - Closest NTL: 157.0
# Processed row 152 - Closest NTL: 155.0
# Processed row 153 - Closest NTL: 41.0
# Processed row 154 - Closest NTL: 44.0
# Processed row 155 - Closest NTL: 47.0
# Processed row 156 - Closest NTL: 36.0
# Processed row 157 - Closest NTL: 255.0
# Processed row 158 - Closest NTL: 255.0
# Processed row 159 - Closest NTL: 77.0
# Processed row 160 - Closest NTL: 255.0
# Processed row 161 - Closest NTL: 255.0
# Processed row 162 - Closest NTL: 77.0
# Processed row 163 - Closest NTL: 107.0
# Processed row 164 - Closest NTL: 103.0
# Processed row 165 - Closest NTL: 77.0
# Processed row 166 - Closest NTL: 27.0
# Processed row 167 - Closest NTL: 26.0
# Processed row 168 - Closest NTL: 26.0
# Processed row 169 - Closest NTL: 28.0
# Processed row 170 - Closest NTL: 27.0
# Processed row 171 - Closest NTL: 28.0
# Processed row 172 - Closest NTL: 28.0
# Processed row 173 - Closest NTL: 27.0
# Processed row 174 - Closest NTL: 28.0
# Processed row 175 - Closest NTL: 255.0
# Processed row 176 - Closest NTL: 255.0
# Processed row 177 - Closest NTL: 255.0
# Processed row 178 - Closest NTL: 255.0
# Processed row 179 - Closest NTL: 255.0
# Processed row 180 - Closest NTL: 255.0
# Processed row 181 - Closest NTL: 255.0
# Processed row 182 - Closest NTL: 255.0
# Processed row 183 - Closest NTL: 255.0
# Processed row 184 - Closest NTL: 26.0
# Processed row 185 - Closest NTL: 26.0
# Processed row 186 - Closest NTL: 26.0
# Processed row 187 - Closest NTL: 26.0
# Processed row 188 - Closest NTL: 26.0
# Processed row 189 - Closest NTL: 26.0
# Processed row 190 - Closest NTL: 25.0
# Processed row 191 - Closest NTL: 26.0
# Processed row 192 - Closest NTL: 27.0
# Processed row 193 - Closest NTL: 27.0
# Processed row 194 - Closest NTL: 26.0
# Processed row 195 - Closest NTL: 25.0
# Processed row 196 - Closest NTL: 27.0
# Processed row 197 - Closest NTL: 26.0
# Processed row 198 - Closest NTL: 25.0
# Processed row 199 - Closest NTL: 26.0
# Processed row 200 - Closest NTL: 27.0
# Processed row 201 - Closest NTL: 26.0
# Processed row 202 - Closest NTL: 172.0
# Processed row 203 - Closest NTL: 48.0
# Processed row 204 - Closest NTL: 47.0
# Processed row 205 - Closest NTL: 108.0
# Processed row 206 - Closest NTL: 38.0
# Processed row 207 - Closest NTL: 38.0
# Processed row 208 - Closest NTL: 108.0
# Processed row 209 - Closest NTL: 38.0
# Processed row 210 - Closest NTL: 38.0
# Processed row 211 - Closest NTL: 25.0
# Processed row 212 - Closest NTL: 25.0
# Processed row 213 - Closest NTL: 26.0
# Processed row 214 - Closest NTL: 25.0
# Processed row 215 - Closest NTL: 25.0
# Processed row 216 - Closest NTL: 26.0
# Processed row 217 - Closest NTL: 24.0
# Processed row 218 - Closest NTL: 23.0
# Processed row 219 - Closest NTL: 23.0
# Processed row 220 - Closest NTL: 172.0
# Processed row 221 - Closest NTL: 103.0
# Processed row 222 - Closest NTL: 99.0
# Processed row 223 - Closest NTL: 146.0
# Processed row 224 - Closest NTL: 129.0
# Processed row 225 - Closest NTL: 124.0
# Processed row 226 - Closest NTL: 143.0
# Processed row 227 - Closest NTL: 125.0
# Processed row 228 - Closest NTL: 121.0
# Processed row 229 - Closest NTL: 181.0
# Processed row 230 - Closest NTL: 92.0
# Processed row 231 - Closest NTL: 89.0
# Processed row 232 - Closest NTL: 126.0
# Processed row 233 - Closest NTL: 91.0
# Processed row 234 - Closest NTL: 87.0
# Processed row 235 - Closest NTL: 126.0
# Processed row 236 - Closest NTL: 91.0
# Processed row 237 - Closest NTL: 87.0
# Processed row 238 - Closest NTL: 24.0
# Processed row 239 - Closest NTL: 23.0
# Processed row 240 - Closest NTL: 22.0
# Processed row 241 - Closest NTL: 23.0
# Processed row 242 - Closest NTL: 24.0
# Processed row 243 - Closest NTL: 24.0
# Processed row 244 - Closest NTL: 23.0
# Processed row 245 - Closest NTL: 24.0
# Processed row 246 - Closest NTL: 24.0
# Processed row 247 - Closest NTL: 230.0
# Processed row 248 - Closest NTL: 229.0
# Processed row 249 - Closest NTL: 219.0
# Processed row 250 - Closest NTL: 230.0
# Processed row 251 - Closest NTL: 229.0
# Processed row 252 - Closest NTL: 219.0
# Processed row 253 - Closest NTL: 228.0
# Processed row 254 - Closest NTL: 230.0
# Processed row 255 - Closest NTL: 218.0
# Processed row 256 - Closest NTL: 177.0
# Processed row 257 - Closest NTL: 177.0
# Processed row 258 - Closest NTL: 32.0
# Processed row 259 - Closest NTL: 177.0
# Processed row 260 - Closest NTL: 177.0
# Processed row 261 - Closest NTL: 32.0
# Processed row 262 - Closest NTL: 176.0
# Processed row 263 - Closest NTL: 176.0
# Processed row 264 - Closest NTL: 33.0
# Processed row 265 - Closest NTL: 23.0
# Processed row 266 - Closest NTL: 20.0
# Processed row 267 - Closest NTL: 18.0
# Processed row 268 - Closest NTL: 23.0
# Processed row 269 - Closest NTL: 20.0
# Processed row 270 - Closest NTL: 18.0
# Processed row 271 - Closest NTL: 22.0
# Processed row 272 - Closest NTL: 19.0
# Processed row 273 - Closest NTL: 19.0
# Processed row 274 - Closest NTL: 255.0
# Processed row 275 - Closest NTL: 255.0
# Processed row 276 - Closest NTL: 73.0
# Processed row 277 - Closest NTL: 101.0
# Processed row 278 - Closest NTL: 98.0
# Processed row 279 - Closest NTL: 72.0
# Processed row 280 - Closest NTL: 101.0
# Processed row 281 - Closest NTL: 98.0
# Processed row 282 - Closest NTL: 72.0
# Processed row 283 - Closest NTL: 24.0
# Processed row 284 - Closest NTL: 23.0
# Processed row 285 - Closest NTL: 23.0
# Processed row 286 - Closest NTL: 24.0
# Processed row 287 - Closest NTL: 24.0
# Processed row 288 - Closest NTL: 23.0
# Processed row 289 - Closest NTL: 24.0
# Processed row 290 - Closest NTL: 24.0
# Processed row 291 - Closest NTL: 23.0
# Processed row 292 - Closest NTL: 25.0
# Processed row 293 - Closest NTL: 25.0
# Processed row 294 - Closest NTL: 24.0
# Processed row 295 - Closest NTL: 25.0
# Processed row 296 - Closest NTL: 25.0
# Processed row 297 - Closest NTL: 24.0
# Processed row 298 - Closest NTL: 23.0
# Processed row 299 - Closest NTL: 23.0
# Processed row 300 - Closest NTL: 21.0
# Processed row 301 - Closest NTL: 125.0
# Processed row 302 - Closest NTL: 124.0
# Processed row 303 - Closest NTL: 53.0
# Processed row 304 - Closest NTL: 124.0
# Processed row 305 - Closest NTL: 124.0
# Processed row 306 - Closest NTL: 56.0
# Processed row 307 - Closest NTL: 61.0
# Processed row 308 - Closest NTL: 57.0
# Processed row 309 - Closest NTL: 57.0
# Processed row 310 - Closest NTL: 141.0
# Processed row 311 - Closest NTL: 140.0
# Processed row 312 - Closest NTL: 140.0
# Processed row 313 - Closest NTL: 94.0
# Processed row 314 - Closest NTL: 91.0
# Processed row 315 - Closest NTL: 91.0
# Processed row 316 - Closest NTL: 94.0
# Processed row 317 - Closest NTL: 91.0
# Processed row 318 - Closest NTL: 91.0
# Processed row 319 - Closest NTL: 255.0
# Processed row 320 - Closest NTL: 255.0
# Processed row 321 - Closest NTL: 141.0
# Processed row 322 - Closest NTL: 255.0
# Processed row 323 - Closest NTL: 255.0
# Processed row 324 - Closest NTL: 141.0
# Processed row 325 - Closest NTL: 255.0
# Processed row 326 - Closest NTL: 255.0
# Processed row 327 - Closest NTL: 141.0
# Processed row 328 - Closest NTL: 168.0
# Processed row 329 - Closest NTL: 255.0
# Processed row 330 - Closest NTL: 255.0
# Processed row 331 - Closest NTL: 168.0
# Processed row 332 - Closest NTL: 255.0
# Processed row 333 - Closest NTL: 255.0
# Processed row 334 - Closest NTL: 203.0
# Processed row 335 - Closest NTL: 230.0
# Processed row 336 - Closest NTL: 229.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_4.csv
# Number of closest NTLs assigned: 336

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_5.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_5.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_5.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 40.0
# Processed row 2 - Closest NTL: 37.0
# Processed row 3 - Closest NTL: 37.0
# Processed row 4 - Closest NTL: 40.0
# Processed row 5 - Closest NTL: 38.0
# Processed row 6 - Closest NTL: 38.0
# Processed row 7 - Closest NTL: 40.0
# Processed row 8 - Closest NTL: 38.0
# Processed row 9 - Closest NTL: 38.0
# Processed row 10 - Closest NTL: 53.0
# Processed row 11 - Closest NTL: 52.0
# Processed row 12 - Closest NTL: 48.0
# Processed row 13 - Closest NTL: 53.0
# Processed row 14 - Closest NTL: 52.0
# Processed row 15 - Closest NTL: 48.0
# Processed row 16 - Closest NTL: 52.0
# Processed row 17 - Closest NTL: 51.0
# Processed row 18 - Closest NTL: 45.0
# Processed row 19 - Closest NTL: 144.0
# Processed row 20 - Closest NTL: 144.0
# Processed row 21 - Closest NTL: 255.0
# Processed row 22 - Closest NTL: 144.0
# Processed row 23 - Closest NTL: 144.0
# Processed row 24 - Closest NTL: 255.0
# Processed row 25 - Closest NTL: 143.0
# Processed row 26 - Closest NTL: 143.0
# Processed row 27 - Closest NTL: 255.0
# Processed row 28 - Closest NTL: 38.0
# Processed row 29 - Closest NTL: 37.0
# Processed row 30 - Closest NTL: 36.0
# Processed row 31 - Closest NTL: 39.0
# Processed row 32 - Closest NTL: 39.0
# Processed row 33 - Closest NTL: 40.0
# Processed row 34 - Closest NTL: 37.0
# Processed row 35 - Closest NTL: 38.0
# Processed row 36 - Closest NTL: 39.0
# Processed row 37 - Closest NTL: 255.0
# Processed row 38 - Closest NTL: 255.0
# Processed row 39 - Closest NTL: 255.0
# Processed row 40 - Closest NTL: 132.0
# Processed row 41 - Closest NTL: 130.0
# Processed row 42 - Closest NTL: 132.0
# Processed row 43 - Closest NTL: 132.0
# Processed row 44 - Closest NTL: 130.0
# Processed row 45 - Closest NTL: 132.0
# Processed row 46 - Closest NTL: 20.0
# Processed row 47 - Closest NTL: 20.0
# Processed row 48 - Closest NTL: 20.0
# Processed row 49 - Closest NTL: 19.0
# Processed row 50 - Closest NTL: 20.0
# Processed row 51 - Closest NTL: 20.0
# Processed row 52 - Closest NTL: 18.0
# Processed row 53 - Closest NTL: 21.0
# Processed row 54 - Closest NTL: 21.0
# Processed row 55 - Closest NTL: 19.0
# Processed row 56 - Closest NTL: 18.0
# Processed row 57 - Closest NTL: 19.0
# Processed row 58 - Closest NTL: 19.0
# Processed row 59 - Closest NTL: 17.0
# Processed row 60 - Closest NTL: 16.0
# Processed row 61 - Closest NTL: 19.0
# Processed row 62 - Closest NTL: 17.0
# Processed row 63 - Closest NTL: 16.0
# Processed row 64 - Closest NTL: 19.0
# Processed row 65 - Closest NTL: 19.0
# Processed row 66 - Closest NTL: 19.0
# Processed row 67 - Closest NTL: 19.0
# Processed row 68 - Closest NTL: 19.0
# Processed row 69 - Closest NTL: 19.0
# Processed row 70 - Closest NTL: 18.0
# Processed row 71 - Closest NTL: 18.0
# Processed row 72 - Closest NTL: 18.0
# Processed row 73 - Closest NTL: 21.0
# Processed row 74 - Closest NTL: 21.0
# Processed row 75 - Closest NTL: 19.0
# Processed row 76 - Closest NTL: 20.0
# Processed row 77 - Closest NTL: 20.0
# Processed row 78 - Closest NTL: 19.0
# Processed row 79 - Closest NTL: 20.0
# Processed row 80 - Closest NTL: 20.0
# Processed row 81 - Closest NTL: 19.0
# Processed row 82 - Closest NTL: 68.0
# Processed row 83 - Closest NTL: 67.0
# Processed row 84 - Closest NTL: 55.0
# Processed row 85 - Closest NTL: 43.0
# Processed row 86 - Closest NTL: 41.0
# Processed row 87 - Closest NTL: 41.0
# Processed row 88 - Closest NTL: 40.0
# Processed row 89 - Closest NTL: 41.0
# Processed row 90 - Closest NTL: 40.0
# Processed row 91 - Closest NTL: 28.0
# Processed row 92 - Closest NTL: 24.0
# Processed row 93 - Closest NTL: 23.0
# Processed row 94 - Closest NTL: 28.0
# Processed row 95 - Closest NTL: 24.0
# Processed row 96 - Closest NTL: 23.0
# Processed row 97 - Closest NTL: 20.0
# Processed row 98 - Closest NTL: 21.0
# Processed row 99 - Closest NTL: 23.0
# Processed row 100 - Closest NTL: 33.0
# Processed row 101 - Closest NTL: 27.0
# Processed row 102 - Closest NTL: 24.0
# Processed row 103 - Closest NTL: 31.0
# Processed row 104 - Closest NTL: 30.0
# Processed row 105 - Closest NTL: 24.0
# Processed row 106 - Closest NTL: 31.0
# Processed row 107 - Closest NTL: 30.0
# Processed row 108 - Closest NTL: 24.0
# Processed row 109 - Closest NTL: 255.0
# Processed row 110 - Closest NTL: 191.0
# Processed row 111 - Closest NTL: 187.0
# Processed row 112 - Closest NTL: 121.0
# Processed row 113 - Closest NTL: 93.0
# Processed row 114 - Closest NTL: 91.0
# Processed row 115 - Closest NTL: 121.0
# Processed row 116 - Closest NTL: 93.0
# Processed row 117 - Closest NTL: 91.0
# Processed row 118 - Closest NTL: 200.0
# Processed row 119 - Closest NTL: 57.0
# Processed row 120 - Closest NTL: 57.0
# Processed row 121 - Closest NTL: 200.0
# Processed row 122 - Closest NTL: 57.0
# Processed row 123 - Closest NTL: 57.0
# Processed row 124 - Closest NTL: 199.0
# Processed row 125 - Closest NTL: 57.0
# Processed row 126 - Closest NTL: 57.0
# Processed row 127 - Closest NTL: 28.0
# Processed row 128 - Closest NTL: 27.0
# Processed row 129 - Closest NTL: 27.0
# Processed row 130 - Closest NTL: 26.0
# Processed row 131 - Closest NTL: 26.0
# Processed row 132 - Closest NTL: 25.0
# Processed row 133 - Closest NTL: 26.0
# Processed row 134 - Closest NTL: 26.0
# Processed row 135 - Closest NTL: 25.0
# Processed row 136 - Closest NTL: 204.0
# Processed row 137 - Closest NTL: 208.0
# Processed row 138 - Closest NTL: 224.0
# Processed row 139 - Closest NTL: 204.0
# Processed row 140 - Closest NTL: 208.0
# Processed row 141 - Closest NTL: 224.0
# Processed row 142 - Closest NTL: 200.0
# Processed row 143 - Closest NTL: 206.0
# Processed row 144 - Closest NTL: 223.0
# Processed row 145 - Closest NTL: 126.0
# Processed row 146 - Closest NTL: 41.0
# Processed row 147 - Closest NTL: 41.0
# Processed row 148 - Closest NTL: 75.0
# Processed row 149 - Closest NTL: 23.0
# Processed row 150 - Closest NTL: 23.0
# Processed row 151 - Closest NTL: 75.0
# Processed row 152 - Closest NTL: 23.0
# Processed row 153 - Closest NTL: 23.0
# Processed row 154 - Closest NTL: 30.0
# Processed row 155 - Closest NTL: 25.0
# Processed row 156 - Closest NTL: 23.0
# Processed row 157 - Closest NTL: 27.0
# Processed row 158 - Closest NTL: 25.0
# Processed row 159 - Closest NTL: 24.0
# Processed row 160 - Closest NTL: 25.0
# Processed row 161 - Closest NTL: 25.0
# Processed row 162 - Closest NTL: 24.0
# Processed row 163 - Closest NTL: 21.0
# Processed row 164 - Closest NTL: 20.0
# Processed row 165 - Closest NTL: 20.0
# Processed row 166 - Closest NTL: 21.0
# Processed row 167 - Closest NTL: 20.0
# Processed row 168 - Closest NTL: 20.0
# Processed row 169 - Closest NTL: 21.0
# Processed row 170 - Closest NTL: 20.0
# Processed row 171 - Closest NTL: 20.0
# Processed row 172 - Closest NTL: 255.0
# Processed row 173 - Closest NTL: 255.0
# Processed row 174 - Closest NTL: 255.0
# Processed row 175 - Closest NTL: 255.0
# Processed row 176 - Closest NTL: 255.0
# Processed row 177 - Closest NTL: 255.0
# Processed row 178 - Closest NTL: 255.0
# Processed row 179 - Closest NTL: 255.0
# Processed row 180 - Closest NTL: 255.0
# Processed row 181 - Closest NTL: 255.0
# Processed row 182 - Closest NTL: 190.0
# Processed row 183 - Closest NTL: 185.0
# Processed row 184 - Closest NTL: 163.0
# Processed row 185 - Closest NTL: 159.0
# Processed row 186 - Closest NTL: 158.0
# Processed row 187 - Closest NTL: 163.0
# Processed row 188 - Closest NTL: 159.0
# Processed row 189 - Closest NTL: 158.0
# Processed row 190 - Closest NTL: 185.0
# Processed row 191 - Closest NTL: 185.0
# Processed row 192 - Closest NTL: 180.0
# Processed row 193 - Closest NTL: 185.0
# Processed row 194 - Closest NTL: 185.0
# Processed row 195 - Closest NTL: 180.0
# Processed row 196 - Closest NTL: 185.0
# Processed row 197 - Closest NTL: 185.0
# Processed row 198 - Closest NTL: 180.0
# Processed row 199 - Closest NTL: 122.0
# Processed row 200 - Closest NTL: 161.0
# Processed row 201 - Closest NTL: 160.0
# Processed row 202 - Closest NTL: 123.0
# Processed row 203 - Closest NTL: 159.0
# Processed row 204 - Closest NTL: 158.0
# Processed row 205 - Closest NTL: 123.0
# Processed row 206 - Closest NTL: 159.0
# Processed row 207 - Closest NTL: 158.0
# Processed row 208 - Closest NTL: 51.0
# Processed row 209 - Closest NTL: 49.0
# Processed row 210 - Closest NTL: 49.0
# Processed row 211 - Closest NTL: 183.0
# Processed row 212 - Closest NTL: 184.0
# Processed row 213 - Closest NTL: 47.0
# Processed row 214 - Closest NTL: 183.0
# Processed row 215 - Closest NTL: 184.0
# Processed row 216 - Closest NTL: 47.0
# Processed row 217 - Closest NTL: 43.0
# Processed row 218 - Closest NTL: 255.0
# Processed row 219 - Closest NTL: 255.0
# Processed row 220 - Closest NTL: 47.0
# Processed row 221 - Closest NTL: 255.0
# Processed row 222 - Closest NTL: 255.0
# Processed row 223 - Closest NTL: 50.0
# Processed row 224 - Closest NTL: 47.0
# Processed row 225 - Closest NTL: 45.0
# Processed row 226 - Closest NTL: 255.0
# Processed row 227 - Closest NTL: 255.0
# Processed row 228 - Closest NTL: 255.0
# Processed row 229 - Closest NTL: 255.0
# Processed row 230 - Closest NTL: 255.0
# Processed row 231 - Closest NTL: 255.0
# Processed row 232 - Closest NTL: 255.0
# Processed row 233 - Closest NTL: 255.0
# Processed row 234 - Closest NTL: 200.0
# Processed row 235 - Closest NTL: 255.0
# Processed row 236 - Closest NTL: 255.0
# Processed row 237 - Closest NTL: 255.0
# Processed row 238 - Closest NTL: 255.0
# Processed row 239 - Closest NTL: 255.0
# Processed row 240 - Closest NTL: 255.0
# Processed row 241 - Closest NTL: 255.0
# Processed row 242 - Closest NTL: 255.0
# Processed row 243 - Closest NTL: 255.0
# Processed row 244 - Closest NTL: 255.0
# Processed row 245 - Closest NTL: 255.0
# Processed row 246 - Closest NTL: 255.0
# Processed row 247 - Closest NTL: 255.0
# Processed row 248 - Closest NTL: 255.0
# Processed row 249 - Closest NTL: 255.0
# Processed row 250 - Closest NTL: 255.0
# Processed row 251 - Closest NTL: 255.0
# Processed row 252 - Closest NTL: 255.0
# Processed row 253 - Closest NTL: 23.0
# Processed row 254 - Closest NTL: 23.0
# Processed row 255 - Closest NTL: 24.0
# Processed row 256 - Closest NTL: 23.0
# Processed row 257 - Closest NTL: 23.0
# Processed row 258 - Closest NTL: 23.0
# Processed row 259 - Closest NTL: 23.0
# Processed row 260 - Closest NTL: 23.0
# Processed row 261 - Closest NTL: 23.0
# Processed row 262 - Closest NTL: 58.0
# Processed row 263 - Closest NTL: 60.0
# Processed row 264 - Closest NTL: 63.0
# Processed row 265 - Closest NTL: 58.0
# Processed row 266 - Closest NTL: 60.0
# Processed row 267 - Closest NTL: 64.0
# Processed row 268 - Closest NTL: 58.0
# Processed row 269 - Closest NTL: 60.0
# Processed row 270 - Closest NTL: 64.0
# Processed row 271 - Closest NTL: 29.0
# Processed row 272 - Closest NTL: 27.0
# Processed row 273 - Closest NTL: 26.0
# Processed row 274 - Closest NTL: 27.0
# Processed row 275 - Closest NTL: 26.0
# Processed row 276 - Closest NTL: 26.0
# Processed row 277 - Closest NTL: 27.0
# Processed row 278 - Closest NTL: 26.0
# Processed row 279 - Closest NTL: 26.0
# Processed row 280 - Closest NTL: 23.0
# Processed row 281 - Closest NTL: 24.0
# Processed row 282 - Closest NTL: 26.0
# Processed row 283 - Closest NTL: 23.0
# Processed row 284 - Closest NTL: 24.0
# Processed row 285 - Closest NTL: 26.0
# Processed row 286 - Closest NTL: 25.0
# Processed row 287 - Closest NTL: 25.0
# Processed row 288 - Closest NTL: 26.0
# Processed row 289 - Closest NTL: 29.0
# Processed row 290 - Closest NTL: 28.0
# Processed row 291 - Closest NTL: 26.0
# Processed row 292 - Closest NTL: 23.0
# Processed row 293 - Closest NTL: 26.0
# Processed row 294 - Closest NTL: 27.0
# Processed row 295 - Closest NTL: 23.0
# Processed row 296 - Closest NTL: 26.0
# Processed row 297 - Closest NTL: 27.0
# Processed row 298 - Closest NTL: 255.0
# Processed row 299 - Closest NTL: 255.0
# Processed row 300 - Closest NTL: 255.0
# Processed row 301 - Closest NTL: 255.0
# Processed row 302 - Closest NTL: 255.0
# Processed row 303 - Closest NTL: 255.0
# Processed row 304 - Closest NTL: 255.0
# Processed row 305 - Closest NTL: 255.0
# Processed row 306 - Closest NTL: 255.0
# Processed row 307 - Closest NTL: 255.0
# Processed row 308 - Closest NTL: 199.0
# Processed row 309 - Closest NTL: 196.0
# Processed row 310 - Closest NTL: 255.0
# Processed row 311 - Closest NTL: 157.0
# Processed row 312 - Closest NTL: 159.0
# Processed row 313 - Closest NTL: 255.0
# Processed row 314 - Closest NTL: 156.0
# Processed row 315 - Closest NTL: 159.0
# Processed row 316 - Closest NTL: 255.0
# Processed row 317 - Closest NTL: 255.0
# Processed row 318 - Closest NTL: 255.0
# Processed row 319 - Closest NTL: 255.0
# Processed row 320 - Closest NTL: 255.0
# Processed row 321 - Closest NTL: 255.0
# Processed row 322 - Closest NTL: 255.0
# Processed row 323 - Closest NTL: 255.0
# Processed row 324 - Closest NTL: 255.0
# Processed row 325 - Closest NTL: 255.0
# Processed row 326 - Closest NTL: 255.0
# Processed row 327 - Closest NTL: 255.0
# Processed row 328 - Closest NTL: 255.0
# Processed row 329 - Closest NTL: 255.0
# Processed row 330 - Closest NTL: 255.0
# Processed row 331 - Closest NTL: 255.0
# Processed row 332 - Closest NTL: 255.0
# Processed row 333 - Closest NTL: 255.0
# Processed row 334 - Closest NTL: 255.0
# Processed row 335 - Closest NTL: 255.0
# Processed row 336 - Closest NTL: 31.0
# Processed row 337 - Closest NTL: 90.0
# Processed row 338 - Closest NTL: 88.0
# Processed row 339 - Closest NTL: 33.0
# Processed row 340 - Closest NTL: 90.0
# Processed row 341 - Closest NTL: 88.0
# Processed row 342 - Closest NTL: 33.0
# Processed row 343 - Closest NTL: 36.0
# Processed row 344 - Closest NTL: 115.0
# Processed row 345 - Closest NTL: 114.0
# Processed row 346 - Closest NTL: 36.0
# Processed row 347 - Closest NTL: 115.0
# Processed row 348 - Closest NTL: 114.0
# Processed row 349 - Closest NTL: 35.0
# Processed row 350 - Closest NTL: 33.0
# Processed row 351 - Closest NTL: 34.0
# Processed row 352 - Closest NTL: 30.0
# Processed row 353 - Closest NTL: 29.0
# Processed row 354 - Closest NTL: 30.0
# Processed row 355 - Closest NTL: 30.0
# Processed row 356 - Closest NTL: 29.0
# Processed row 357 - Closest NTL: 30.0
# Processed row 358 - Closest NTL: 100.0
# Processed row 359 - Closest NTL: 100.0
# Processed row 360 - Closest NTL: 28.0
# Processed row 361 - Closest NTL: 26.0
# Processed row 362 - Closest NTL: 25.0
# Processed row 363 - Closest NTL: 24.0
# Processed row 364 - Closest NTL: 25.0
# Processed row 365 - Closest NTL: 25.0
# Processed row 366 - Closest NTL: 24.0
# Processed row 367 - Closest NTL: 25.0
# Processed row 368 - Closest NTL: 25.0
# Processed row 369 - Closest NTL: 24.0
# Processed row 370 - Closest NTL: 120.0
# Processed row 371 - Closest NTL: 118.0
# Processed row 372 - Closest NTL: 17.0
# Processed row 373 - Closest NTL: 118.0
# Processed row 374 - Closest NTL: 118.0
# Processed row 375 - Closest NTL: 17.0
# Processed row 376 - Closest NTL: 118.0
# Processed row 377 - Closest NTL: 118.0
# Processed row 378 - Closest NTL: 17.0
# Processed row 379 - Closest NTL: 46.0
# Processed row 380 - Closest NTL: 28.0
# Processed row 381 - Closest NTL: 26.0
# Processed row 382 - Closest NTL: 27.0
# Processed row 383 - Closest NTL: 26.0
# Processed row 384 - Closest NTL: 28.0
# Processed row 385 - Closest NTL: 27.0
# Processed row 386 - Closest NTL: 26.0
# Processed row 387 - Closest NTL: 28.0
# Processed row 388 - Closest NTL: 22.0
# Processed row 389 - Closest NTL: 21.0
# Processed row 390 - Closest NTL: 20.0
# Processed row 391 - Closest NTL: 22.0
# Processed row 392 - Closest NTL: 21.0
# Processed row 393 - Closest NTL: 20.0
# Processed row 394 - Closest NTL: 22.0
# Processed row 395 - Closest NTL: 21.0
# Processed row 396 - Closest NTL: 20.0
# Processed row 397 - Closest NTL: 23.0
# Processed row 398 - Closest NTL: 20.0
# Processed row 399 - Closest NTL: 19.0
# Processed row 400 - Closest NTL: 21.0
# Processed row 401 - Closest NTL: 22.0
# Processed row 402 - Closest NTL: 21.0
# Processed row 403 - Closest NTL: 20.0
# Processed row 404 - Closest NTL: 23.0
# Processed row 405 - Closest NTL: 21.0
# Processed row 406 - Closest NTL: 17.0
# Processed row 407 - Closest NTL: 16.0
# Processed row 408 - Closest NTL: 16.0
# Processed row 409 - Closest NTL: 17.0
# Processed row 410 - Closest NTL: 16.0
# Processed row 411 - Closest NTL: 16.0
# Processed row 412 - Closest NTL: 17.0
# Processed row 413 - Closest NTL: 16.0
# Processed row 414 - Closest NTL: 16.0
# Processed row 415 - Closest NTL: 27.0
# Processed row 416 - Closest NTL: 24.0
# Processed row 417 - Closest NTL: 22.0
# Processed row 418 - Closest NTL: 25.0
# Processed row 419 - Closest NTL: 22.0
# Processed row 420 - Closest NTL: 21.0
# Processed row 421 - Closest NTL: 25.0
# Processed row 422 - Closest NTL: 22.0
# Processed row 423 - Closest NTL: 21.0
# Processed row 424 - Closest NTL: 179.0
# Processed row 425 - Closest NTL: 177.0
# Processed row 426 - Closest NTL: 30.0
# Processed row 427 - Closest NTL: 179.0
# Processed row 428 - Closest NTL: 177.0
# Processed row 429 - Closest NTL: 30.0
# Processed row 430 - Closest NTL: 31.0
# Processed row 431 - Closest NTL: 30.0
# Processed row 432 - Closest NTL: 29.0
# Processed row 433 - Closest NTL: 22.0
# Processed row 434 - Closest NTL: 21.0
# Processed row 435 - Closest NTL: 18.0
# Processed row 436 - Closest NTL: 22.0
# Processed row 437 - Closest NTL: 21.0
# Processed row 438 - Closest NTL: 18.0
# Processed row 439 - Closest NTL: 18.0
# Processed row 440 - Closest NTL: 19.0
# Processed row 441 - Closest NTL: 18.0
# Processed row 442 - Closest NTL: 99.0
# Processed row 443 - Closest NTL: 98.0
# Processed row 444 - Closest NTL: 32.0
# Processed row 445 - Closest NTL: 34.0
# Processed row 446 - Closest NTL: 32.0
# Processed row 447 - Closest NTL: 31.0
# Processed row 448 - Closest NTL: 34.0
# Processed row 449 - Closest NTL: 32.0
# Processed row 450 - Closest NTL: 31.0
# Processed row 451 - Closest NTL: 92.0
# Processed row 452 - Closest NTL: 71.0
# Processed row 453 - Closest NTL: 74.0
# Processed row 454 - Closest NTL: 105.0
# Processed row 455 - Closest NTL: 85.0
# Processed row 456 - Closest NTL: 86.0
# Processed row 457 - Closest NTL: 105.0
# Processed row 458 - Closest NTL: 85.0
# Processed row 459 - Closest NTL: 86.0
# Processed row 460 - Closest NTL: 86.0
# Processed row 461 - Closest NTL: 237.0
# Processed row 462 - Closest NTL: 238.0
# Processed row 463 - Closest NTL: 68.0
# Processed row 464 - Closest NTL: 71.0
# Processed row 465 - Closest NTL: 74.0
# Processed row 466 - Closest NTL: 68.0
# Processed row 467 - Closest NTL: 71.0
# Processed row 468 - Closest NTL: 74.0
# Processed row 469 - Closest NTL: 24.0
# Processed row 470 - Closest NTL: 24.0
# Processed row 471 - Closest NTL: 23.0
# Processed row 472 - Closest NTL: 25.0
# Processed row 473 - Closest NTL: 21.0
# Processed row 474 - Closest NTL: 20.0
# Processed row 475 - Closest NTL: 25.0
# Processed row 476 - Closest NTL: 21.0
# Processed row 477 - Closest NTL: 20.0
# Processed row 478 - Closest NTL: 255.0
# Processed row 479 - Closest NTL: 255.0
# Processed row 480 - Closest NTL: 255.0
# Processed row 481 - Closest NTL: 255.0
# Processed row 482 - Closest NTL: 255.0
# Processed row 483 - Closest NTL: 255.0
# Processed row 484 - Closest NTL: 255.0
# Processed row 485 - Closest NTL: 255.0
# Processed row 486 - Closest NTL: 255.0
# Processed row 487 - Closest NTL: 197.0
# Processed row 488 - Closest NTL: 24.0
# Processed row 489 - Closest NTL: 24.0
# Processed row 490 - Closest NTL: 195.0
# Processed row 491 - Closest NTL: 23.0
# Processed row 492 - Closest NTL: 23.0
# Processed row 493 - Closest NTL: 195.0
# Processed row 494 - Closest NTL: 23.0
# Processed row 495 - Closest NTL: 23.0
# Processed row 496 - Closest NTL: 30.0
# Processed row 497 - Closest NTL: 29.0
# Processed row 498 - Closest NTL: 30.0
# Processed row 499 - Closest NTL: 30.0
# Processed row 500 - Closest NTL: 29.0
# Processed row 501 - Closest NTL: 30.0
# Processed row 502 - Closest NTL: 26.0
# Processed row 503 - Closest NTL: 28.0
# Processed row 504 - Closest NTL: 29.0
# Processed row 505 - Closest NTL: 120.0
# Processed row 506 - Closest NTL: 60.0
# Processed row 507 - Closest NTL: 58.0
# Processed row 508 - Closest NTL: 120.0
# Processed row 509 - Closest NTL: 60.0
# Processed row 510 - Closest NTL: 58.0
# Processed row 511 - Closest NTL: 24.0
# Processed row 512 - Closest NTL: 25.0
# Processed row 513 - Closest NTL: 24.0
# Processed row 514 - Closest NTL: 23.0
# Processed row 515 - Closest NTL: 22.0
# Processed row 516 - Closest NTL: 21.0
# Processed row 517 - Closest NTL: 21.0
# Processed row 518 - Closest NTL: 22.0
# Processed row 519 - Closest NTL: 21.0
# Processed row 520 - Closest NTL: 21.0
# Processed row 521 - Closest NTL: 22.0
# Processed row 522 - Closest NTL: 21.0
# Processed row 523 - Closest NTL: 255.0
# Processed row 524 - Closest NTL: 255.0
# Processed row 525 - Closest NTL: 255.0
# Processed row 526 - Closest NTL: 255.0
# Processed row 527 - Closest NTL: 255.0
# Processed row 528 - Closest NTL: 255.0
# Processed row 529 - Closest NTL: 255.0
# Processed row 530 - Closest NTL: 255.0
# Processed row 531 - Closest NTL: 255.0
# Processed row 532 - Closest NTL: 255.0
# Processed row 533 - Closest NTL: 255.0
# Processed row 534 - Closest NTL: 255.0
# Processed row 535 - Closest NTL: 255.0
# Processed row 536 - Closest NTL: 255.0
# Processed row 537 - Closest NTL: 255.0
# Processed row 538 - Closest NTL: 255.0
# Processed row 539 - Closest NTL: 255.0
# Processed row 540 - Closest NTL: 255.0
# Processed row 541 - Closest NTL: 255.0
# Processed row 542 - Closest NTL: 255.0
# Processed row 543 - Closest NTL: 191.0
# Processed row 544 - Closest NTL: 255.0
# Processed row 545 - Closest NTL: 255.0
# Processed row 546 - Closest NTL: 255.0
# Processed row 547 - Closest NTL: 255.0
# Processed row 548 - Closest NTL: 255.0
# Processed row 549 - Closest NTL: 255.0
# Processed row 550 - Closest NTL: 255.0
# Processed row 551 - Closest NTL: 255.0
# Processed row 552 - Closest NTL: 205.0
# Processed row 553 - Closest NTL: 201.0
# Processed row 554 - Closest NTL: 202.0
# Processed row 555 - Closest NTL: 183.0
# Processed row 556 - Closest NTL: 201.0
# Processed row 557 - Closest NTL: 202.0
# Processed row 558 - Closest NTL: 183.0
# Processed row 559 - Closest NTL: 199.0
# Processed row 560 - Closest NTL: 199.0
# Processed row 561 - Closest NTL: 24.0
# Processed row 562 - Closest NTL: 198.0
# Processed row 563 - Closest NTL: 196.0
# Processed row 564 - Closest NTL: 22.0
# Processed row 565 - Closest NTL: 198.0
# Processed row 566 - Closest NTL: 196.0
# Processed row 567 - Closest NTL: 22.0
# Processed row 568 - Closest NTL: 223.0
# Processed row 569 - Closest NTL: 255.0
# Processed row 570 - Closest NTL: 255.0
# Processed row 571 - Closest NTL: 223.0
# Processed row 572 - Closest NTL: 255.0
# Processed row 573 - Closest NTL: 255.0
# Processed row 574 - Closest NTL: 223.0
# Processed row 575 - Closest NTL: 255.0
# Processed row 576 - Closest NTL: 255.0
# Processed row 577 - Closest NTL: 255.0
# Processed row 578 - Closest NTL: 255.0
# Processed row 579 - Closest NTL: 132.0
# Processed row 580 - Closest NTL: 255.0
# Processed row 581 - Closest NTL: 255.0
# Processed row 582 - Closest NTL: 132.0
# Processed row 583 - Closest NTL: 199.0
# Processed row 584 - Closest NTL: 199.0
# Processed row 585 - Closest NTL: 112.0
# Processed row 586 - Closest NTL: 23.0
# Processed row 587 - Closest NTL: 23.0
# Processed row 588 - Closest NTL: 22.0
# Processed row 589 - Closest NTL: 23.0
# Processed row 590 - Closest NTL: 23.0
# Processed row 591 - Closest NTL: 22.0
# Processed row 592 - Closest NTL: 23.0
# Processed row 593 - Closest NTL: 23.0
# Processed row 594 - Closest NTL: 22.0
# Processed row 595 - Closest NTL: 158.0
# Processed row 596 - Closest NTL: 158.0
# Processed row 597 - Closest NTL: 156.0
# Processed row 598 - Closest NTL: 158.0
# Processed row 599 - Closest NTL: 158.0
# Processed row 600 - Closest NTL: 156.0
# Processed row 601 - Closest NTL: 136.0
# Processed row 602 - Closest NTL: 123.0
# Processed row 603 - Closest NTL: 121.0
# Processed row 604 - Closest NTL: 117.0
# Processed row 605 - Closest NTL: 255.0
# Processed row 606 - Closest NTL: 255.0
# Processed row 607 - Closest NTL: 117.0
# Processed row 608 - Closest NTL: 255.0
# Processed row 609 - Closest NTL: 255.0
# Processed row 610 - Closest NTL: 34.0
# Processed row 611 - Closest NTL: 31.0
# Processed row 612 - Closest NTL: 31.0
# Processed row 613 - Closest NTL: 138.0
# Processed row 614 - Closest NTL: 138.0
# Processed row 615 - Closest NTL: 59.0
# Processed row 616 - Closest NTL: 255.0
# Processed row 617 - Closest NTL: 255.0
# Processed row 618 - Closest NTL: 164.0
# Processed row 619 - Closest NTL: 255.0
# Processed row 620 - Closest NTL: 255.0
# Processed row 621 - Closest NTL: 164.0
# Processed row 622 - Closest NTL: 81.0
# Processed row 623 - Closest NTL: 80.0
# Processed row 624 - Closest NTL: 166.0
# Processed row 625 - Closest NTL: 49.0
# Processed row 626 - Closest NTL: 48.0
# Processed row 627 - Closest NTL: 51.0
# Processed row 628 - Closest NTL: 47.0
# Processed row 629 - Closest NTL: 51.0
# Processed row 630 - Closest NTL: 53.0
# Processed row 631 - Closest NTL: 53.0
# Processed row 632 - Closest NTL: 82.0
# Processed row 633 - Closest NTL: 80.0
# Processed row 634 - Closest NTL: 101.0
# Processed row 635 - Closest NTL: 52.0
# Processed row 636 - Closest NTL: 46.0
# Processed row 637 - Closest NTL: 101.0
# Processed row 638 - Closest NTL: 52.0
# Processed row 639 - Closest NTL: 46.0
# Processed row 640 - Closest NTL: 75.0
# Processed row 641 - Closest NTL: 73.0
# Processed row 642 - Closest NTL: 70.0
# Processed row 643 - Closest NTL: 79.0
# Processed row 644 - Closest NTL: 77.0
# Processed row 645 - Closest NTL: 73.0
# Processed row 646 - Closest NTL: 79.0
# Processed row 647 - Closest NTL: 77.0
# Processed row 648 - Closest NTL: 73.0
# Processed row 649 - Closest NTL: 21.0
# Processed row 650 - Closest NTL: 21.0
# Processed row 651 - Closest NTL: 21.0
# Processed row 652 - Closest NTL: 21.0
# Processed row 653 - Closest NTL: 21.0
# Processed row 654 - Closest NTL: 21.0
# Processed row 655 - Closest NTL: 18.0
# Processed row 656 - Closest NTL: 18.0
# Processed row 657 - Closest NTL: 19.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_5.csv
# Number of closest NTLs assigned: 657

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_6.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_6.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None

    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_6.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 243.0
# Processed row 2 - Closest NTL: 243.0
# Processed row 3 - Closest NTL: 255.0
# Processed row 4 - Closest NTL: 243.0
# Processed row 5 - Closest NTL: 243.0
# Processed row 6 - Closest NTL: 255.0
# Processed row 7 - Closest NTL: 191.0
# Processed row 8 - Closest NTL: 192.0
# Processed row 9 - Closest NTL: 225.0
# Processed row 10 - Closest NTL: 129.0
# Processed row 11 - Closest NTL: 129.0
# Processed row 12 - Closest NTL: 25.0
# Processed row 13 - Closest NTL: 126.0
# Processed row 14 - Closest NTL: 128.0
# Processed row 15 - Closest NTL: 24.0
# Processed row 16 - Closest NTL: 126.0
# Processed row 17 - Closest NTL: 128.0
# Processed row 18 - Closest NTL: 24.0
# Processed row 19 - Closest NTL: 97.0
# Processed row 20 - Closest NTL: 33.0
# Processed row 21 - Closest NTL: 31.0
# Processed row 22 - Closest NTL: 97.0
# Processed row 23 - Closest NTL: 33.0
# Processed row 24 - Closest NTL: 31.0
# Processed row 25 - Closest NTL: 40.0
# Processed row 26 - Closest NTL: 39.0
# Processed row 27 - Closest NTL: 38.0
# Processed row 28 - Closest NTL: 36.0
# Processed row 29 - Closest NTL: 97.0
# Processed row 30 - Closest NTL: 97.0
# Processed row 31 - Closest NTL: 36.0
# Processed row 32 - Closest NTL: 97.0
# Processed row 33 - Closest NTL: 97.0
# Processed row 34 - Closest NTL: 38.0
# Processed row 35 - Closest NTL: 96.0
# Processed row 36 - Closest NTL: 97.0
# Processed row 37 - Closest NTL: 30.0
# Processed row 38 - Closest NTL: 140.0
# Processed row 39 - Closest NTL: 139.0
# Processed row 40 - Closest NTL: 28.0
# Processed row 41 - Closest NTL: 29.0
# Processed row 42 - Closest NTL: 29.0
# Processed row 43 - Closest NTL: 28.0
# Processed row 44 - Closest NTL: 29.0
# Processed row 45 - Closest NTL: 29.0
# Processed row 46 - Closest NTL: 151.0
# Processed row 47 - Closest NTL: 70.0
# Processed row 48 - Closest NTL: 68.0
# Processed row 49 - Closest NTL: 151.0
# Processed row 50 - Closest NTL: 70.0
# Processed row 51 - Closest NTL: 68.0
# Processed row 52 - Closest NTL: 21.0
# Processed row 53 - Closest NTL: 21.0
# Processed row 54 - Closest NTL: 18.0
# Processed row 55 - Closest NTL: 219.0
# Processed row 56 - Closest NTL: 168.0
# Processed row 57 - Closest NTL: 166.0
# Processed row 58 - Closest NTL: 255.0
# Processed row 59 - Closest NTL: 255.0
# Processed row 60 - Closest NTL: 255.0
# Processed row 61 - Closest NTL: 255.0
# Processed row 62 - Closest NTL: 255.0
# Processed row 63 - Closest NTL: 255.0
# Processed row 64 - Closest NTL: 25.0
# Processed row 65 - Closest NTL: 23.0
# Processed row 66 - Closest NTL: 23.0
# Processed row 67 - Closest NTL: 25.0
# Processed row 68 - Closest NTL: 23.0
# Processed row 69 - Closest NTL: 23.0
# Processed row 70 - Closest NTL: 21.0
# Processed row 71 - Closest NTL: 22.0
# Processed row 72 - Closest NTL: 20.0
# Processed row 73 - Closest NTL: 140.0
# Processed row 74 - Closest NTL: 38.0
# Processed row 75 - Closest NTL: 36.0
# Processed row 76 - Closest NTL: 140.0
# Processed row 77 - Closest NTL: 38.0
# Processed row 78 - Closest NTL: 36.0
# Processed row 79 - Closest NTL: 137.0
# Processed row 80 - Closest NTL: 37.0
# Processed row 81 - Closest NTL: 38.0
# Processed row 82 - Closest NTL: 107.0
# Processed row 83 - Closest NTL: 44.0
# Processed row 84 - Closest NTL: 39.0
# Processed row 85 - Closest NTL: 107.0
# Processed row 86 - Closest NTL: 44.0
# Processed row 87 - Closest NTL: 39.0
# Processed row 88 - Closest NTL: 105.0
# Processed row 89 - Closest NTL: 45.0
# Processed row 90 - Closest NTL: 42.0
# Processed row 91 - Closest NTL: 169.0
# Processed row 92 - Closest NTL: 168.0
# Processed row 93 - Closest NTL: 81.0
# Processed row 94 - Closest NTL: 169.0
# Processed row 95 - Closest NTL: 168.0
# Processed row 96 - Closest NTL: 81.0
# Processed row 97 - Closest NTL: 167.0
# Processed row 98 - Closest NTL: 166.0
# Processed row 99 - Closest NTL: 87.0
# Processed row 100 - Closest NTL: 30.0
# Processed row 101 - Closest NTL: 26.0
# Processed row 102 - Closest NTL: 25.0
# Processed row 103 - Closest NTL: 30.0
# Processed row 104 - Closest NTL: 26.0
# Processed row 105 - Closest NTL: 25.0
# Processed row 106 - Closest NTL: 25.0
# Processed row 107 - Closest NTL: 24.0
# Processed row 108 - Closest NTL: 24.0
# Processed row 109 - Closest NTL: 172.0
# Processed row 110 - Closest NTL: 28.0
# Processed row 111 - Closest NTL: 28.0
# Processed row 112 - Closest NTL: 30.0
# Processed row 113 - Closest NTL: 29.0
# Processed row 114 - Closest NTL: 27.0
# Processed row 115 - Closest NTL: 30.0
# Processed row 116 - Closest NTL: 29.0
# Processed row 117 - Closest NTL: 27.0
# Processed row 118 - Closest NTL: 241.0
# Processed row 119 - Closest NTL: 187.0
# Processed row 120 - Closest NTL: 72.0
# Processed row 121 - Closest NTL: 122.0
# Processed row 122 - Closest NTL: 71.0
# Processed row 123 - Closest NTL: 72.0
# Processed row 124 - Closest NTL: 122.0
# Processed row 125 - Closest NTL: 71.0
# Processed row 126 - Closest NTL: 72.0
# Processed row 127 - Closest NTL: 47.0
# Processed row 128 - Closest NTL: 49.0
# Processed row 129 - Closest NTL: 50.0
# Processed row 130 - Closest NTL: 46.0
# Processed row 131 - Closest NTL: 46.0
# Processed row 132 - Closest NTL: 49.0
# Processed row 133 - Closest NTL: 46.0
# Processed row 134 - Closest NTL: 46.0
# Processed row 135 - Closest NTL: 49.0
# Processed row 136 - Closest NTL: 107.0
# Processed row 137 - Closest NTL: 105.0
# Processed row 138 - Closest NTL: 54.0
# Processed row 139 - Closest NTL: 96.0
# Processed row 140 - Closest NTL: 94.0
# Processed row 141 - Closest NTL: 52.0
# Processed row 142 - Closest NTL: 96.0
# Processed row 143 - Closest NTL: 94.0
# Processed row 144 - Closest NTL: 52.0
# Processed row 145 - Closest NTL: 26.0
# Processed row 146 - Closest NTL: 28.0
# Processed row 147 - Closest NTL: 29.0
# Processed row 148 - Closest NTL: 25.0
# Processed row 149 - Closest NTL: 24.0
# Processed row 150 - Closest NTL: 23.0
# Processed row 151 - Closest NTL: 25.0
# Processed row 152 - Closest NTL: 24.0
# Processed row 153 - Closest NTL: 23.0
# Processed row 154 - Closest NTL: 23.0
# Processed row 155 - Closest NTL: 23.0
# Processed row 156 - Closest NTL: 22.0
# Processed row 157 - Closest NTL: 77.0
# Processed row 158 - Closest NTL: 72.0
# Processed row 159 - Closest NTL: 50.0
# Processed row 160 - Closest NTL: 77.0
# Processed row 161 - Closest NTL: 72.0
# Processed row 162 - Closest NTL: 50.0
# Processed row 163 - Closest NTL: 77.0
# Processed row 164 - Closest NTL: 72.0
# Processed row 165 - Closest NTL: 52.0
# Processed row 166 - Closest NTL: 40.0
# Processed row 167 - Closest NTL: 42.0
# Processed row 168 - Closest NTL: 41.0
# Processed row 169 - Closest NTL: 44.0
# Processed row 170 - Closest NTL: 45.0
# Processed row 171 - Closest NTL: 46.0
# Processed row 172 - Closest NTL: 44.0
# Processed row 173 - Closest NTL: 45.0
# Processed row 174 - Closest NTL: 46.0
# Processed row 175 - Closest NTL: 219.0
# Processed row 176 - Closest NTL: 218.0
# Processed row 177 - Closest NTL: 37.0
# Processed row 178 - Closest NTL: 219.0
# Processed row 179 - Closest NTL: 218.0
# Processed row 180 - Closest NTL: 37.0
# Processed row 181 - Closest NTL: 39.0
# Processed row 182 - Closest NTL: 40.0
# Processed row 183 - Closest NTL: 98.0
# Processed row 184 - Closest NTL: 83.0
# Processed row 185 - Closest NTL: 93.0
# Processed row 186 - Closest NTL: 92.0
# Processed row 187 - Closest NTL: 137.0
# Processed row 188 - Closest NTL: 174.0
# Processed row 189 - Closest NTL: 172.0
# Processed row 190 - Closest NTL: 137.0
# Processed row 191 - Closest NTL: 174.0
# Processed row 192 - Closest NTL: 172.0
# Processed row 193 - Closest NTL: 20.0
# Processed row 194 - Closest NTL: 19.0
# Processed row 195 - Closest NTL: 18.0
# Processed row 196 - Closest NTL: 20.0
# Processed row 197 - Closest NTL: 19.0
# Processed row 198 - Closest NTL: 18.0
# Processed row 199 - Closest NTL: 19.0
# Processed row 200 - Closest NTL: 20.0
# Processed row 201 - Closest NTL: 18.0
# Processed row 202 - Closest NTL: 24.0
# Processed row 203 - Closest NTL: 24.0
# Processed row 204 - Closest NTL: 24.0
# Processed row 205 - Closest NTL: 22.0
# Processed row 206 - Closest NTL: 23.0
# Processed row 207 - Closest NTL: 23.0
# Processed row 208 - Closest NTL: 22.0
# Processed row 209 - Closest NTL: 23.0
# Processed row 210 - Closest NTL: 23.0
# Processed row 211 - Closest NTL: 255.0
# Processed row 212 - Closest NTL: 255.0
# Processed row 213 - Closest NTL: 151.0
# Processed row 214 - Closest NTL: 255.0
# Processed row 215 - Closest NTL: 255.0
# Processed row 216 - Closest NTL: 149.0
# Processed row 217 - Closest NTL: 255.0
# Processed row 218 - Closest NTL: 255.0
# Processed row 219 - Closest NTL: 149.0
# Processed row 220 - Closest NTL: 255.0
# Processed row 221 - Closest NTL: 255.0
# Processed row 222 - Closest NTL: 255.0
# Processed row 223 - Closest NTL: 55.0
# Processed row 224 - Closest NTL: 201.0
# Processed row 225 - Closest NTL: 202.0
# Processed row 226 - Closest NTL: 55.0
# Processed row 227 - Closest NTL: 201.0
# Processed row 228 - Closest NTL: 202.0
# Processed row 229 - Closest NTL: 207.0
# Processed row 230 - Closest NTL: 33.0
# Processed row 231 - Closest NTL: 33.0
# Processed row 232 - Closest NTL: 207.0
# Processed row 233 - Closest NTL: 33.0
# Processed row 234 - Closest NTL: 33.0
# Processed row 235 - Closest NTL: 56.0
# Processed row 236 - Closest NTL: 30.0
# Processed row 237 - Closest NTL: 28.0
# Processed row 238 - Closest NTL: 27.0
# Processed row 239 - Closest NTL: 26.0
# Processed row 240 - Closest NTL: 26.0
# Processed row 241 - Closest NTL: 25.0
# Processed row 242 - Closest NTL: 25.0
# Processed row 243 - Closest NTL: 26.0
# Processed row 244 - Closest NTL: 25.0
# Processed row 245 - Closest NTL: 25.0
# Processed row 246 - Closest NTL: 26.0
# Processed row 247 - Closest NTL: 28.0
# Processed row 248 - Closest NTL: 29.0
# Processed row 249 - Closest NTL: 28.0
# Processed row 250 - Closest NTL: 28.0
# Processed row 251 - Closest NTL: 29.0
# Processed row 252 - Closest NTL: 28.0
# Processed row 253 - Closest NTL: 28.0
# Processed row 254 - Closest NTL: 28.0
# Processed row 255 - Closest NTL: 27.0
# Processed row 256 - Closest NTL: 24.0
# Processed row 257 - Closest NTL: 24.0
# Processed row 258 - Closest NTL: 25.0
# Processed row 259 - Closest NTL: 24.0
# Processed row 260 - Closest NTL: 24.0
# Processed row 261 - Closest NTL: 25.0
# Processed row 262 - Closest NTL: 54.0
# Processed row 263 - Closest NTL: 50.0
# Processed row 264 - Closest NTL: 44.0
# Processed row 265 - Closest NTL: 56.0
# Processed row 266 - Closest NTL: 50.0
# Processed row 267 - Closest NTL: 44.0
# Processed row 268 - Closest NTL: 56.0
# Processed row 269 - Closest NTL: 48.0
# Processed row 270 - Closest NTL: 42.0
# Processed row 271 - Closest NTL: 25.0
# Processed row 272 - Closest NTL: 23.0
# Processed row 273 - Closest NTL: 23.0
# Processed row 274 - Closest NTL: 25.0
# Processed row 275 - Closest NTL: 23.0
# Processed row 276 - Closest NTL: 23.0
# Processed row 277 - Closest NTL: 24.0
# Processed row 278 - Closest NTL: 23.0
# Processed row 279 - Closest NTL: 23.0
# Processed row 280 - Closest NTL: 237.0
# Processed row 281 - Closest NTL: 236.0
# Processed row 282 - Closest NTL: 38.0
# Processed row 283 - Closest NTL: 237.0
# Processed row 284 - Closest NTL: 236.0
# Processed row 285 - Closest NTL: 38.0
# Processed row 286 - Closest NTL: 234.0
# Processed row 287 - Closest NTL: 233.0
# Processed row 288 - Closest NTL: 35.0
# Processed row 289 - Closest NTL: 75.0
# Processed row 290 - Closest NTL: 75.0
# Processed row 291 - Closest NTL: 30.0
# Processed row 292 - Closest NTL: 75.0
# Processed row 293 - Closest NTL: 75.0
# Processed row 294 - Closest NTL: 30.0
# Processed row 295 - Closest NTL: 30.0
# Processed row 296 - Closest NTL: 30.0
# Processed row 297 - Closest NTL: 29.0
# Processed row 298 - Closest NTL: 255.0
# Processed row 299 - Closest NTL: 255.0
# Processed row 300 - Closest NTL: 255.0
# Processed row 301 - Closest NTL: 255.0
# Processed row 302 - Closest NTL: 255.0
# Processed row 303 - Closest NTL: 255.0
# Processed row 304 - Closest NTL: 255.0
# Processed row 305 - Closest NTL: 255.0
# Processed row 306 - Closest NTL: 221.0
# Processed row 307 - Closest NTL: 23.0
# Processed row 308 - Closest NTL: 24.0
# Processed row 309 - Closest NTL: 25.0
# Processed row 310 - Closest NTL: 23.0
# Processed row 311 - Closest NTL: 24.0
# Processed row 312 - Closest NTL: 25.0
# Processed row 313 - Closest NTL: 22.0
# Processed row 314 - Closest NTL: 24.0
# Processed row 315 - Closest NTL: 23.0
# Processed row 316 - Closest NTL: 245.0
# Processed row 317 - Closest NTL: 243.0
# Processed row 318 - Closest NTL: 62.0
# Processed row 319 - Closest NTL: 245.0
# Processed row 320 - Closest NTL: 243.0
# Processed row 321 - Closest NTL: 62.0
# Processed row 322 - Closest NTL: 129.0
# Processed row 323 - Closest NTL: 126.0
# Processed row 324 - Closest NTL: 69.0
# Processed row 325 - Closest NTL: 255.0
# Processed row 326 - Closest NTL: 255.0
# Processed row 327 - Closest NTL: 255.0
# Processed row 328 - Closest NTL: 255.0
# Processed row 329 - Closest NTL: 255.0
# Processed row 330 - Closest NTL: 255.0
# Processed row 331 - Closest NTL: 255.0
# Processed row 332 - Closest NTL: 255.0
# Processed row 333 - Closest NTL: 255.0
# Processed row 334 - Closest NTL: 255.0
# Processed row 335 - Closest NTL: 255.0
# Processed row 336 - Closest NTL: 255.0
# Processed row 337 - Closest NTL: 255.0
# Processed row 338 - Closest NTL: 255.0
# Processed row 339 - Closest NTL: 255.0
# Processed row 340 - Closest NTL: 255.0
# Processed row 341 - Closest NTL: 255.0
# Processed row 342 - Closest NTL: 255.0
# Processed row 343 - Closest NTL: 255.0
# Processed row 344 - Closest NTL: 255.0
# Processed row 345 - Closest NTL: 255.0
# Processed row 346 - Closest NTL: 255.0
# Processed row 347 - Closest NTL: 255.0
# Processed row 348 - Closest NTL: 255.0
# Processed row 349 - Closest NTL: 255.0
# Processed row 350 - Closest NTL: 255.0
# Processed row 351 - Closest NTL: 255.0
# Processed row 352 - Closest NTL: 255.0
# Processed row 353 - Closest NTL: 255.0
# Processed row 354 - Closest NTL: 255.0
# Processed row 355 - Closest NTL: 255.0
# Processed row 356 - Closest NTL: 255.0
# Processed row 357 - Closest NTL: 255.0
# Processed row 358 - Closest NTL: 255.0
# Processed row 359 - Closest NTL: 255.0
# Processed row 360 - Closest NTL: 255.0
# Processed row 361 - Closest NTL: 64.0
# Processed row 362 - Closest NTL: 64.0
# Processed row 363 - Closest NTL: 54.0
# Processed row 364 - Closest NTL: 64.0
# Processed row 365 - Closest NTL: 64.0
# Processed row 366 - Closest NTL: 54.0
# Processed row 367 - Closest NTL: 64.0
# Processed row 368 - Closest NTL: 64.0
# Processed row 369 - Closest NTL: 54.0
# Processed row 370 - Closest NTL: 112.0
# Processed row 371 - Closest NTL: 78.0
# Processed row 372 - Closest NTL: 78.0
# Processed row 373 - Closest NTL: 72.0
# Processed row 374 - Closest NTL: 74.0
# Processed row 375 - Closest NTL: 74.0
# Processed row 376 - Closest NTL: 72.0
# Processed row 377 - Closest NTL: 74.0
# Processed row 378 - Closest NTL: 74.0
# Processed row 379 - Closest NTL: 240.0
# Processed row 380 - Closest NTL: 240.0
# Processed row 381 - Closest NTL: 96.0
# Processed row 382 - Closest NTL: 240.0
# Processed row 383 - Closest NTL: 240.0
# Processed row 384 - Closest NTL: 96.0
# Processed row 385 - Closest NTL: 24.0
# Processed row 386 - Closest NTL: 24.0
# Processed row 387 - Closest NTL: 23.0
# Processed row 388 - Closest NTL: 29.0
# Processed row 389 - Closest NTL: 43.0
# Processed row 390 - Closest NTL: 43.0
# Processed row 391 - Closest NTL: 29.0
# Processed row 392 - Closest NTL: 43.0
# Processed row 393 - Closest NTL: 43.0
# Processed row 394 - Closest NTL: 27.0
# Processed row 395 - Closest NTL: 43.0
# Processed row 396 - Closest NTL: 42.0
# Processed row 397 - Closest NTL: 27.0
# Processed row 398 - Closest NTL: 27.0
# Processed row 399 - Closest NTL: 26.0
# Processed row 400 - Closest NTL: 27.0
# Processed row 401 - Closest NTL: 27.0
# Processed row 402 - Closest NTL: 42.0
# Processed row 403 - Closest NTL: 27.0
# Processed row 404 - Closest NTL: 27.0
# Processed row 405 - Closest NTL: 42.0
# Processed row 406 - Closest NTL: 68.0
# Processed row 407 - Closest NTL: 70.0
# Processed row 408 - Closest NTL: 68.0
# Processed row 409 - Closest NTL: 68.0
# Processed row 410 - Closest NTL: 70.0
# Processed row 411 - Closest NTL: 68.0
# Processed row 412 - Closest NTL: 66.0
# Processed row 413 - Closest NTL: 67.0
# Processed row 414 - Closest NTL: 69.0
# Processed row 415 - Closest NTL: 25.0
# Processed row 416 - Closest NTL: 26.0
# Processed row 417 - Closest NTL: 22.0
# Processed row 418 - Closest NTL: 27.0
# Processed row 419 - Closest NTL: 24.0
# Processed row 420 - Closest NTL: 24.0
# Processed row 421 - Closest NTL: 29.0
# Processed row 422 - Closest NTL: 25.0
# Processed row 423 - Closest NTL: 25.0
# Processed row 424 - Closest NTL: 228.0
# Processed row 425 - Closest NTL: 226.0
# Processed row 426 - Closest NTL: 58.0
# Processed row 427 - Closest NTL: 228.0
# Processed row 428 - Closest NTL: 227.0
# Processed row 429 - Closest NTL: 61.0
# Processed row 430 - Closest NTL: 228.0
# Processed row 431 - Closest NTL: 227.0
# Processed row 432 - Closest NTL: 61.0
# Processed row 433 - Closest NTL: 255.0
# Processed row 434 - Closest NTL: 255.0
# Processed row 435 - Closest NTL: 63.0
# Processed row 436 - Closest NTL: 255.0
# Processed row 437 - Closest NTL: 255.0
# Processed row 438 - Closest NTL: 64.0
# Processed row 439 - Closest NTL: 255.0
# Processed row 440 - Closest NTL: 255.0
# Processed row 441 - Closest NTL: 64.0
# Processed row 442 - Closest NTL: 19.0
# Processed row 443 - Closest NTL: 19.0
# Processed row 444 - Closest NTL: 19.0
# Processed row 445 - Closest NTL: 19.0
# Processed row 446 - Closest NTL: 19.0
# Processed row 447 - Closest NTL: 19.0
# Processed row 448 - Closest NTL: 16.0
# Processed row 449 - Closest NTL: 18.0
# Processed row 450 - Closest NTL: 18.0
# Processed row 451 - Closest NTL: 37.0
# Processed row 452 - Closest NTL: 39.0
# Processed row 453 - Closest NTL: 40.0
# Processed row 454 - Closest NTL: 37.0
# Processed row 455 - Closest NTL: 39.0
# Processed row 456 - Closest NTL: 40.0
# Processed row 457 - Closest NTL: 36.0
# Processed row 458 - Closest NTL: 39.0
# Processed row 459 - Closest NTL: 40.0
# Processed row 460 - Closest NTL: 234.0
# Processed row 461 - Closest NTL: 208.0
# Processed row 462 - Closest NTL: 204.0
# Processed row 463 - Closest NTL: 199.0
# Processed row 464 - Closest NTL: 167.0
# Processed row 465 - Closest NTL: 162.0
# Processed row 466 - Closest NTL: 199.0
# Processed row 467 - Closest NTL: 167.0
# Processed row 468 - Closest NTL: 162.0
# Processed row 469 - Closest NTL: 255.0
# Processed row 470 - Closest NTL: 255.0
# Processed row 471 - Closest NTL: 79.0
# Processed row 472 - Closest NTL: 255.0
# Processed row 473 - Closest NTL: 255.0
# Processed row 474 - Closest NTL: 79.0
# Processed row 475 - Closest NTL: 58.0
# Processed row 476 - Closest NTL: 58.0
# Processed row 477 - Closest NTL: 59.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_6.csv
# Number of closest NTLs assigned: 477

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_7.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_7.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_7.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 24.0
# Processed row 2 - Closest NTL: 25.0
# Processed row 3 - Closest NTL: 25.0
# Processed row 4 - Closest NTL: 25.0
# Processed row 5 - Closest NTL: 25.0
# Processed row 6 - Closest NTL: 25.0
# Processed row 7 - Closest NTL: 24.0
# Processed row 8 - Closest NTL: 22.0
# Processed row 9 - Closest NTL: 22.0
# Processed row 10 - Closest NTL: 171.0
# Processed row 11 - Closest NTL: 57.0
# Processed row 12 - Closest NTL: 56.0
# Processed row 13 - Closest NTL: 83.0
# Processed row 14 - Closest NTL: 182.0
# Processed row 15 - Closest NTL: 181.0
# Processed row 16 - Closest NTL: 83.0
# Processed row 17 - Closest NTL: 182.0
# Processed row 18 - Closest NTL: 181.0
# Processed row 19 - Closest NTL: 109.0
# Processed row 20 - Closest NTL: 108.0
# Processed row 21 - Closest NTL: 26.0
# Processed row 22 - Closest NTL: 109.0
# Processed row 23 - Closest NTL: 108.0
# Processed row 24 - Closest NTL: 26.0
# Processed row 25 - Closest NTL: 29.0
# Processed row 26 - Closest NTL: 28.0
# Processed row 27 - Closest NTL: 27.0
# Processed row 28 - Closest NTL: 64.0
# Processed row 29 - Closest NTL: 60.0
# Processed row 30 - Closest NTL: 56.0
# Processed row 31 - Closest NTL: 58.0
# Processed row 32 - Closest NTL: 56.0
# Processed row 33 - Closest NTL: 53.0
# Processed row 34 - Closest NTL: 58.0
# Processed row 35 - Closest NTL: 56.0
# Processed row 36 - Closest NTL: 53.0
# Processed row 37 - Closest NTL: 30.0
# Processed row 38 - Closest NTL: 30.0
# Processed row 39 - Closest NTL: 30.0
# Processed row 40 - Closest NTL: 30.0
# Processed row 41 - Closest NTL: 30.0
# Processed row 42 - Closest NTL: 30.0
# Processed row 43 - Closest NTL: 27.0
# Processed row 44 - Closest NTL: 28.0
# Processed row 45 - Closest NTL: 29.0
# Processed row 46 - Closest NTL: 103.0
# Processed row 47 - Closest NTL: 102.0
# Processed row 48 - Closest NTL: 26.0
# Processed row 49 - Closest NTL: 103.0
# Processed row 50 - Closest NTL: 102.0
# Processed row 51 - Closest NTL: 26.0
# Processed row 52 - Closest NTL: 28.0
# Processed row 53 - Closest NTL: 28.0
# Processed row 54 - Closest NTL: 28.0
# Processed row 55 - Closest NTL: 27.0
# Processed row 56 - Closest NTL: 25.0
# Processed row 57 - Closest NTL: 26.0
# Processed row 58 - Closest NTL: 27.0
# Processed row 59 - Closest NTL: 24.0
# Processed row 60 - Closest NTL: 25.0
# Processed row 61 - Closest NTL: 27.0
# Processed row 62 - Closest NTL: 24.0
# Processed row 63 - Closest NTL: 25.0
# Processed row 64 - Closest NTL: 105.0
# Processed row 65 - Closest NTL: 105.0
# Processed row 66 - Closest NTL: 166.0
# Processed row 67 - Closest NTL: 105.0
# Processed row 68 - Closest NTL: 105.0
# Processed row 69 - Closest NTL: 166.0
# Processed row 70 - Closest NTL: 26.0
# Processed row 71 - Closest NTL: 27.0
# Processed row 72 - Closest NTL: 27.0
# Processed row 73 - Closest NTL: 30.0
# Processed row 74 - Closest NTL: 31.0
# Processed row 75 - Closest NTL: 30.0
# Processed row 76 - Closest NTL: 29.0
# Processed row 77 - Closest NTL: 31.0
# Processed row 78 - Closest NTL: 30.0
# Processed row 79 - Closest NTL: 29.0
# Processed row 80 - Closest NTL: 31.0
# Processed row 81 - Closest NTL: 30.0
# Processed row 82 - Closest NTL: 24.0
# Processed row 83 - Closest NTL: 23.0
# Processed row 84 - Closest NTL: 22.0
# Processed row 85 - Closest NTL: 24.0
# Processed row 86 - Closest NTL: 23.0
# Processed row 87 - Closest NTL: 22.0
# Processed row 88 - Closest NTL: 21.0
# Processed row 89 - Closest NTL: 22.0
# Processed row 90 - Closest NTL: 23.0
# Processed row 91 - Closest NTL: 25.0
# Processed row 92 - Closest NTL: 62.0
# Processed row 93 - Closest NTL: 63.0
# Processed row 94 - Closest NTL: 25.0
# Processed row 95 - Closest NTL: 62.0
# Processed row 96 - Closest NTL: 63.0
# Processed row 97 - Closest NTL: 24.0
# Processed row 98 - Closest NTL: 64.0
# Processed row 99 - Closest NTL: 63.0
# Processed row 100 - Closest NTL: 23.0
# Processed row 101 - Closest NTL: 23.0
# Processed row 102 - Closest NTL: 21.0
# Processed row 103 - Closest NTL: 23.0
# Processed row 104 - Closest NTL: 23.0
# Processed row 105 - Closest NTL: 21.0
# Processed row 106 - Closest NTL: 22.0
# Processed row 107 - Closest NTL: 22.0
# Processed row 108 - Closest NTL: 21.0
# Processed row 109 - Closest NTL: 41.0
# Processed row 110 - Closest NTL: 81.0
# Processed row 111 - Closest NTL: 79.0
# Processed row 112 - Closest NTL: 41.0
# Processed row 113 - Closest NTL: 81.0
# Processed row 114 - Closest NTL: 79.0
# Processed row 115 - Closest NTL: 39.0
# Processed row 116 - Closest NTL: 80.0
# Processed row 117 - Closest NTL: 78.0
# Processed row 118 - Closest NTL: 164.0
# Processed row 119 - Closest NTL: 164.0
# Processed row 120 - Closest NTL: 88.0
# Processed row 121 - Closest NTL: 162.0
# Processed row 122 - Closest NTL: 164.0
# Processed row 123 - Closest NTL: 87.0
# Processed row 124 - Closest NTL: 162.0
# Processed row 125 - Closest NTL: 164.0
# Processed row 126 - Closest NTL: 87.0
# Processed row 127 - Closest NTL: 48.0
# Processed row 128 - Closest NTL: 53.0
# Processed row 129 - Closest NTL: 71.0
# Processed row 130 - Closest NTL: 52.0
# Processed row 131 - Closest NTL: 55.0
# Processed row 132 - Closest NTL: 72.0
# Processed row 133 - Closest NTL: 52.0
# Processed row 134 - Closest NTL: 55.0
# Processed row 135 - Closest NTL: 72.0
# Processed row 136 - Closest NTL: 90.0
# Processed row 137 - Closest NTL: 134.0
# Processed row 138 - Closest NTL: 134.0
# Processed row 139 - Closest NTL: 90.0
# Processed row 140 - Closest NTL: 134.0
# Processed row 141 - Closest NTL: 134.0
# Processed row 142 - Closest NTL: 90.0
# Processed row 143 - Closest NTL: 134.0
# Processed row 144 - Closest NTL: 134.0
# Processed row 145 - Closest NTL: 159.0
# Processed row 146 - Closest NTL: 155.0
# Processed row 147 - Closest NTL: 154.0
# Processed row 148 - Closest NTL: 96.0
# Processed row 149 - Closest NTL: 95.0
# Processed row 150 - Closest NTL: 105.0
# Processed row 151 - Closest NTL: 96.0
# Processed row 152 - Closest NTL: 95.0
# Processed row 153 - Closest NTL: 105.0
# Processed row 154 - Closest NTL: 255.0
# Processed row 155 - Closest NTL: 209.0
# Processed row 156 - Closest NTL: 208.0
# Processed row 157 - Closest NTL: 255.0
# Processed row 158 - Closest NTL: 209.0
# Processed row 159 - Closest NTL: 208.0
# Processed row 160 - Closest NTL: 255.0
# Processed row 161 - Closest NTL: 207.0
# Processed row 162 - Closest NTL: 207.0
# Processed row 163 - Closest NTL: 49.0
# Processed row 164 - Closest NTL: 51.0
# Processed row 165 - Closest NTL: 52.0
# Processed row 166 - Closest NTL: 46.0
# Processed row 167 - Closest NTL: 47.0
# Processed row 168 - Closest NTL: 49.0
# Processed row 169 - Closest NTL: 46.0
# Processed row 170 - Closest NTL: 47.0
# Processed row 171 - Closest NTL: 49.0
# Processed row 172 - Closest NTL: 85.0
# Processed row 173 - Closest NTL: 40.0
# Processed row 174 - Closest NTL: 39.0
# Processed row 175 - Closest NTL: 85.0
# Processed row 176 - Closest NTL: 40.0
# Processed row 177 - Closest NTL: 39.0
# Processed row 178 - Closest NTL: 85.0
# Processed row 179 - Closest NTL: 40.0
# Processed row 180 - Closest NTL: 39.0
# Processed row 181 - Closest NTL: 36.0
# Processed row 182 - Closest NTL: 33.0
# Processed row 183 - Closest NTL: 28.0
# Processed row 184 - Closest NTL: 34.0
# Processed row 185 - Closest NTL: 31.0
# Processed row 186 - Closest NTL: 26.0
# Processed row 187 - Closest NTL: 34.0
# Processed row 188 - Closest NTL: 31.0
# Processed row 189 - Closest NTL: 26.0
# Processed row 190 - Closest NTL: 173.0
# Processed row 191 - Closest NTL: 85.0
# Processed row 192 - Closest NTL: 79.0
# Processed row 193 - Closest NTL: 171.0
# Processed row 194 - Closest NTL: 78.0
# Processed row 195 - Closest NTL: 76.0
# Processed row 196 - Closest NTL: 75.0
# Processed row 197 - Closest NTL: 72.0
# Processed row 198 - Closest NTL: 72.0
# Processed row 199 - Closest NTL: 230.0
# Processed row 200 - Closest NTL: 229.0
# Processed row 201 - Closest NTL: 23.0
# Processed row 202 - Closest NTL: 230.0
# Processed row 203 - Closest NTL: 229.0
# Processed row 204 - Closest NTL: 23.0
# Processed row 205 - Closest NTL: 161.0
# Processed row 206 - Closest NTL: 161.0
# Processed row 207 - Closest NTL: 161.0
# Processed row 208 - Closest NTL: 161.0
# Processed row 209 - Closest NTL: 161.0
# Processed row 210 - Closest NTL: 24.0
# Processed row 211 - Closest NTL: 161.0
# Processed row 212 - Closest NTL: 161.0
# Processed row 213 - Closest NTL: 24.0
# Processed row 214 - Closest NTL: 161.0
# Processed row 215 - Closest NTL: 161.0
# Processed row 216 - Closest NTL: 24.0
# Processed row 217 - Closest NTL: 29.0
# Processed row 218 - Closest NTL: 25.0
# Processed row 219 - Closest NTL: 24.0
# Processed row 220 - Closest NTL: 29.0
# Processed row 221 - Closest NTL: 25.0
# Processed row 222 - Closest NTL: 24.0
# Processed row 223 - Closest NTL: 28.0
# Processed row 224 - Closest NTL: 26.0
# Processed row 225 - Closest NTL: 21.0
# Processed row 226 - Closest NTL: 28.0
# Processed row 227 - Closest NTL: 26.0
# Processed row 228 - Closest NTL: 21.0
# Processed row 229 - Closest NTL: 26.0
# Processed row 230 - Closest NTL: 22.0
# Processed row 231 - Closest NTL: 19.0
# Processed row 232 - Closest NTL: 36.0
# Processed row 233 - Closest NTL: 34.0
# Processed row 234 - Closest NTL: 29.0
# Processed row 235 - Closest NTL: 39.0
# Processed row 236 - Closest NTL: 35.0
# Processed row 237 - Closest NTL: 30.0
# Processed row 238 - Closest NTL: 39.0
# Processed row 239 - Closest NTL: 35.0
# Processed row 240 - Closest NTL: 30.0
# Processed row 241 - Closest NTL: 159.0
# Processed row 242 - Closest NTL: 146.0
# Processed row 243 - Closest NTL: 146.0
# Processed row 244 - Closest NTL: 161.0
# Processed row 245 - Closest NTL: 151.0
# Processed row 246 - Closest NTL: 147.0
# Processed row 247 - Closest NTL: 62.0
# Processed row 248 - Closest NTL: 58.0
# Processed row 249 - Closest NTL: 55.0
# Processed row 250 - Closest NTL: 249.0
# Processed row 251 - Closest NTL: 249.0
# Processed row 252 - Closest NTL: 255.0
# Processed row 253 - Closest NTL: 255.0
# Processed row 254 - Closest NTL: 255.0
# Processed row 255 - Closest NTL: 255.0
# Processed row 256 - Closest NTL: 255.0
# Processed row 257 - Closest NTL: 255.0
# Processed row 258 - Closest NTL: 255.0
# Processed row 259 - Closest NTL: 26.0
# Processed row 260 - Closest NTL: 26.0
# Processed row 261 - Closest NTL: 27.0
# Processed row 262 - Closest NTL: 26.0
# Processed row 263 - Closest NTL: 26.0
# Processed row 264 - Closest NTL: 27.0
# Processed row 265 - Closest NTL: 28.0
# Processed row 266 - Closest NTL: 30.0
# Processed row 267 - Closest NTL: 29.0
# Processed row 268 - Closest NTL: 255.0
# Processed row 269 - Closest NTL: 191.0
# Processed row 270 - Closest NTL: 188.0
# Processed row 271 - Closest NTL: 255.0
# Processed row 272 - Closest NTL: 191.0
# Processed row 273 - Closest NTL: 188.0
# Processed row 274 - Closest NTL: 255.0
# Processed row 275 - Closest NTL: 189.0
# Processed row 276 - Closest NTL: 187.0
# Processed row 277 - Closest NTL: 34.0
# Processed row 278 - Closest NTL: 35.0
# Processed row 279 - Closest NTL: 38.0
# Processed row 280 - Closest NTL: 33.0
# Processed row 281 - Closest NTL: 34.0
# Processed row 282 - Closest NTL: 38.0
# Processed row 283 - Closest NTL: 33.0
# Processed row 284 - Closest NTL: 34.0
# Processed row 285 - Closest NTL: 38.0
# Processed row 286 - Closest NTL: 43.0
# Processed row 287 - Closest NTL: 42.0
# Processed row 288 - Closest NTL: 40.0
# Processed row 289 - Closest NTL: 43.0
# Processed row 290 - Closest NTL: 42.0
# Processed row 291 - Closest NTL: 40.0
# Processed row 292 - Closest NTL: 43.0
# Processed row 293 - Closest NTL: 42.0
# Processed row 294 - Closest NTL: 40.0
# Processed row 295 - Closest NTL: 211.0
# Processed row 296 - Closest NTL: 64.0
# Processed row 297 - Closest NTL: 60.0
# Processed row 298 - Closest NTL: 211.0
# Processed row 299 - Closest NTL: 63.0
# Processed row 300 - Closest NTL: 57.0
# Processed row 301 - Closest NTL: 211.0
# Processed row 302 - Closest NTL: 63.0
# Processed row 303 - Closest NTL: 57.0
# Processed row 304 - Closest NTL: 66.0
# Processed row 305 - Closest NTL: 63.0
# Processed row 306 - Closest NTL: 59.0
# Processed row 307 - Closest NTL: 211.0
# Processed row 308 - Closest NTL: 64.0
# Processed row 309 - Closest NTL: 60.0
# Processed row 310 - Closest NTL: 211.0
# Processed row 311 - Closest NTL: 64.0
# Processed row 312 - Closest NTL: 60.0
# Processed row 313 - Closest NTL: 41.0
# Processed row 314 - Closest NTL: 40.0
# Processed row 315 - Closest NTL: 40.0
# Processed row 316 - Closest NTL: 41.0
# Processed row 317 - Closest NTL: 40.0
# Processed row 318 - Closest NTL: 40.0
# Processed row 319 - Closest NTL: 41.0
# Processed row 320 - Closest NTL: 40.0
# Processed row 321 - Closest NTL: 40.0
# Processed row 322 - Closest NTL: 255.0
# Processed row 323 - Closest NTL: 255.0
# Processed row 324 - Closest NTL: 255.0
# Processed row 325 - Closest NTL: 255.0
# Processed row 326 - Closest NTL: 255.0
# Processed row 327 - Closest NTL: 255.0
# Processed row 328 - Closest NTL: 255.0
# Processed row 329 - Closest NTL: 255.0
# Processed row 330 - Closest NTL: 255.0
# Processed row 331 - Closest NTL: 255.0
# Processed row 332 - Closest NTL: 255.0
# Processed row 333 - Closest NTL: 255.0
# Processed row 334 - Closest NTL: 255.0
# Processed row 335 - Closest NTL: 255.0
# Processed row 336 - Closest NTL: 255.0
# Processed row 337 - Closest NTL: 255.0
# Processed row 338 - Closest NTL: 255.0
# Processed row 339 - Closest NTL: 255.0
# Processed row 340 - Closest NTL: 29.0
# Processed row 341 - Closest NTL: 31.0
# Processed row 342 - Closest NTL: 35.0
# Processed row 343 - Closest NTL: 29.0
# Processed row 344 - Closest NTL: 31.0
# Processed row 345 - Closest NTL: 35.0
# Processed row 346 - Closest NTL: 29.0
# Processed row 347 - Closest NTL: 31.0
# Processed row 348 - Closest NTL: 35.0
# Processed row 349 - Closest NTL: 83.0
# Processed row 350 - Closest NTL: 198.0
# Processed row 351 - Closest NTL: 197.0
# Processed row 352 - Closest NTL: 74.0
# Processed row 353 - Closest NTL: 112.0
# Processed row 354 - Closest NTL: 112.0
# Processed row 355 - Closest NTL: 76.0
# Processed row 356 - Closest NTL: 111.0
# Processed row 357 - Closest NTL: 111.0
# Processed row 358 - Closest NTL: 64.0
# Processed row 359 - Closest NTL: 58.0
# Processed row 360 - Closest NTL: 54.0
# Processed row 361 - Closest NTL: 64.0
# Processed row 362 - Closest NTL: 58.0
# Processed row 363 - Closest NTL: 54.0
# Processed row 364 - Closest NTL: 64.0
# Processed row 365 - Closest NTL: 59.0
# Processed row 366 - Closest NTL: 54.0
# Processed row 367 - Closest NTL: 39.0
# Processed row 368 - Closest NTL: 37.0
# Processed row 369 - Closest NTL: 39.0
# Processed row 370 - Closest NTL: 79.0
# Processed row 371 - Closest NTL: 78.0
# Processed row 372 - Closest NTL: 49.0
# Processed row 373 - Closest NTL: 79.0
# Processed row 374 - Closest NTL: 78.0
# Processed row 375 - Closest NTL: 49.0
# Processed row 376 - Closest NTL: 255.0
# Processed row 377 - Closest NTL: 255.0
# Processed row 378 - Closest NTL: 55.0
# Processed row 379 - Closest NTL: 135.0
# Processed row 380 - Closest NTL: 135.0
# Processed row 381 - Closest NTL: 58.0
# Processed row 382 - Closest NTL: 135.0
# Processed row 383 - Closest NTL: 135.0
# Processed row 384 - Closest NTL: 58.0
# Processed row 385 - Closest NTL: 157.0
# Processed row 386 - Closest NTL: 157.0
# Processed row 387 - Closest NTL: 35.0
# Processed row 388 - Closest NTL: 157.0
# Processed row 389 - Closest NTL: 157.0
# Processed row 390 - Closest NTL: 35.0
# Processed row 391 - Closest NTL: 157.0
# Processed row 392 - Closest NTL: 157.0
# Processed row 393 - Closest NTL: 37.0
# Processed row 394 - Closest NTL: 255.0
# Processed row 395 - Closest NTL: 255.0
# Processed row 396 - Closest NTL: 255.0
# Processed row 397 - Closest NTL: 255.0
# Processed row 398 - Closest NTL: 255.0
# Processed row 399 - Closest NTL: 255.0
# Processed row 400 - Closest NTL: 255.0
# Processed row 401 - Closest NTL: 255.0
# Processed row 402 - Closest NTL: 255.0
# Processed row 403 - Closest NTL: 25.0
# Processed row 404 - Closest NTL: 27.0
# Processed row 405 - Closest NTL: 26.0
# Processed row 406 - Closest NTL: 26.0
# Processed row 407 - Closest NTL: 26.0
# Processed row 408 - Closest NTL: 26.0
# Processed row 409 - Closest NTL: 26.0
# Processed row 410 - Closest NTL: 26.0
# Processed row 411 - Closest NTL: 26.0
# Processed row 412 - Closest NTL: 63.0
# Processed row 413 - Closest NTL: 76.0
# Processed row 414 - Closest NTL: 75.0
# Processed row 415 - Closest NTL: 25.0
# Processed row 416 - Closest NTL: 24.0
# Processed row 417 - Closest NTL: 24.0
# Processed row 418 - Closest NTL: 24.0
# Processed row 419 - Closest NTL: 23.0
# Processed row 420 - Closest NTL: 23.0
# Processed row 421 - Closest NTL: 23.0
# Processed row 422 - Closest NTL: 23.0
# Processed row 423 - Closest NTL: 23.0
# Processed row 424 - Closest NTL: 25.0
# Processed row 425 - Closest NTL: 24.0
# Processed row 426 - Closest NTL: 25.0
# Processed row 427 - Closest NTL: 27.0
# Processed row 428 - Closest NTL: 27.0
# Processed row 429 - Closest NTL: 29.0
# Processed row 430 - Closest NTL: 25.0
# Processed row 431 - Closest NTL: 27.0
# Processed row 432 - Closest NTL: 30.0
# Processed row 433 - Closest NTL: 124.0
# Processed row 434 - Closest NTL: 123.0
# Processed row 435 - Closest NTL: 40.0
# Processed row 436 - Closest NTL: 124.0
# Processed row 437 - Closest NTL: 123.0
# Processed row 438 - Closest NTL: 40.0
# Processed row 439 - Closest NTL: 37.0
# Processed row 440 - Closest NTL: 40.0
# Processed row 441 - Closest NTL: 157.0
# Processed row 442 - Closest NTL: 25.0
# Processed row 443 - Closest NTL: 27.0
# Processed row 444 - Closest NTL: 29.0
# Processed row 445 - Closest NTL: 26.0
# Processed row 446 - Closest NTL: 28.0
# Processed row 447 - Closest NTL: 30.0
# Processed row 448 - Closest NTL: 26.0
# Processed row 449 - Closest NTL: 28.0
# Processed row 450 - Closest NTL: 30.0
# Processed row 451 - Closest NTL: 25.0
# Processed row 452 - Closest NTL: 25.0
# Processed row 453 - Closest NTL: 24.0
# Processed row 454 - Closest NTL: 26.0
# Processed row 455 - Closest NTL: 25.0
# Processed row 456 - Closest NTL: 24.0
# Processed row 457 - Closest NTL: 26.0
# Processed row 458 - Closest NTL: 25.0
# Processed row 459 - Closest NTL: 24.0
# Processed row 460 - Closest NTL: 37.0
# Processed row 461 - Closest NTL: 35.0
# Processed row 462 - Closest NTL: 35.0
# Processed row 463 - Closest NTL: 39.0
# Processed row 464 - Closest NTL: 37.0
# Processed row 465 - Closest NTL: 37.0
# Processed row 466 - Closest NTL: 39.0
# Processed row 467 - Closest NTL: 37.0
# Processed row 468 - Closest NTL: 37.0
# Processed row 469 - Closest NTL: 41.0
# Processed row 470 - Closest NTL: 42.0
# Processed row 471 - Closest NTL: 43.0
# Processed row 472 - Closest NTL: 41.0
# Processed row 473 - Closest NTL: 44.0
# Processed row 474 - Closest NTL: 47.0
# Processed row 475 - Closest NTL: 41.0
# Processed row 476 - Closest NTL: 44.0
# Processed row 477 - Closest NTL: 47.0
# Processed row 478 - Closest NTL: 25.0
# Processed row 479 - Closest NTL: 168.0
# Processed row 480 - Closest NTL: 169.0
# Processed row 481 - Closest NTL: 48.0
# Processed row 482 - Closest NTL: 48.0
# Processed row 483 - Closest NTL: 49.0
# Processed row 484 - Closest NTL: 44.0
# Processed row 485 - Closest NTL: 45.0
# Processed row 486 - Closest NTL: 47.0
# Processed row 487 - Closest NTL: 40.0
# Processed row 488 - Closest NTL: 42.0
# Processed row 489 - Closest NTL: 43.0
# Processed row 490 - Closest NTL: 170.0
# Processed row 491 - Closest NTL: 171.0
# Processed row 492 - Closest NTL: 113.0
# Processed row 493 - Closest NTL: 172.0
# Processed row 494 - Closest NTL: 170.0
# Processed row 495 - Closest NTL: 114.0
# Processed row 496 - Closest NTL: 28.0
# Processed row 497 - Closest NTL: 29.0
# Processed row 498 - Closest NTL: 31.0
# Processed row 499 - Closest NTL: 30.0
# Processed row 500 - Closest NTL: 30.0
# Processed row 501 - Closest NTL: 30.0
# Processed row 502 - Closest NTL: 30.0
# Processed row 503 - Closest NTL: 30.0
# Processed row 504 - Closest NTL: 30.0
# Processed row 505 - Closest NTL: 28.0
# Processed row 506 - Closest NTL: 29.0
# Processed row 507 - Closest NTL: 28.0
# Processed row 508 - Closest NTL: 151.0
# Processed row 509 - Closest NTL: 148.0
# Processed row 510 - Closest NTL: 146.0
# Processed row 511 - Closest NTL: 176.0
# Processed row 512 - Closest NTL: 166.0
# Processed row 513 - Closest NTL: 166.0
# Processed row 514 - Closest NTL: 176.0
# Processed row 515 - Closest NTL: 166.0
# Processed row 516 - Closest NTL: 166.0
# Processed row 517 - Closest NTL: 176.0
# Processed row 518 - Closest NTL: 171.0
# Processed row 519 - Closest NTL: 174.0
# Processed row 520 - Closest NTL: 176.0
# Processed row 521 - Closest NTL: 171.0
# Processed row 522 - Closest NTL: 174.0
# Processed row 523 - Closest NTL: 183.0
# Processed row 524 - Closest NTL: 179.0
# Processed row 525 - Closest NTL: 181.0
# Processed row 526 - Closest NTL: 25.0
# Processed row 527 - Closest NTL: 24.0
# Processed row 528 - Closest NTL: 23.0
# Processed row 529 - Closest NTL: 23.0
# Processed row 530 - Closest NTL: 23.0
# Processed row 531 - Closest NTL: 24.0
# Processed row 532 - Closest NTL: 23.0
# Processed row 533 - Closest NTL: 23.0
# Processed row 534 - Closest NTL: 24.0
# Processed row 535 - Closest NTL: 66.0
# Processed row 536 - Closest NTL: 68.0
# Processed row 537 - Closest NTL: 60.0
# Processed row 538 - Closest NTL: 66.0
# Processed row 539 - Closest NTL: 68.0
# Processed row 540 - Closest NTL: 60.0
# Processed row 541 - Closest NTL: 67.0
# Processed row 542 - Closest NTL: 59.0
# Processed row 543 - Closest NTL: 58.0
# Processed row 544 - Closest NTL: 255.0
# Processed row 545 - Closest NTL: 194.0
# Processed row 546 - Closest NTL: 195.0
# Processed row 547 - Closest NTL: 255.0
# Processed row 548 - Closest NTL: 194.0
# Processed row 549 - Closest NTL: 195.0
# Processed row 550 - Closest NTL: 255.0
# Processed row 551 - Closest NTL: 194.0
# Processed row 552 - Closest NTL: 194.0
# Processed row 553 - Closest NTL: 54.0
# Processed row 554 - Closest NTL: 121.0
# Processed row 555 - Closest NTL: 121.0
# Processed row 556 - Closest NTL: 57.0
# Processed row 557 - Closest NTL: 56.0
# Processed row 558 - Closest NTL: 56.0
# Processed row 559 - Closest NTL: 59.0
# Processed row 560 - Closest NTL: 60.0
# Processed row 561 - Closest NTL: 59.0
# Processed row 562 - Closest NTL: 83.0
# Processed row 563 - Closest NTL: 28.0
# Processed row 564 - Closest NTL: 27.0
# Processed row 565 - Closest NTL: 83.0
# Processed row 566 - Closest NTL: 28.0
# Processed row 567 - Closest NTL: 27.0
# Processed row 568 - Closest NTL: 27.0
# Processed row 569 - Closest NTL: 30.0
# Processed row 570 - Closest NTL: 31.0
# Processed row 571 - Closest NTL: 32.0
# Processed row 572 - Closest NTL: 36.0
# Processed row 573 - Closest NTL: 36.0
# Processed row 574 - Closest NTL: 32.0
# Processed row 575 - Closest NTL: 36.0
# Processed row 576 - Closest NTL: 36.0
# Processed row 577 - Closest NTL: 33.0
# Processed row 578 - Closest NTL: 36.0
# Processed row 579 - Closest NTL: 39.0
# Processed row 580 - Closest NTL: 25.0
# Processed row 581 - Closest NTL: 24.0
# Processed row 582 - Closest NTL: 24.0
# Processed row 583 - Closest NTL: 24.0
# Processed row 584 - Closest NTL: 24.0
# Processed row 585 - Closest NTL: 24.0
# Processed row 586 - Closest NTL: 24.0
# Processed row 587 - Closest NTL: 24.0
# Processed row 588 - Closest NTL: 24.0
# Processed row 589 - Closest NTL: 255.0
# Processed row 590 - Closest NTL: 255.0
# Processed row 591 - Closest NTL: 255.0
# Processed row 592 - Closest NTL: 255.0
# Processed row 593 - Closest NTL: 255.0
# Processed row 594 - Closest NTL: 255.0
# Processed row 595 - Closest NTL: 255.0
# Processed row 596 - Closest NTL: 255.0
# Processed row 597 - Closest NTL: 255.0
# Processed row 598 - Closest NTL: 92.0
# Processed row 599 - Closest NTL: 97.0
# Processed row 600 - Closest NTL: 204.0
# Processed row 601 - Closest NTL: 96.0
# Processed row 602 - Closest NTL: 103.0
# Processed row 603 - Closest NTL: 207.0
# Processed row 604 - Closest NTL: 96.0
# Processed row 605 - Closest NTL: 103.0
# Processed row 606 - Closest NTL: 207.0
# Processed row 607 - Closest NTL: 255.0
# Processed row 608 - Closest NTL: 255.0
# Processed row 609 - Closest NTL: 255.0
# Processed row 610 - Closest NTL: 255.0
# Processed row 611 - Closest NTL: 255.0
# Processed row 612 - Closest NTL: 255.0
# Processed row 613 - Closest NTL: 72.0
# Processed row 614 - Closest NTL: 82.0
# Processed row 615 - Closest NTL: 79.0
# Processed row 616 - Closest NTL: 25.0
# Processed row 617 - Closest NTL: 24.0
# Processed row 618 - Closest NTL: 24.0
# Processed row 619 - Closest NTL: 24.0
# Processed row 620 - Closest NTL: 24.0
# Processed row 621 - Closest NTL: 24.0
# Processed row 622 - Closest NTL: 24.0
# Processed row 623 - Closest NTL: 25.0
# Processed row 624 - Closest NTL: 27.0
# Processed row 625 - Closest NTL: 255.0
# Processed row 626 - Closest NTL: 255.0
# Processed row 627 - Closest NTL: 83.0
# Processed row 628 - Closest NTL: 255.0
# Processed row 629 - Closest NTL: 255.0
# Processed row 630 - Closest NTL: 84.0
# Processed row 631 - Closest NTL: 255.0
# Processed row 632 - Closest NTL: 255.0
# Processed row 633 - Closest NTL: 84.0
# Processed row 634 - Closest NTL: 43.0
# Processed row 635 - Closest NTL: 41.0
# Processed row 636 - Closest NTL: 40.0
# Processed row 637 - Closest NTL: 46.0
# Processed row 638 - Closest NTL: 45.0
# Processed row 639 - Closest NTL: 46.0
# Processed row 640 - Closest NTL: 46.0
# Processed row 641 - Closest NTL: 45.0
# Processed row 642 - Closest NTL: 46.0
# Processed row 643 - Closest NTL: 109.0
# Processed row 644 - Closest NTL: 108.0
# Processed row 645 - Closest NTL: 63.0
# Processed row 646 - Closest NTL: 109.0
# Processed row 647 - Closest NTL: 108.0
# Processed row 648 - Closest NTL: 63.0
# Processed row 649 - Closest NTL: 107.0
# Processed row 650 - Closest NTL: 105.0
# Processed row 651 - Closest NTL: 59.0
# Processed row 652 - Closest NTL: 59.0
# Processed row 653 - Closest NTL: 83.0
# Processed row 654 - Closest NTL: 84.0
# Processed row 655 - Closest NTL: 56.0
# Processed row 656 - Closest NTL: 61.0
# Processed row 657 - Closest NTL: 64.0
# Processed row 658 - Closest NTL: 56.0
# Processed row 659 - Closest NTL: 61.0
# Processed row 660 - Closest NTL: 64.0
# Processed row 661 - Closest NTL: 36.0
# Processed row 662 - Closest NTL: 58.0
# Processed row 663 - Closest NTL: 61.0
# Processed row 664 - Closest NTL: 32.0
# Processed row 665 - Closest NTL: 54.0
# Processed row 666 - Closest NTL: 58.0
# Processed row 667 - Closest NTL: 32.0
# Processed row 668 - Closest NTL: 54.0
# Processed row 669 - Closest NTL: 58.0
# Processed row 670 - Closest NTL: 44.0
# Processed row 671 - Closest NTL: 49.0
# Processed row 672 - Closest NTL: 54.0
# Processed row 673 - Closest NTL: 43.0
# Processed row 674 - Closest NTL: 172.0
# Processed row 675 - Closest NTL: 173.0
# Processed row 676 - Closest NTL: 43.0
# Processed row 677 - Closest NTL: 172.0
# Processed row 678 - Closest NTL: 172.0
# Processed row 679 - Closest NTL: 255.0
# Processed row 680 - Closest NTL: 255.0
# Processed row 681 - Closest NTL: 255.0
# Processed row 682 - Closest NTL: 255.0
# Processed row 683 - Closest NTL: 255.0
# Processed row 684 - Closest NTL: 255.0
# Processed row 685 - Closest NTL: 255.0
# Processed row 686 - Closest NTL: 255.0
# Processed row 687 - Closest NTL: 255.0
# Processed row 688 - Closest NTL: 25.0
# Processed row 689 - Closest NTL: 24.0
# Processed row 690 - Closest NTL: 25.0
# Processed row 691 - Closest NTL: 26.0
# Processed row 692 - Closest NTL: 25.0
# Processed row 693 - Closest NTL: 23.0
# Processed row 694 - Closest NTL: 26.0
# Processed row 695 - Closest NTL: 25.0
# Processed row 696 - Closest NTL: 23.0
# Processed row 697 - Closest NTL: 161.0
# Processed row 698 - Closest NTL: 159.0
# Processed row 699 - Closest NTL: 47.0
# Processed row 700 - Closest NTL: 162.0
# Processed row 701 - Closest NTL: 158.0
# Processed row 702 - Closest NTL: 47.0
# Processed row 703 - Closest NTL: 45.0
# Processed row 704 - Closest NTL: 47.0
# Processed row 705 - Closest NTL: 50.0
# Processed row 706 - Closest NTL: 167.0
# Processed row 707 - Closest NTL: 165.0
# Processed row 708 - Closest NTL: 93.0
# Processed row 709 - Closest NTL: 165.0
# Processed row 710 - Closest NTL: 164.0
# Processed row 711 - Closest NTL: 94.0
# Processed row 712 - Closest NTL: 165.0
# Processed row 713 - Closest NTL: 164.0
# Processed row 714 - Closest NTL: 94.0
# Processed row 715 - Closest NTL: 28.0
# Processed row 716 - Closest NTL: 26.0
# Processed row 717 - Closest NTL: 26.0
# Processed row 718 - Closest NTL: 26.0
# Processed row 719 - Closest NTL: 25.0
# Processed row 720 - Closest NTL: 26.0
# Processed row 721 - Closest NTL: 26.0
# Processed row 722 - Closest NTL: 25.0
# Processed row 723 - Closest NTL: 26.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_7.csv
# Number of closest NTLs assigned: 723

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_8.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_8.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_8.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 93.0
# Processed row 2 - Closest NTL: 95.0
# Processed row 3 - Closest NTL: 79.0
# Processed row 4 - Closest NTL: 93.0
# Processed row 5 - Closest NTL: 95.0
# Processed row 6 - Closest NTL: 79.0
# Processed row 7 - Closest NTL: 94.0
# Processed row 8 - Closest NTL: 96.0
# Processed row 9 - Closest NTL: 82.0
# Processed row 10 - Closest NTL: 227.0
# Processed row 11 - Closest NTL: 227.0
# Processed row 12 - Closest NTL: 255.0
# Processed row 13 - Closest NTL: 227.0
# Processed row 14 - Closest NTL: 227.0
# Processed row 15 - Closest NTL: 255.0
# Processed row 16 - Closest NTL: 118.0
# Processed row 17 - Closest NTL: 120.0
# Processed row 18 - Closest NTL: 154.0
# Processed row 19 - Closest NTL: 46.0
# Processed row 20 - Closest NTL: 46.0
# Processed row 21 - Closest NTL: 42.0
# Processed row 22 - Closest NTL: 108.0
# Processed row 23 - Closest NTL: 110.0
# Processed row 24 - Closest NTL: 109.0
# Processed row 25 - Closest NTL: 106.0
# Processed row 26 - Closest NTL: 109.0
# Processed row 27 - Closest NTL: 110.0
# Processed row 28 - Closest NTL: 201.0
# Processed row 29 - Closest NTL: 78.0
# Processed row 30 - Closest NTL: 76.0
# Processed row 31 - Closest NTL: 27.0
# Processed row 32 - Closest NTL: 28.0
# Processed row 33 - Closest NTL: 27.0
# Processed row 34 - Closest NTL: 27.0
# Processed row 35 - Closest NTL: 28.0
# Processed row 36 - Closest NTL: 27.0
# Processed row 37 - Closest NTL: 18.0
# Processed row 38 - Closest NTL: 20.0
# Processed row 39 - Closest NTL: 21.0
# Processed row 40 - Closest NTL: 18.0
# Processed row 41 - Closest NTL: 20.0
# Processed row 42 - Closest NTL: 21.0
# Processed row 43 - Closest NTL: 16.0
# Processed row 44 - Closest NTL: 20.0
# Processed row 45 - Closest NTL: 21.0
# Processed row 46 - Closest NTL: 255.0
# Processed row 47 - Closest NTL: 255.0
# Processed row 48 - Closest NTL: 255.0
# Processed row 49 - Closest NTL: 255.0
# Processed row 50 - Closest NTL: 255.0
# Processed row 51 - Closest NTL: 255.0
# Processed row 52 - Closest NTL: 255.0
# Processed row 53 - Closest NTL: 255.0
# Processed row 54 - Closest NTL: 255.0
# Processed row 55 - Closest NTL: 25.0
# Processed row 56 - Closest NTL: 21.0
# Processed row 57 - Closest NTL: 20.0
# Processed row 58 - Closest NTL: 25.0
# Processed row 59 - Closest NTL: 21.0
# Processed row 60 - Closest NTL: 20.0
# Processed row 61 - Closest NTL: 22.0
# Processed row 62 - Closest NTL: 17.0
# Processed row 63 - Closest NTL: 18.0
# Processed row 64 - Closest NTL: 92.0
# Processed row 65 - Closest NTL: 88.0
# Processed row 66 - Closest NTL: 43.0
# Processed row 67 - Closest NTL: 92.0
# Processed row 68 - Closest NTL: 90.0
# Processed row 69 - Closest NTL: 49.0
# Processed row 70 - Closest NTL: 50.0
# Processed row 71 - Closest NTL: 48.0
# Processed row 72 - Closest NTL: 47.0
# Processed row 73 - Closest NTL: 25.0
# Processed row 74 - Closest NTL: 21.0
# Processed row 75 - Closest NTL: 21.0
# Processed row 76 - Closest NTL: 26.0
# Processed row 77 - Closest NTL: 23.0
# Processed row 78 - Closest NTL: 21.0
# Processed row 79 - Closest NTL: 94.0
# Processed row 80 - Closest NTL: 22.0
# Processed row 81 - Closest NTL: 24.0
# Processed row 82 - Closest NTL: 23.0
# Processed row 83 - Closest NTL: 24.0
# Processed row 84 - Closest NTL: 23.0
# Processed row 85 - Closest NTL: 24.0
# Processed row 86 - Closest NTL: 23.0
# Processed row 87 - Closest NTL: 24.0
# Processed row 88 - Closest NTL: 24.0
# Processed row 89 - Closest NTL: 23.0
# Processed row 90 - Closest NTL: 24.0
# Processed row 91 - Closest NTL: 21.0
# Processed row 92 - Closest NTL: 21.0
# Processed row 93 - Closest NTL: 17.0
# Processed row 94 - Closest NTL: 23.0
# Processed row 95 - Closest NTL: 19.0
# Processed row 96 - Closest NTL: 19.0
# Processed row 97 - Closest NTL: 23.0
# Processed row 98 - Closest NTL: 19.0
# Processed row 99 - Closest NTL: 19.0
# Processed row 100 - Closest NTL: 98.0
# Processed row 101 - Closest NTL: 49.0
# Processed row 102 - Closest NTL: 50.0
# Processed row 103 - Closest NTL: 98.0
# Processed row 104 - Closest NTL: 49.0
# Processed row 105 - Closest NTL: 50.0
# Processed row 106 - Closest NTL: 45.0
# Processed row 107 - Closest NTL: 48.0
# Processed row 108 - Closest NTL: 49.0
# Processed row 109 - Closest NTL: 20.0
# Processed row 110 - Closest NTL: 20.0
# Processed row 111 - Closest NTL: 20.0
# Processed row 112 - Closest NTL: 20.0
# Processed row 113 - Closest NTL: 20.0
# Processed row 114 - Closest NTL: 20.0
# Processed row 115 - Closest NTL: 16.0
# Processed row 116 - Closest NTL: 15.0
# Processed row 117 - Closest NTL: 16.0
# Processed row 118 - Closest NTL: 44.0
# Processed row 119 - Closest NTL: 45.0
# Processed row 120 - Closest NTL: 43.0
# Processed row 121 - Closest NTL: 44.0
# Processed row 122 - Closest NTL: 45.0
# Processed row 123 - Closest NTL: 43.0
# Processed row 124 - Closest NTL: 48.0
# Processed row 125 - Closest NTL: 48.0
# Processed row 126 - Closest NTL: 44.0
# Processed row 127 - Closest NTL: 63.0
# Processed row 128 - Closest NTL: 63.0
# Processed row 129 - Closest NTL: 27.0
# Processed row 130 - Closest NTL: 29.0
# Processed row 131 - Closest NTL: 29.0
# Processed row 132 - Closest NTL: 28.0
# Processed row 133 - Closest NTL: 29.0
# Processed row 134 - Closest NTL: 29.0
# Processed row 135 - Closest NTL: 28.0
# Processed row 136 - Closest NTL: 84.0
# Processed row 137 - Closest NTL: 79.0
# Processed row 138 - Closest NTL: 75.0
# Processed row 139 - Closest NTL: 87.0
# Processed row 140 - Closest NTL: 82.0
# Processed row 141 - Closest NTL: 76.0
# Processed row 142 - Closest NTL: 87.0
# Processed row 143 - Closest NTL: 82.0
# Processed row 144 - Closest NTL: 76.0
# Processed row 145 - Closest NTL: 255.0
# Processed row 146 - Closest NTL: 255.0
# Processed row 147 - Closest NTL: 255.0
# Processed row 148 - Closest NTL: 255.0
# Processed row 149 - Closest NTL: 255.0
# Processed row 150 - Closest NTL: 255.0
# Processed row 151 - Closest NTL: 255.0
# Processed row 152 - Closest NTL: 255.0
# Processed row 153 - Closest NTL: 255.0
# Processed row 154 - Closest NTL: 24.0
# Processed row 155 - Closest NTL: 25.0
# Processed row 156 - Closest NTL: 23.0
# Processed row 157 - Closest NTL: 24.0
# Processed row 158 - Closest NTL: 25.0
# Processed row 159 - Closest NTL: 23.0
# Processed row 160 - Closest NTL: 27.0
# Processed row 161 - Closest NTL: 25.0
# Processed row 162 - Closest NTL: 24.0
# Processed row 163 - Closest NTL: 16.0
# Processed row 164 - Closest NTL: 16.0
# Processed row 165 - Closest NTL: 14.0
# Processed row 166 - Closest NTL: 16.0
# Processed row 167 - Closest NTL: 16.0
# Processed row 168 - Closest NTL: 14.0
# Processed row 169 - Closest NTL: 17.0
# Processed row 170 - Closest NTL: 19.0
# Processed row 171 - Closest NTL: 19.0
# Processed row 172 - Closest NTL: 42.0
# Processed row 173 - Closest NTL: 41.0
# Processed row 174 - Closest NTL: 40.0
# Processed row 175 - Closest NTL: 42.0
# Processed row 176 - Closest NTL: 41.0
# Processed row 177 - Closest NTL: 40.0
# Processed row 178 - Closest NTL: 44.0
# Processed row 179 - Closest NTL: 42.0
# Processed row 180 - Closest NTL: 39.0
# Processed row 181 - Closest NTL: 225.0
# Processed row 182 - Closest NTL: 187.0
# Processed row 183 - Closest NTL: 184.0
# Processed row 184 - Closest NTL: 225.0
# Processed row 185 - Closest NTL: 187.0
# Processed row 186 - Closest NTL: 184.0
# Processed row 187 - Closest NTL: 222.0
# Processed row 188 - Closest NTL: 181.0
# Processed row 189 - Closest NTL: 184.0
# Processed row 190 - Closest NTL: 23.0
# Processed row 191 - Closest NTL: 22.0
# Processed row 192 - Closest NTL: 21.0
# Processed row 193 - Closest NTL: 23.0
# Processed row 194 - Closest NTL: 22.0
# Processed row 195 - Closest NTL: 21.0
# Processed row 196 - Closest NTL: 21.0
# Processed row 197 - Closest NTL: 21.0
# Processed row 198 - Closest NTL: 20.0
# Processed row 199 - Closest NTL: 73.0
# Processed row 200 - Closest NTL: 183.0
# Processed row 201 - Closest NTL: 183.0
# Processed row 202 - Closest NTL: 74.0
# Processed row 203 - Closest NTL: 73.0
# Processed row 204 - Closest NTL: 69.0
# Processed row 205 - Closest NTL: 255.0
# Processed row 206 - Closest NTL: 87.0
# Processed row 207 - Closest NTL: 89.0
# Processed row 208 - Closest NTL: 255.0
# Processed row 209 - Closest NTL: 87.0
# Processed row 210 - Closest NTL: 90.0
# Processed row 211 - Closest NTL: 255.0
# Processed row 212 - Closest NTL: 87.0
# Processed row 213 - Closest NTL: 90.0
# Processed row 214 - Closest NTL: 29.0
# Processed row 215 - Closest NTL: 26.0
# Processed row 216 - Closest NTL: 26.0
# Processed row 217 - Closest NTL: 29.0
# Processed row 218 - Closest NTL: 26.0
# Processed row 219 - Closest NTL: 26.0
# Processed row 220 - Closest NTL: 30.0
# Processed row 221 - Closest NTL: 29.0
# Processed row 222 - Closest NTL: 25.0
# Processed row 223 - Closest NTL: 37.0
# Processed row 224 - Closest NTL: 36.0
# Processed row 225 - Closest NTL: 36.0
# Processed row 226 - Closest NTL: 28.0
# Processed row 227 - Closest NTL: 29.0
# Processed row 228 - Closest NTL: 31.0
# Processed row 229 - Closest NTL: 19.0
# Processed row 230 - Closest NTL: 21.0
# Processed row 231 - Closest NTL: 26.0
# Processed row 232 - Closest NTL: 35.0
# Processed row 233 - Closest NTL: 36.0
# Processed row 234 - Closest NTL: 41.0
# Processed row 235 - Closest NTL: 35.0
# Processed row 236 - Closest NTL: 36.0
# Processed row 237 - Closest NTL: 41.0
# Processed row 238 - Closest NTL: 32.0
# Processed row 239 - Closest NTL: 36.0
# Processed row 240 - Closest NTL: 38.0
# Processed row 241 - Closest NTL: 27.0
# Processed row 242 - Closest NTL: 27.0
# Processed row 243 - Closest NTL: 27.0
# Processed row 244 - Closest NTL: 25.0
# Processed row 245 - Closest NTL: 27.0
# Processed row 246 - Closest NTL: 27.0
# Processed row 247 - Closest NTL: 25.0
# Processed row 248 - Closest NTL: 25.0
# Processed row 249 - Closest NTL: 27.0
# Processed row 250 - Closest NTL: 141.0
# Processed row 251 - Closest NTL: 142.0
# Processed row 252 - Closest NTL: 63.0
# Processed row 253 - Closest NTL: 141.0
# Processed row 254 - Closest NTL: 142.0
# Processed row 255 - Closest NTL: 63.0
# Processed row 256 - Closest NTL: 55.0
# Processed row 257 - Closest NTL: 57.0
# Processed row 258 - Closest NTL: 59.0
# Processed row 259 - Closest NTL: 125.0
# Processed row 260 - Closest NTL: 52.0
# Processed row 261 - Closest NTL: 52.0
# Processed row 262 - Closest NTL: 125.0
# Processed row 263 - Closest NTL: 52.0
# Processed row 264 - Closest NTL: 52.0
# Processed row 265 - Closest NTL: 55.0
# Processed row 266 - Closest NTL: 55.0
# Processed row 267 - Closest NTL: 55.0
# Processed row 268 - Closest NTL: 174.0
# Processed row 269 - Closest NTL: 171.0
# Processed row 270 - Closest NTL: 64.0
# Processed row 271 - Closest NTL: 172.0
# Processed row 272 - Closest NTL: 172.0
# Processed row 273 - Closest NTL: 60.0
# Processed row 274 - Closest NTL: 172.0
# Processed row 275 - Closest NTL: 172.0
# Processed row 276 - Closest NTL: 60.0
# Processed row 277 - Closest NTL: 23.0
# Processed row 278 - Closest NTL: 23.0
# Processed row 279 - Closest NTL: 22.0
# Processed row 280 - Closest NTL: 23.0
# Processed row 281 - Closest NTL: 23.0
# Processed row 282 - Closest NTL: 22.0
# Processed row 283 - Closest NTL: 25.0
# Processed row 284 - Closest NTL: 25.0
# Processed row 285 - Closest NTL: 24.0
# Processed row 286 - Closest NTL: 21.0
# Processed row 287 - Closest NTL: 23.0
# Processed row 288 - Closest NTL: 25.0
# Processed row 289 - Closest NTL: 22.0
# Processed row 290 - Closest NTL: 23.0
# Processed row 291 - Closest NTL: 22.0
# Processed row 292 - Closest NTL: 22.0
# Processed row 293 - Closest NTL: 23.0
# Processed row 294 - Closest NTL: 22.0
# Processed row 295 - Closest NTL: 255.0
# Processed row 296 - Closest NTL: 255.0
# Processed row 297 - Closest NTL: 255.0
# Processed row 298 - Closest NTL: 255.0
# Processed row 299 - Closest NTL: 255.0
# Processed row 300 - Closest NTL: 255.0
# Processed row 301 - Closest NTL: 255.0
# Processed row 302 - Closest NTL: 255.0
# Processed row 303 - Closest NTL: 255.0
# Processed row 304 - Closest NTL: 255.0
# Processed row 305 - Closest NTL: 255.0
# Processed row 306 - Closest NTL: 255.0
# Processed row 307 - Closest NTL: 255.0
# Processed row 308 - Closest NTL: 255.0
# Processed row 309 - Closest NTL: 255.0
# Processed row 310 - Closest NTL: 235.0
# Processed row 311 - Closest NTL: 255.0
# Processed row 312 - Closest NTL: 255.0
# Processed row 313 - Closest NTL: 25.0
# Processed row 314 - Closest NTL: 24.0
# Processed row 315 - Closest NTL: 24.0
# Processed row 316 - Closest NTL: 24.0
# Processed row 317 - Closest NTL: 25.0
# Processed row 318 - Closest NTL: 25.0
# Processed row 319 - Closest NTL: 24.0
# Processed row 320 - Closest NTL: 25.0
# Processed row 321 - Closest NTL: 25.0
# Processed row 322 - Closest NTL: 29.0
# Processed row 323 - Closest NTL: 31.0
# Processed row 324 - Closest NTL: 33.0
# Processed row 325 - Closest NTL: 33.0
# Processed row 326 - Closest NTL: 35.0
# Processed row 327 - Closest NTL: 38.0
# Processed row 328 - Closest NTL: 33.0
# Processed row 329 - Closest NTL: 35.0
# Processed row 330 - Closest NTL: 38.0
# Processed row 331 - Closest NTL: 45.0
# Processed row 332 - Closest NTL: 43.0
# Processed row 333 - Closest NTL: 44.0
# Processed row 334 - Closest NTL: 45.0
# Processed row 335 - Closest NTL: 43.0
# Processed row 336 - Closest NTL: 44.0
# Processed row 337 - Closest NTL: 45.0
# Processed row 338 - Closest NTL: 43.0
# Processed row 339 - Closest NTL: 44.0
# Processed row 340 - Closest NTL: 22.0
# Processed row 341 - Closest NTL: 22.0
# Processed row 342 - Closest NTL: 22.0
# Processed row 343 - Closest NTL: 22.0
# Processed row 344 - Closest NTL: 22.0
# Processed row 345 - Closest NTL: 22.0
# Processed row 346 - Closest NTL: 22.0
# Processed row 347 - Closest NTL: 22.0
# Processed row 348 - Closest NTL: 21.0
# Processed row 349 - Closest NTL: 168.0
# Processed row 350 - Closest NTL: 168.0
# Processed row 351 - Closest NTL: 33.0
# Processed row 352 - Closest NTL: 173.0
# Processed row 353 - Closest NTL: 167.0
# Processed row 354 - Closest NTL: 34.0
# Processed row 355 - Closest NTL: 173.0
# Processed row 356 - Closest NTL: 167.0
# Processed row 357 - Closest NTL: 34.0
# Processed row 358 - Closest NTL: 74.0
# Processed row 359 - Closest NTL: 74.0
# Processed row 360 - Closest NTL: 34.0
# Processed row 361 - Closest NTL: 74.0
# Processed row 362 - Closest NTL: 75.0
# Processed row 363 - Closest NTL: 32.0
# Processed row 364 - Closest NTL: 74.0
# Processed row 365 - Closest NTL: 75.0
# Processed row 366 - Closest NTL: 32.0
# Processed row 367 - Closest NTL: 16.0
# Processed row 368 - Closest NTL: 18.0
# Processed row 369 - Closest NTL: 16.0
# Processed row 370 - Closest NTL: 13.0
# Processed row 371 - Closest NTL: 16.0
# Processed row 372 - Closest NTL: 16.0
# Processed row 373 - Closest NTL: 13.0
# Processed row 374 - Closest NTL: 16.0
# Processed row 375 - Closest NTL: 13.0
# Processed row 376 - Closest NTL: 32.0
# Processed row 377 - Closest NTL: 35.0
# Processed row 378 - Closest NTL: 34.0
# Processed row 379 - Closest NTL: 32.0
# Processed row 380 - Closest NTL: 35.0
# Processed row 381 - Closest NTL: 34.0
# Processed row 382 - Closest NTL: 33.0
# Processed row 383 - Closest NTL: 34.0
# Processed row 384 - Closest NTL: 34.0
# Processed row 385 - Closest NTL: 17.0
# Processed row 386 - Closest NTL: 16.0
# Processed row 387 - Closest NTL: 12.0
# Processed row 388 - Closest NTL: 13.0
# Processed row 389 - Closest NTL: 13.0
# Processed row 390 - Closest NTL: 11.0
# Processed row 391 - Closest NTL: 13.0
# Processed row 392 - Closest NTL: 13.0
# Processed row 393 - Closest NTL: 11.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_8.csv
# Number of closest NTLs assigned: 393

# %%
import pandas as pd

# Load the CSV files into pandas DataFrames
ntl_data = pd.read_csv('/kaggle/working/ntl_part_9.csv')
merged_output = pd.read_csv('/kaggle/working/llong_part_9.csv')

# Function to calculate the distance between two coordinates
def calculate_distance(lat1, lon1, lat2, lon2):
    coord1 = (lat1, lon1)
    coord2 = (lat2, lon2)
    dist=(lat1-lat2)**2 + (lon1-lon2)**2
    return dist

# Function to find the closest NTL for each image
def find_closest_ntl(row):
    min_distance = float('inf')
    closest_ntl = None
    
    for idx, ntl_row in ntl_data.iterrows():
        distance = calculate_distance(row['Latitude'], row['Longitude'],ntl_row['latitude'],ntl_row['longitude '])
        if distance < min_distance:
            min_distance = distance
            closest_ntl = ntl_row[' NTL']
    
    print(f"Processed row {row.name + 1} - Closest NTL: {closest_ntl}")
    return closest_ntl

# Apply the function to calculate closest NTL for each image
merged_output['Closest_NTL'] = merged_output.apply(find_closest_ntl, axis=1)

# Count the number of assigned closest NTLs
num_assigned_ntls = merged_output['Closest_NTL'].count()

# Save the updated DataFrame to a new CSV file in /kaggle/working/
output_path = '/kaggle/working/merged_output_with_ntl_9.csv'
merged_output.to_csv(output_path, index=False)

print(f"CSV file saved to: {output_path}")
print(f"Number of closest NTLs assigned: {num_assigned_ntls}")
# Out:
# Processed row 1 - Closest NTL: 255.0
# Processed row 2 - Closest NTL: 255.0
# Processed row 3 - Closest NTL: 255.0
# Processed row 4 - Closest NTL: 255.0
# Processed row 5 - Closest NTL: 255.0
# Processed row 6 - Closest NTL: 255.0
# Processed row 7 - Closest NTL: 255.0
# Processed row 8 - Closest NTL: 255.0
# Processed row 9 - Closest NTL: 255.0
# Processed row 10 - Closest NTL: 255.0
# Processed row 11 - Closest NTL: 255.0
# Processed row 12 - Closest NTL: 255.0
# Processed row 13 - Closest NTL: 255.0
# Processed row 14 - Closest NTL: 255.0
# Processed row 15 - Closest NTL: 255.0
# Processed row 16 - Closest NTL: 255.0
# Processed row 17 - Closest NTL: 255.0
# Processed row 18 - Closest NTL: 255.0
# Processed row 19 - Closest NTL: 10.0
# Processed row 20 - Closest NTL: 11.0
# Processed row 21 - Closest NTL: 11.0
# Processed row 22 - Closest NTL: 10.0
# Processed row 23 - Closest NTL: 11.0
# Processed row 24 - Closest NTL: 11.0
# Processed row 25 - Closest NTL: 10.0
# Processed row 26 - Closest NTL: 11.0
# Processed row 27 - Closest NTL: 12.0
# Processed row 28 - Closest NTL: 10.0
# Processed row 29 - Closest NTL: 10.0
# Processed row 30 - Closest NTL: 10.0
# Processed row 31 - Closest NTL: 10.0
# Processed row 32 - Closest NTL: 10.0
# Processed row 33 - Closest NTL: 10.0
# Processed row 34 - Closest NTL: 8.0
# Processed row 35 - Closest NTL: 8.0
# Processed row 36 - Closest NTL: 8.0
# Processed row 37 - Closest NTL: 10.0
# Processed row 38 - Closest NTL: 8.0
# Processed row 39 - Closest NTL: 8.0
# Processed row 40 - Closest NTL: 11.0
# Processed row 41 - Closest NTL: 10.0
# Processed row 42 - Closest NTL: 9.0
# Processed row 43 - Closest NTL: 11.0
# Processed row 44 - Closest NTL: 10.0
# Processed row 45 - Closest NTL: 9.0
# Processed row 46 - Closest NTL: 9.0
# Processed row 47 - Closest NTL: 11.0
# Processed row 48 - Closest NTL: 10.0
# Processed row 49 - Closest NTL: 10.0
# Processed row 50 - Closest NTL: 11.0
# Processed row 51 - Closest NTL: 10.0
# Processed row 52 - Closest NTL: 10.0
# Processed row 53 - Closest NTL: 11.0
# Processed row 54 - Closest NTL: 10.0
# Processed row 55 - Closest NTL: 226.0
# Processed row 56 - Closest NTL: 227.0
# Processed row 57 - Closest NTL: 186.0
# Processed row 58 - Closest NTL: 64.0
# Processed row 59 - Closest NTL: 69.0
# Processed row 60 - Closest NTL: 74.0
# Processed row 61 - Closest NTL: 61.0
# Processed row 62 - Closest NTL: 68.0
# Processed row 63 - Closest NTL: 75.0
# Processed row 64 - Closest NTL: 83.0
# Processed row 65 - Closest NTL: 131.0
# Processed row 66 - Closest NTL: 135.0
# Processed row 67 - Closest NTL: 83.0
# Processed row 68 - Closest NTL: 131.0
# Processed row 69 - Closest NTL: 135.0
# Processed row 70 - Closest NTL: 80.0
# Processed row 71 - Closest NTL: 127.0
# Processed row 72 - Closest NTL: 134.0
# Processed row 73 - Closest NTL: 9.0
# Processed row 74 - Closest NTL: 9.0
# Processed row 75 - Closest NTL: 9.0
# Processed row 76 - Closest NTL: 10.0
# Processed row 77 - Closest NTL: 10.0
# Processed row 78 - Closest NTL: 9.0
# Processed row 79 - Closest NTL: 10.0
# Processed row 80 - Closest NTL: 10.0
# Processed row 81 - Closest NTL: 9.0
# Processed row 82 - Closest NTL: 7.0
# Processed row 83 - Closest NTL: 8.0
# Processed row 84 - Closest NTL: 9.0
# Processed row 85 - Closest NTL: 10.0
# Processed row 86 - Closest NTL: 8.0
# Processed row 87 - Closest NTL: 8.0
# Processed row 88 - Closest NTL: 10.0
# Processed row 89 - Closest NTL: 8.0
# Processed row 90 - Closest NTL: 8.0
# Processed row 91 - Closest NTL: 9.0
# Processed row 92 - Closest NTL: 10.0
# Processed row 93 - Closest NTL: 9.0
# Processed row 94 - Closest NTL: 9.0
# Processed row 95 - Closest NTL: 10.0
# Processed row 96 - Closest NTL: 9.0
# Processed row 97 - Closest NTL: 8.0
# Processed row 98 - Closest NTL: 8.0
# Processed row 99 - Closest NTL: 8.0
# Processed row 100 - Closest NTL: 255.0
# Processed row 101 - Closest NTL: 255.0
# Processed row 102 - Closest NTL: 242.0
# Processed row 103 - Closest NTL: 255.0
# Processed row 104 - Closest NTL: 255.0
# Processed row 105 - Closest NTL: 243.0
# Processed row 106 - Closest NTL: 255.0
# Processed row 107 - Closest NTL: 255.0
# Processed row 108 - Closest NTL: 157.0
# Processed row 109 - Closest NTL: 9.0
# Processed row 110 - Closest NTL: 10.0
# Processed row 111 - Closest NTL: 10.0
# Processed row 112 - Closest NTL: 10.0
# Processed row 113 - Closest NTL: 9.0
# Processed row 114 - Closest NTL: 10.0
# Processed row 115 - Closest NTL: 8.0
# Processed row 116 - Closest NTL: 9.0
# Processed row 117 - Closest NTL: 8.0
# Processed row 118 - Closest NTL: 8.0
# Processed row 119 - Closest NTL: 9.0
# Processed row 120 - Closest NTL: 9.0
# Processed row 121 - Closest NTL: 8.0
# Processed row 122 - Closest NTL: 9.0
# Processed row 123 - Closest NTL: 9.0
# Processed row 124 - Closest NTL: 9.0
# Processed row 125 - Closest NTL: 9.0
# Processed row 126 - Closest NTL: 9.0
# Processed row 127 - Closest NTL: 21.0
# Processed row 128 - Closest NTL: 23.0
# Processed row 129 - Closest NTL: 26.0
# Processed row 130 - Closest NTL: 17.0
# Processed row 131 - Closest NTL: 20.0
# Processed row 132 - Closest NTL: 24.0
# Processed row 133 - Closest NTL: 17.0
# Processed row 134 - Closest NTL: 20.0
# Processed row 135 - Closest NTL: 24.0
# Processed row 136 - Closest NTL: 11.0
# Processed row 137 - Closest NTL: 12.0
# Processed row 138 - Closest NTL: 10.0
# Processed row 139 - Closest NTL: 11.0
# Processed row 140 - Closest NTL: 11.0
# Processed row 141 - Closest NTL: 11.0
# Processed row 142 - Closest NTL: 11.0
# Processed row 143 - Closest NTL: 11.0
# Processed row 144 - Closest NTL: 11.0
# Processed row 145 - Closest NTL: 10.0
# Processed row 146 - Closest NTL: 11.0
# Processed row 147 - Closest NTL: 11.0
# Processed row 148 - Closest NTL: 10.0
# Processed row 149 - Closest NTL: 11.0
# Processed row 150 - Closest NTL: 11.0
# Processed row 151 - Closest NTL: 10.0
# Processed row 152 - Closest NTL: 10.0
# Processed row 153 - Closest NTL: 9.0
# Processed row 154 - Closest NTL: 10.0
# Processed row 155 - Closest NTL: 9.0
# Processed row 156 - Closest NTL: 10.0
# Processed row 157 - Closest NTL: 8.0
# Processed row 158 - Closest NTL: 8.0
# Processed row 159 - Closest NTL: 8.0
# Processed row 160 - Closest NTL: 8.0
# Processed row 161 - Closest NTL: 8.0
# Processed row 162 - Closest NTL: 8.0
# Processed row 163 - Closest NTL: 9.0
# Processed row 164 - Closest NTL: 9.0
# Processed row 165 - Closest NTL: 9.0
# Processed row 166 - Closest NTL: 8.0
# Processed row 167 - Closest NTL: 9.0
# Processed row 168 - Closest NTL: 9.0
# Processed row 169 - Closest NTL: 8.0
# Processed row 170 - Closest NTL: 9.0
# Processed row 171 - Closest NTL: 9.0
# Processed row 172 - Closest NTL: 118.0
# Processed row 173 - Closest NTL: 97.0
# Processed row 174 - Closest NTL: 87.0
# Processed row 175 - Closest NTL: 118.0
# Processed row 176 - Closest NTL: 97.0
# Processed row 177 - Closest NTL: 87.0
# Processed row 178 - Closest NTL: 13.0
# Processed row 179 - Closest NTL: 15.0
# Processed row 180 - Closest NTL: 18.0
# Processed row 181 - Closest NTL: 13.0
# Processed row 182 - Closest NTL: 15.0
# Processed row 183 - Closest NTL: 18.0
# Processed row 184 - Closest NTL: 12.0
# Processed row 185 - Closest NTL: 12.0
# Processed row 186 - Closest NTL: 12.0
# Processed row 187 - Closest NTL: 12.0
# Processed row 188 - Closest NTL: 14.0
# Processed row 189 - Closest NTL: 17.0
# Processed row 190 - Closest NTL: 15.0
# Processed row 191 - Closest NTL: 18.0
# Processed row 192 - Closest NTL: 22.0
# Processed row 193 - Closest NTL: 15.0
# Processed row 194 - Closest NTL: 18.0
# Processed row 195 - Closest NTL: 22.0
# Processed row 196 - Closest NTL: 13.0
# Processed row 197 - Closest NTL: 13.0
# Processed row 198 - Closest NTL: 13.0
# Processed row 199 - Closest NTL: 13.0
# Processed row 200 - Closest NTL: 13.0
# Processed row 201 - Closest NTL: 13.0
# Processed row 202 - Closest NTL: 12.0
# Processed row 203 - Closest NTL: 12.0
# Processed row 204 - Closest NTL: 12.0
# Processed row 205 - Closest NTL: 9.0
# Processed row 206 - Closest NTL: 8.0
# Processed row 207 - Closest NTL: 8.0
# Processed row 208 - Closest NTL: 9.0
# Processed row 209 - Closest NTL: 8.0
# Processed row 210 - Closest NTL: 8.0
# Processed row 211 - Closest NTL: 9.0
# Processed row 212 - Closest NTL: 8.0
# Processed row 213 - Closest NTL: 8.0
# Processed row 214 - Closest NTL: 10.0
# Processed row 215 - Closest NTL: 10.0
# Processed row 216 - Closest NTL: 11.0
# Processed row 217 - Closest NTL: 10.0
# Processed row 218 - Closest NTL: 10.0
# Processed row 219 - Closest NTL: 11.0
# Processed row 220 - Closest NTL: 9.0
# Processed row 221 - Closest NTL: 10.0
# Processed row 222 - Closest NTL: 9.0
# Processed row 223 - Closest NTL: 29.0
# Processed row 224 - Closest NTL: 31.0
# Processed row 225 - Closest NTL: 38.0
# Processed row 226 - Closest NTL: 28.0
# Processed row 227 - Closest NTL: 32.0
# Processed row 228 - Closest NTL: 37.0
# Processed row 229 - Closest NTL: 28.0
# Processed row 230 - Closest NTL: 32.0
# Processed row 231 - Closest NTL: 37.0
# Processed row 232 - Closest NTL: 11.0
# Processed row 233 - Closest NTL: 11.0
# Processed row 234 - Closest NTL: 11.0
# Processed row 235 - Closest NTL: 11.0
# Processed row 236 - Closest NTL: 11.0
# Processed row 237 - Closest NTL: 11.0
# Processed row 238 - Closest NTL: 10.0
# Processed row 239 - Closest NTL: 10.0
# Processed row 240 - Closest NTL: 10.0
# Processed row 241 - Closest NTL: 8.0
# Processed row 242 - Closest NTL: 8.0
# Processed row 243 - Closest NTL: 8.0
# Processed row 244 - Closest NTL: 8.0
# Processed row 245 - Closest NTL: 8.0
# Processed row 246 - Closest NTL: 8.0
# Processed row 247 - Closest NTL: 8.0
# Processed row 248 - Closest NTL: 8.0
# Processed row 249 - Closest NTL: 8.0
# Processed row 250 - Closest NTL: 9.0
# Processed row 251 - Closest NTL: 8.0
# Processed row 252 - Closest NTL: 8.0
# Processed row 253 - Closest NTL: 9.0
# Processed row 254 - Closest NTL: 8.0
# Processed row 255 - Closest NTL: 8.0
# Processed row 256 - Closest NTL: 9.0
# Processed row 257 - Closest NTL: 8.0
# Processed row 258 - Closest NTL: 8.0
# Processed row 259 - Closest NTL: 68.0
# Processed row 260 - Closest NTL: 75.0
# Processed row 261 - Closest NTL: 80.0
# Processed row 262 - Closest NTL: 68.0
# Processed row 263 - Closest NTL: 75.0
# Processed row 264 - Closest NTL: 80.0
# Processed row 265 - Closest NTL: 69.0
# Processed row 266 - Closest NTL: 76.0
# Processed row 267 - Closest NTL: 84.0
# Processed row 268 - Closest NTL: 8.0
# Processed row 269 - Closest NTL: 9.0
# Processed row 270 - Closest NTL: 9.0
# Processed row 271 - Closest NTL: 8.0
# Processed row 272 - Closest NTL: 9.0
# Processed row 273 - Closest NTL: 9.0
# Processed row 274 - Closest NTL: 10.0
# Processed row 275 - Closest NTL: 9.0
# Processed row 276 - Closest NTL: 9.0
# Processed row 277 - Closest NTL: 9.0
# Processed row 278 - Closest NTL: 9.0
# Processed row 279 - Closest NTL: 9.0
# Processed row 280 - Closest NTL: 8.0
# Processed row 281 - Closest NTL: 9.0
# Processed row 282 - Closest NTL: 10.0
# Processed row 283 - Closest NTL: 8.0
# Processed row 284 - Closest NTL: 9.0
# Processed row 285 - Closest NTL: 10.0
# Processed row 286 - Closest NTL: 9.0
# Processed row 287 - Closest NTL: 8.0
# Processed row 288 - Closest NTL: 8.0
# Processed row 289 - Closest NTL: 9.0
# Processed row 290 - Closest NTL: 9.0
# Processed row 291 - Closest NTL: 9.0
# Processed row 292 - Closest NTL: 9.0
# Processed row 293 - Closest NTL: 9.0
# Processed row 294 - Closest NTL: 9.0
# CSV file saved to: /kaggle/working/merged_output_with_ntl_9.csv
# Number of closest NTLs assigned: 294

# %%
import csv
import json
from shapely.geometry import shape, Point

# Load GeoJSON data for Haryana
with open('/content/HARYANA_STATE.geojson', 'r') as geojson_file:
    haryana_data = json.load(geojson_file)
    haryana_boundary = shape(haryana_data['features'][0]['geometry'])

# Read the CSV file
csv_file_path = '/content/ind_pak_relative_wealth_index (1).csv'
filtered_rows = []

with open(csv_file_path, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Extract latitude and longitude from the CSV row
        latitude = float(row['latitude'])
        longitude = float(row['longitude'])

        # Check if the latitude and longitude fall inside Haryana
        point = Point(longitude, latitude)
        if haryana_boundary.contains(point):
            filtered_rows.append(row)

# Write the filtered rows to a new CSV file in /kaggle/working/
output_csv_path = '/content/filtered_data.csv'  # Changed output path
fieldnames = reader.fieldnames
with open(output_csv_path, 'w', newline='') as outfile:
    writer = csv.DictWriter(outfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(filtered_rows)

print('Filtered data saved to', output_csv_path)
# Out:
# Filtered data saved to /content/filtered_data.csv

# %% [markdown]
# First the csv file needs to be filtered so that we get the data of Haryana only. This is done using the above code block. Then, latitude and longitude of the filtered csv file are used along with the latitude and longitude of our csv file to get the closest RWI value for each patch. This is saved in the CSV file "csv file with labels.csv".

# %%
  import pandas as pd

  # Load the CSV files into pandas DataFrames
  y_data = pd.read_csv('/content/filtered_data.csv')
  x_data = pd.read_csv('/content/deep + atm.csv')

  # Function to calculate the distance between two coordinates
  def calculate_distance(lat1, lon1, lat2, lon2):
      coord1 = (lat1, lon1)
      coord2 = (lat2, lon2)
      dist=(lat1-lat2)**2 + (lon1-lon2)**2
      return dist

  # Function to find the closest NTL for each image
  def find_closest_rwi(row):
      min_distance = float('inf')
      closest_rwi = None

      for idx, y_row in y_data.iterrows():
          distance = calculate_distance(row['Latitude'], row['Longitude'],y_row['latitude'],y_row['longitude'])
          if distance < min_distance:
              min_distance = distance
              closest_rwi = y_row['rwi']

      print(f"Processed row {row.name + 1} - Closest rwi: {closest_rwi}")
      return closest_rwi

  x_data['Closest_rwi'] = x_data.apply(find_closest_rwi, axis=1)

  num_assigned_rwi = x_data['Closest_rwi'].count()

  output_path = '/content/csv file with labels.csv'
  x_data.to_csv(output_path, index=False)

  print(f"CSV file saved to: {output_path}")
  print(f"Number of closest RWIs assigned: {num_assigned_rwi}")
# Out:
# Processed row 1 - Closest rwi: 0.512
# Processed row 2 - Closest rwi: 0.512
# Processed row 3 - Closest rwi: 0.512
# Processed row 4 - Closest rwi: 0.512
# Processed row 5 - Closest rwi: 0.512
# Processed row 6 - Closest rwi: 0.512
# Processed row 7 - Closest rwi: 0.512
# Processed row 8 - Closest rwi: 0.512
# Processed row 9 - Closest rwi: 0.512
# Processed row 10 - Closest rwi: 0.129
# Processed row 11 - Closest rwi: 0.6
# Processed row 12 - Closest rwi: 0.6
# Processed row 13 - Closest rwi: 0.129
# Processed row 14 - Closest rwi: 0.6
# Processed row 15 - Closest rwi: 0.6
# Processed row 16 - Closest rwi: 0.129
# Processed row 17 - Closest rwi: 0.6
# Processed row 18 - Closest rwi: 0.6
# Processed row 19 - Closest rwi: 0.938
# Processed row 20 - Closest rwi: 0.938
# Processed row 21 - Closest rwi: 0.349
# Processed row 22 - Closest rwi: 0.938
# Processed row 23 - Closest rwi: 0.938
# Processed row 24 - Closest rwi: 0.349
# Processed row 25 - Closest rwi: 0.938
# Processed row 26 - Closest rwi: 0.938
# Processed row 27 - Closest rwi: 0.349
# Processed row 28 - Closest rwi: 0.192
# Processed row 29 - Closest rwi: 0.192
# Processed row 30 - Closest rwi: 0.192
# Processed row 31 - Closest rwi: 0.192
# Processed row 32 - Closest rwi: 0.192
# Processed row 33 - Closest rwi: 0.192
# Processed row 34 - Closest rwi: 0.192
# Processed row 35 - Closest rwi: 0.192
# Processed row 36 - Closest rwi: 0.192
# Processed row 37 - Closest rwi: 0.945
# Processed row 38 - Closest rwi: 0.945
# Processed row 39 - Closest rwi: 0.945
# Processed row 40 - Closest rwi: 0.336
# Processed row 41 - Closest rwi: 0.336
# Processed row 42 - Closest rwi: 0.336
# Processed row 43 - Closest rwi: 0.336
# Processed row 44 - Closest rwi: 0.336
# Processed row 45 - Closest rwi: 0.336
# Processed row 46 - Closest rwi: 1.289
# Processed row 47 - Closest rwi: 1.289
# Processed row 48 - Closest rwi: 1.289
# Processed row 49 - Closest rwi: 1.315
# Processed row 50 - Closest rwi: 1.315
# Processed row 51 - Closest rwi: 1.315
# Processed row 52 - Closest rwi: 1.315
# Processed row 53 - Closest rwi: 1.315
# Processed row 54 - Closest rwi: 1.315
# Processed row 55 - Closest rwi: 0.132
# Processed row 56 - Closest rwi: 0.132
# Processed row 57 - Closest rwi: 0.132
# Processed row 58 - Closest rwi: 0.132
# Processed row 59 - Closest rwi: 0.132
# Processed row 60 - Closest rwi: 0.132
# Processed row 61 - Closest rwi: 0.132
# Processed row 62 - Closest rwi: 0.132
# Processed row 63 - Closest rwi: 0.132
# Processed row 64 - Closest rwi: 0.105
# Processed row 65 - Closest rwi: 0.105
# Processed row 66 - Closest rwi: 0.658
# Processed row 67 - Closest rwi: 0.105
# Processed row 68 - Closest rwi: 0.105
# Processed row 69 - Closest rwi: 0.658
# Processed row 70 - Closest rwi: 0.105
# Processed row 71 - Closest rwi: 0.105
# Processed row 72 - Closest rwi: 0.658
# Processed row 73 - Closest rwi: 0.628
# Processed row 74 - Closest rwi: 0.888
# Processed row 75 - Closest rwi: 0.888
# Processed row 76 - Closest rwi: 0.628
# Processed row 77 - Closest rwi: 0.888
# Processed row 78 - Closest rwi: 0.888
# Processed row 79 - Closest rwi: 0.099
# Processed row 80 - Closest rwi: 0.258
# Processed row 81 - Closest rwi: 0.258
# Processed row 82 - Closest rwi: -0.179
# Processed row 83 - Closest rwi: -0.179
# Processed row 84 - Closest rwi: -0.179
# Processed row 85 - Closest rwi: -0.179
# Processed row 86 - Closest rwi: -0.179
# Processed row 87 - Closest rwi: -0.179
# Processed row 88 - Closest rwi: -0.179
# Processed row 89 - Closest rwi: -0.179
# Processed row 90 - Closest rwi: -0.179
# Processed row 91 - Closest rwi: 0.367
# Processed row 92 - Closest rwi: 0.367
# Processed row 93 - Closest rwi: 0.367
# Processed row 94 - Closest rwi: 0.367
# Processed row 95 - Closest rwi: 0.367
# Processed row 96 - Closest rwi: 0.367
# Processed row 97 - Closest rwi: 0.367
# Processed row 98 - Closest rwi: 0.367
# Processed row 99 - Closest rwi: 0.367
# Processed row 100 - Closest rwi: 0.829
# Processed row 101 - Closest rwi: 0.829
# Processed row 102 - Closest rwi: 0.829
# Processed row 103 - Closest rwi: 0.829
# Processed row 104 - Closest rwi: 0.829
# Processed row 105 - Closest rwi: 0.829
# Processed row 106 - Closest rwi: 0.829
# Processed row 107 - Closest rwi: 0.829
# Processed row 108 - Closest rwi: 0.829
# Processed row 109 - Closest rwi: 0.222
# Processed row 110 - Closest rwi: 0.222
# Processed row 111 - Closest rwi: 0.222
# Processed row 112 - Closest rwi: 0.222
# Processed row 113 - Closest rwi: 0.222
# Processed row 114 - Closest rwi: 0.222
# Processed row 115 - Closest rwi: 0.222
# Processed row 116 - Closest rwi: 0.222
# Processed row 117 - Closest rwi: 0.222
# Processed row 118 - Closest rwi: 0.951
# Processed row 119 - Closest rwi: 0.951
# Processed row 120 - Closest rwi: 0.951
# Processed row 121 - Closest rwi: 0.951
# Processed row 122 - Closest rwi: 0.951
# Processed row 123 - Closest rwi: 0.951
# Processed row 124 - Closest rwi: 0.951
# Processed row 125 - Closest rwi: 0.951
# Processed row 126 - Closest rwi: 0.951
# Processed row 127 - Closest rwi: 0.656
# Processed row 128 - Closest rwi: 0.656
# Processed row 129 - Closest rwi: -0.059
# Processed row 130 - Closest rwi: 0.656
# Processed row 131 - Closest rwi: 0.656
# Processed row 132 - Closest rwi: -0.059
# Processed row 133 - Closest rwi: 0.656
# Processed row 134 - Closest rwi: 0.656
# Processed row 135 - Closest rwi: -0.059
# Processed row 136 - Closest rwi: 0.87
# Processed row 137 - Closest rwi: 0.87
# Processed row 138 - Closest rwi: 0.87
# Processed row 139 - Closest rwi: 0.87
# Processed row 140 - Closest rwi: 0.87
# Processed row 141 - Closest rwi: 0.87
# Processed row 142 - Closest rwi: 0.87
# Processed row 143 - Closest rwi: 0.87
# Processed row 144 - Closest rwi: 0.87
# Processed row 145 - Closest rwi: 0.502
# Processed row 146 - Closest rwi: 0.502
# Processed row 147 - Closest rwi: 0.502
# Processed row 148 - Closest rwi: 0.502
# Processed row 149 - Closest rwi: 0.502
# Processed row 150 - Closest rwi: 0.502
# Processed row 151 - Closest rwi: 0.502
# Processed row 152 - Closest rwi: 0.502
# Processed row 153 - Closest rwi: 0.502
# Processed row 154 - Closest rwi: -0.053
# Processed row 155 - Closest rwi: 0.589
# Processed row 156 - Closest rwi: 0.589
# Processed row 157 - Closest rwi: -0.053
# Processed row 158 - Closest rwi: 0.589
# Processed row 159 - Closest rwi: 0.589
# Processed row 160 - Closest rwi: -0.053
# Processed row 161 - Closest rwi: 0.589
# Processed row 162 - Closest rwi: 0.589
# Processed row 163 - Closest rwi: -0.285
# Processed row 164 - Closest rwi: -0.285
# Processed row 165 - Closest rwi: -0.285
# Processed row 166 - Closest rwi: -0.285
# Processed row 167 - Closest rwi: -0.285
# Processed row 168 - Closest rwi: -0.285
# Processed row 169 - Closest rwi: -0.285
# Processed row 170 - Closest rwi: -0.285
# Processed row 171 - Closest rwi: -0.285
# Processed row 172 - Closest rwi: -0.092
# Processed row 173 - Closest rwi: -0.092
# Processed row 174 - Closest rwi: -0.092
# Processed row 175 - Closest rwi: -0.092
# Processed row 176 - Closest rwi: -0.092
# Processed row 177 - Closest rwi: -0.092
# Processed row 178 - Closest rwi: -0.092
# Processed row 179 - Closest rwi: -0.092
# Processed row 180 - Closest rwi: -0.092
# Processed row 181 - Closest rwi: 0.511
# Processed row 182 - Closest rwi: 0.511
# Processed row 183 - Closest rwi: 0.511
# Processed row 184 - Closest rwi: 0.511
# Processed row 185 - Closest rwi: 0.511
# Processed row 186 - Closest rwi: 0.511
# Processed row 187 - Closest rwi: 0.403
# Processed row 188 - Closest rwi: 0.403
# Processed row 189 - Closest rwi: 0.403
# Processed row 190 - Closest rwi: -0.2
# Processed row 191 - Closest rwi: 0.169
# Processed row 192 - Closest rwi: 0.169
# Processed row 193 - Closest rwi: -0.2
# Processed row 194 - Closest rwi: 0.169
# Processed row 195 - Closest rwi: 0.169
# Processed row 196 - Closest rwi: -0.899
# Processed row 197 - Closest rwi: -0.31
# Processed row 198 - Closest rwi: -0.31
# Processed row 199 - Closest rwi: 0.437
# Processed row 200 - Closest rwi: 0.437
# Processed row 201 - Closest rwi: 0.437
# Processed row 202 - Closest rwi: 0.437
# Processed row 203 - Closest rwi: 0.437
# Processed row 204 - Closest rwi: 0.437
# Processed row 205 - Closest rwi: 0.437
# Processed row 206 - Closest rwi: 0.437
# Processed row 207 - Closest rwi: 0.437
# Processed row 208 - Closest rwi: 0.668
# Processed row 209 - Closest rwi: 0.668
# Processed row 210 - Closest rwi: -0.081
# Processed row 211 - Closest rwi: 0.668
# Processed row 212 - Closest rwi: 0.668
# Processed row 213 - Closest rwi: -0.081
# Processed row 214 - Closest rwi: 0.668
# Processed row 215 - Closest rwi: 0.668
# Processed row 216 - Closest rwi: -0.081
# Processed row 217 - Closest rwi: 0.306
# Processed row 218 - Closest rwi: 0.607
# Processed row 219 - Closest rwi: 0.607
# Processed row 220 - Closest rwi: 0.827
# Processed row 221 - Closest rwi: 0.304
# Processed row 222 - Closest rwi: 0.304
# Processed row 223 - Closest rwi: 0.827
# Processed row 224 - Closest rwi: 0.304
# Processed row 225 - Closest rwi: 0.304
# Processed row 226 - Closest rwi: 0.456
# Processed row 227 - Closest rwi: 0.456
# Processed row 228 - Closest rwi: 0.456
# Processed row 229 - Closest rwi: 0.456
# Processed row 230 - Closest rwi: 0.456
# Processed row 231 - Closest rwi: 0.456
# Processed row 232 - Closest rwi: 0.456
# Processed row 233 - Closest rwi: 0.456
# Processed row 234 - Closest rwi: 0.456
# Processed row 235 - Closest rwi: 0.954
# Processed row 236 - Closest rwi: 0.774
# Processed row 237 - Closest rwi: 0.774
# Processed row 238 - Closest rwi: 0.954
# Processed row 239 - Closest rwi: 0.774
# Processed row 240 - Closest rwi: 0.774
# Processed row 241 - Closest rwi: 0.954
# Processed row 242 - Closest rwi: 0.774
# Processed row 243 - Closest rwi: 0.774
# Processed row 244 - Closest rwi: 0.756
# Processed row 245 - Closest rwi: 0.756
# Processed row 246 - Closest rwi: 0.424
# Processed row 247 - Closest rwi: 0.756
# Processed row 248 - Closest rwi: 0.756
# Processed row 249 - Closest rwi: 0.424
# Processed row 250 - Closest rwi: 0.507
# Processed row 251 - Closest rwi: 0.507
# Processed row 252 - Closest rwi: 0.699
# Processed row 253 - Closest rwi: 0.195
# Processed row 254 - Closest rwi: 0.195
# Processed row 255 - Closest rwi: 0.017
# Processed row 256 - Closest rwi: 0.195
# Processed row 257 - Closest rwi: 0.195
# Processed row 258 - Closest rwi: 0.017
# Processed row 259 - Closest rwi: 0.195
# Processed row 260 - Closest rwi: 0.195
# Processed row 261 - Closest rwi: 0.017
# Processed row 262 - Closest rwi: 0.301
# Processed row 263 - Closest rwi: 0.301
# Processed row 264 - Closest rwi: 0.301
# Processed row 265 - Closest rwi: 0.301
# Processed row 266 - Closest rwi: 0.301
# Processed row 267 - Closest rwi: 0.301
# Processed row 268 - Closest rwi: 0.005
# Processed row 269 - Closest rwi: 0.005
# Processed row 270 - Closest rwi: 0.005
# Processed row 271 - Closest rwi: 0.866
# Processed row 272 - Closest rwi: 0.866
# Processed row 273 - Closest rwi: 0.866
# Processed row 274 - Closest rwi: 0.544
# Processed row 275 - Closest rwi: 0.544
# Processed row 276 - Closest rwi: 0.544
# Processed row 277 - Closest rwi: 0.544
# Processed row 278 - Closest rwi: 0.544
# Processed row 279 - Closest rwi: 0.544
# Processed row 280 - Closest rwi: 0.406
# Processed row 281 - Closest rwi: 0.406
# Processed row 282 - Closest rwi: 0.645
# Processed row 283 - Closest rwi: 0.406
# Processed row 284 - Closest rwi: 0.406
# Processed row 285 - Closest rwi: 0.645
# Processed row 286 - Closest rwi: 0.406
# Processed row 287 - Closest rwi: 0.406
# Processed row 288 - Closest rwi: 0.645
# Processed row 289 - Closest rwi: -0.1
# Processed row 290 - Closest rwi: 0.338
# Processed row 291 - Closest rwi: 0.338
# Processed row 292 - Closest rwi: -0.1
# Processed row 293 - Closest rwi: 0.338
# Processed row 294 - Closest rwi: 0.338
# Processed row 295 - Closest rwi: 0.127
# Processed row 296 - Closest rwi: 0.325
# Processed row 297 - Closest rwi: 0.325
# Processed row 298 - Closest rwi: 0.25
# Processed row 299 - Closest rwi: -0.509
# Processed row 300 - Closest rwi: -0.509
# Processed row 301 - Closest rwi: 0.25
# Processed row 302 - Closest rwi: -0.509
# Processed row 303 - Closest rwi: -0.509
# Processed row 304 - Closest rwi: 0.747
# Processed row 305 - Closest rwi: 0.592
# Processed row 306 - Closest rwi: 0.592
# Processed row 307 - Closest rwi: 0.25
# Processed row 308 - Closest rwi: 0.25
# Processed row 309 - Closest rwi: 0.25
# Processed row 310 - Closest rwi: 0.25
# Processed row 311 - Closest rwi: 0.25
# Processed row 312 - Closest rwi: 0.25
# Processed row 313 - Closest rwi: 0.25
# Processed row 314 - Closest rwi: 0.25
# Processed row 315 - Closest rwi: 0.25
# Processed row 316 - Closest rwi: -0.03
# Processed row 317 - Closest rwi: -0.03
# Processed row 318 - Closest rwi: -0.03
# Processed row 319 - Closest rwi: -0.03
# Processed row 320 - Closest rwi: -0.03
# Processed row 321 - Closest rwi: -0.03
# Processed row 322 - Closest rwi: -0.03
# Processed row 323 - Closest rwi: -0.03
# Processed row 324 - Closest rwi: -0.03
# Processed row 325 - Closest rwi: 0.816
# Processed row 326 - Closest rwi: 0.816
# Processed row 327 - Closest rwi: 0.816
# Processed row 328 - Closest rwi: 0.816
# Processed row 329 - Closest rwi: 0.816
# Processed row 330 - Closest rwi: 0.816
# Processed row 331 - Closest rwi: 0.816
# Processed row 332 - Closest rwi: 0.816
# Processed row 333 - Closest rwi: 0.816
# Processed row 334 - Closest rwi: 0.319
# Processed row 335 - Closest rwi: 0.319
# Processed row 336 - Closest rwi: 0.319
# Processed row 337 - Closest rwi: 0.319
# Processed row 338 - Closest rwi: 0.319
# Processed row 339 - Closest rwi: 0.319
# Processed row 340 - Closest rwi: 0.319
# Processed row 341 - Closest rwi: 0.319
# Processed row 342 - Closest rwi: 0.319
# Processed row 343 - Closest rwi: 0.426
# Processed row 344 - Closest rwi: 0.426
# Processed row 345 - Closest rwi: 0.996
# Processed row 346 - Closest rwi: 0.426
# Processed row 347 - Closest rwi: 0.426
# Processed row 348 - Closest rwi: 0.996
# Processed row 349 - Closest rwi: 0.426
# Processed row 350 - Closest rwi: 0.426
# Processed row 351 - Closest rwi: 0.996
# Processed row 352 - Closest rwi: 0.318
# Processed row 353 - Closest rwi: 0.318
# Processed row 354 - Closest rwi: 0.318
# Processed row 355 - Closest rwi: 0.318
# Processed row 356 - Closest rwi: 0.318
# Processed row 357 - Closest rwi: 0.318
# Processed row 358 - Closest rwi: 0.318
# Processed row 359 - Closest rwi: 0.318
# Processed row 360 - Closest rwi: 0.318
# Processed row 361 - Closest rwi: 0.563
# Processed row 362 - Closest rwi: 0.563
# Processed row 363 - Closest rwi: 0.563
# Processed row 364 - Closest rwi: 0.563
# Processed row 365 - Closest rwi: 0.563
# Processed row 366 - Closest rwi: 0.563
# Processed row 367 - Closest rwi: 0.563
# Processed row 368 - Closest rwi: 0.563
# Processed row 369 - Closest rwi: 0.563
# Processed row 370 - Closest rwi: -0.137
# Processed row 371 - Closest rwi: 0.318
# Processed row 372 - Closest rwi: 0.318
# Processed row 373 - Closest rwi: -0.137
# Processed row 374 - Closest rwi: 0.318
# Processed row 375 - Closest rwi: 0.318
# Processed row 376 - Closest rwi: -0.137
# Processed row 377 - Closest rwi: 0.318
# Processed row 378 - Closest rwi: 0.318
# Processed row 379 - Closest rwi: 0.37
# Processed row 380 - Closest rwi: 0.37
# Processed row 381 - Closest rwi: 0.37
# Processed row 382 - Closest rwi: -0.35
# Processed row 383 - Closest rwi: -0.35
# Processed row 384 - Closest rwi: -0.35
# Processed row 385 - Closest rwi: -0.35
# Processed row 386 - Closest rwi: -0.35
# Processed row 387 - Closest rwi: -0.35
# Processed row 388 - Closest rwi: 0.25
# Processed row 389 - Closest rwi: 0.25
# Processed row 390 - Closest rwi: 0.25
# Processed row 391 - Closest rwi: 0.25
# Processed row 392 - Closest rwi: 0.25
# Processed row 393 - Closest rwi: 0.25
# Processed row 394 - Closest rwi: 0.25
# Processed row 395 - Closest rwi: 0.25
# Processed row 396 - Closest rwi: 0.25
# Processed row 397 - Closest rwi: 0.208
# Processed row 398 - Closest rwi: 0.208
# Processed row 399 - Closest rwi: 0.208
# Processed row 400 - Closest rwi: 0.208
# Processed row 401 - Closest rwi: 0.208
# Processed row 402 - Closest rwi: 0.208
# Processed row 403 - Closest rwi: 0.208
# Processed row 404 - Closest rwi: 0.208
# Processed row 405 - Closest rwi: 0.208
# Processed row 406 - Closest rwi: 0.557
# Processed row 407 - Closest rwi: 0.557
# Processed row 408 - Closest rwi: 0.557
# Processed row 409 - Closest rwi: 0.557
# Processed row 410 - Closest rwi: 0.557
# Processed row 411 - Closest rwi: 0.557
# Processed row 412 - Closest rwi: 0.557
# Processed row 413 - Closest rwi: 0.557
# Processed row 414 - Closest rwi: 0.557
# Processed row 415 - Closest rwi: 0.391
# Processed row 416 - Closest rwi: 0.391
# Processed row 417 - Closest rwi: 0.391
# Processed row 418 - Closest rwi: 0.391
# Processed row 419 - Closest rwi: 0.391
# Processed row 420 - Closest rwi: 0.391
# Processed row 421 - Closest rwi: 0.391
# Processed row 422 - Closest rwi: 0.391
# Processed row 423 - Closest rwi: 0.391
# Processed row 424 - Closest rwi: 0.454
# Processed row 425 - Closest rwi: 0.454
# Processed row 426 - Closest rwi: 0.777
# Processed row 427 - Closest rwi: 0.454
# Processed row 428 - Closest rwi: 0.454
# Processed row 429 - Closest rwi: 0.777
# Processed row 430 - Closest rwi: 0.454
# Processed row 431 - Closest rwi: 0.454
# Processed row 432 - Closest rwi: 0.777
# Processed row 433 - Closest rwi: 0.433
# Processed row 434 - Closest rwi: 0.433
# Processed row 435 - Closest rwi: 0.433
# Processed row 436 - Closest rwi: 0.433
# Processed row 437 - Closest rwi: 0.433
# Processed row 438 - Closest rwi: 0.433
# Processed row 439 - Closest rwi: 0.433
# Processed row 440 - Closest rwi: 0.433
# Processed row 441 - Closest rwi: 0.433
# Processed row 442 - Closest rwi: -0.136
# Processed row 443 - Closest rwi: 0.288
# Processed row 444 - Closest rwi: 0.288
# Processed row 445 - Closest rwi: 0.557
# Processed row 446 - Closest rwi: 0.185
# Processed row 447 - Closest rwi: 0.185
# Processed row 448 - Closest rwi: 0.557
# Processed row 449 - Closest rwi: 0.185
# Processed row 450 - Closest rwi: 0.185
# Processed row 451 - Closest rwi: -0.167
# Processed row 452 - Closest rwi: -0.167
# Processed row 453 - Closest rwi: 0.288
# Processed row 454 - Closest rwi: -0.167
# Processed row 455 - Closest rwi: -0.167
# Processed row 456 - Closest rwi: 0.288
# Processed row 457 - Closest rwi: -0.167
# Processed row 458 - Closest rwi: -0.167
# Processed row 459 - Closest rwi: 0.288
# Processed row 460 - Closest rwi: 0.746
# Processed row 461 - Closest rwi: 0.746
# Processed row 462 - Closest rwi: 0.746
# Processed row 463 - Closest rwi: 0.746
# Processed row 464 - Closest rwi: 0.746
# Processed row 465 - Closest rwi: 0.746
# Processed row 466 - Closest rwi: 0.746
# Processed row 467 - Closest rwi: 0.746
# Processed row 468 - Closest rwi: 0.746
# Processed row 469 - Closest rwi: 0.067
# Processed row 470 - Closest rwi: 0.067
# Processed row 471 - Closest rwi: 0.067
# Processed row 472 - Closest rwi: 0.067
# Processed row 473 - Closest rwi: 0.067
# Processed row 474 - Closest rwi: 0.067
# Processed row 475 - Closest rwi: 0.067
# Processed row 476 - Closest rwi: 0.067
# Processed row 477 - Closest rwi: 0.067
# Processed row 478 - Closest rwi: 0.49
# Processed row 479 - Closest rwi: 0.49
# Processed row 480 - Closest rwi: 0.3
# Processed row 481 - Closest rwi: 0.1
# Processed row 482 - Closest rwi: 0.1
# Processed row 483 - Closest rwi: 0.403
# Processed row 484 - Closest rwi: 0.1
# Processed row 485 - Closest rwi: 0.1
# Processed row 486 - Closest rwi: 0.403
# Processed row 487 - Closest rwi: -0.283
# Processed row 488 - Closest rwi: -0.283
# Processed row 489 - Closest rwi: -0.283
# Processed row 490 - Closest rwi: -0.283
# Processed row 491 - Closest rwi: -0.283
# Processed row 492 - Closest rwi: -0.283
# Processed row 493 - Closest rwi: -0.313
# Processed row 494 - Closest rwi: -0.313
# Processed row 495 - Closest rwi: -0.313
# Processed row 496 - Closest rwi: 0.348
# Processed row 497 - Closest rwi: 0.348
# Processed row 498 - Closest rwi: 0.348
# Processed row 499 - Closest rwi: 0.348
# Processed row 500 - Closest rwi: 0.348
# Processed row 501 - Closest rwi: 0.348
# Processed row 502 - Closest rwi: 0.348
# Processed row 503 - Closest rwi: 0.348
# Processed row 504 - Closest rwi: 0.348
# Processed row 505 - Closest rwi: 0.01
# Processed row 506 - Closest rwi: 0.01
# Processed row 507 - Closest rwi: 0.01
# Processed row 508 - Closest rwi: 0.01
# Processed row 509 - Closest rwi: 0.01
# Processed row 510 - Closest rwi: 0.01
# Processed row 511 - Closest rwi: 0.01
# Processed row 512 - Closest rwi: 0.01
# Processed row 513 - Closest rwi: 0.01
# Processed row 514 - Closest rwi: 0.873
# Processed row 515 - Closest rwi: 1.315
# Processed row 516 - Closest rwi: 1.315
# Processed row 517 - Closest rwi: 0.873
# Processed row 518 - Closest rwi: 1.315
# Processed row 519 - Closest rwi: 1.315
# Processed row 520 - Closest rwi: 0.873
# Processed row 521 - Closest rwi: 1.315
# Processed row 522 - Closest rwi: 1.315
# Processed row 523 - Closest rwi: 0.497
# Processed row 524 - Closest rwi: 0.497
# Processed row 525 - Closest rwi: 0.497
# Processed row 526 - Closest rwi: 0.497
# Processed row 527 - Closest rwi: 0.497
# Processed row 528 - Closest rwi: 0.497
# Processed row 529 - Closest rwi: 0.497
# Processed row 530 - Closest rwi: 0.497
# Processed row 531 - Closest rwi: 0.497
# Processed row 532 - Closest rwi: 0.22
# Processed row 533 - Closest rwi: 0.22
# Processed row 534 - Closest rwi: 0.22
# Processed row 535 - Closest rwi: 0.673
# Processed row 536 - Closest rwi: 0.673
# Processed row 537 - Closest rwi: 0.673
# Processed row 538 - Closest rwi: 0.673
# Processed row 539 - Closest rwi: 0.673
# Processed row 540 - Closest rwi: 0.673
# Processed row 541 - Closest rwi: -0.385
# Processed row 542 - Closest rwi: -0.385
# Processed row 543 - Closest rwi: -0.385
# Processed row 544 - Closest rwi: -0.385
# Processed row 545 - Closest rwi: -0.385
# Processed row 546 - Closest rwi: -0.385
# Processed row 547 - Closest rwi: -0.385
# Processed row 548 - Closest rwi: -0.385
# Processed row 549 - Closest rwi: -0.385
# Processed row 550 - Closest rwi: -0.064
# Processed row 551 - Closest rwi: 0.03
# Processed row 552 - Closest rwi: 0.03
# Processed row 553 - Closest rwi: -0.064
# Processed row 554 - Closest rwi: 0.03
# Processed row 555 - Closest rwi: 0.03
# Processed row 556 - Closest rwi: -0.064
# Processed row 557 - Closest rwi: 0.03
# Processed row 558 - Closest rwi: 0.03
# Processed row 559 - Closest rwi: 1.115
# Processed row 560 - Closest rwi: 1.115
# Processed row 561 - Closest rwi: 1.115
# Processed row 562 - Closest rwi: 1.115
# Processed row 563 - Closest rwi: 1.115
# Processed row 564 - Closest rwi: 1.115
# Processed row 565 - Closest rwi: 1.115
# Processed row 566 - Closest rwi: 1.115
# Processed row 567 - Closest rwi: 1.115
# Processed row 568 - Closest rwi: 0.668
# Processed row 569 - Closest rwi: 0.668
# Processed row 570 - Closest rwi: 0.668
# Processed row 571 - Closest rwi: 0.025
# Processed row 572 - Closest rwi: 0.025
# Processed row 573 - Closest rwi: 0.025
# Processed row 574 - Closest rwi: 0.025
# Processed row 575 - Closest rwi: 0.025
# Processed row 576 - Closest rwi: 0.025
# Processed row 577 - Closest rwi: 0.546
# Processed row 578 - Closest rwi: 0.546
# Processed row 579 - Closest rwi: 0.546
# Processed row 580 - Closest rwi: 0.546
# Processed row 581 - Closest rwi: 0.546
# Processed row 582 - Closest rwi: 0.546
# Processed row 583 - Closest rwi: 0.546
# Processed row 584 - Closest rwi: 0.546
# Processed row 585 - Closest rwi: 0.546
# Processed row 586 - Closest rwi: 1.125
# Processed row 587 - Closest rwi: 1.125
# Processed row 588 - Closest rwi: 1.125
# Processed row 589 - Closest rwi: 1.125
# Processed row 590 - Closest rwi: 1.125
# Processed row 591 - Closest rwi: 1.125
# Processed row 592 - Closest rwi: 1.125
# Processed row 593 - Closest rwi: 1.125
# Processed row 594 - Closest rwi: 1.125
# Processed row 595 - Closest rwi: 0.781
# Processed row 596 - Closest rwi: 0.781
# Processed row 597 - Closest rwi: 0.258
# Processed row 598 - Closest rwi: 0.781
# Processed row 599 - Closest rwi: 0.781
# Processed row 600 - Closest rwi: 0.258
# Processed row 601 - Closest rwi: 0.781
# Processed row 602 - Closest rwi: 0.781
# Processed row 603 - Closest rwi: 0.258
# Processed row 604 - Closest rwi: 0.174
# Processed row 605 - Closest rwi: 0.174
# Processed row 606 - Closest rwi: 0.174
# Processed row 607 - Closest rwi: 0.174
# Processed row 608 - Closest rwi: 0.174
# Processed row 609 - Closest rwi: 0.174
# Processed row 610 - Closest rwi: 0.174
# Processed row 611 - Closest rwi: 0.174
# Processed row 612 - Closest rwi: 0.174
# Processed row 613 - Closest rwi: 0.275
# Processed row 614 - Closest rwi: 0.275
# Processed row 615 - Closest rwi: 0.275
# Processed row 616 - Closest rwi: 0.275
# Processed row 617 - Closest rwi: 0.275
# Processed row 618 - Closest rwi: 0.275
# Processed row 619 - Closest rwi: 0.275
# Processed row 620 - Closest rwi: 0.275
# Processed row 621 - Closest rwi: 0.275
# Processed row 622 - Closest rwi: 0.048
# Processed row 623 - Closest rwi: 0.956
# Processed row 624 - Closest rwi: 0.956
# Processed row 625 - Closest rwi: 0.048
# Processed row 626 - Closest rwi: 0.956
# Processed row 627 - Closest rwi: 0.956
# Processed row 628 - Closest rwi: 0.048
# Processed row 629 - Closest rwi: 0.956
# Processed row 630 - Closest rwi: 0.956
# Processed row 631 - Closest rwi: -0.127
# Processed row 632 - Closest rwi: -0.127
# Processed row 633 - Closest rwi: -0.127
# Processed row 634 - Closest rwi: -0.127
# Processed row 635 - Closest rwi: -0.127
# Processed row 636 - Closest rwi: -0.127
# Processed row 637 - Closest rwi: -0.127
# Processed row 638 - Closest rwi: -0.127
# Processed row 639 - Closest rwi: -0.127
# Processed row 640 - Closest rwi: 0.711
# Processed row 641 - Closest rwi: 0.711
# Processed row 642 - Closest rwi: 0.703
# Processed row 643 - Closest rwi: 0.711
# Processed row 644 - Closest rwi: 0.711
# Processed row 645 - Closest rwi: 0.703
# Processed row 646 - Closest rwi: 0.711
# Processed row 647 - Closest rwi: 0.711
# Processed row 648 - Closest rwi: 0.703
# Processed row 649 - Closest rwi: 0.214
# Processed row 650 - Closest rwi: 0.557
# Processed row 651 - Closest rwi: 0.557
# Processed row 652 - Closest rwi: 0.719
# Processed row 653 - Closest rwi: -0.092
# Processed row 654 - Closest rwi: -0.092
# Processed row 655 - Closest rwi: 0.719
# Processed row 656 - Closest rwi: -0.092
# Processed row 657 - Closest rwi: -0.092
# Processed row 658 - Closest rwi: -0.104
# Processed row 659 - Closest rwi: 0.461
# Processed row 660 - Closest rwi: 0.461
# Processed row 661 - Closest rwi: -0.104
# Processed row 662 - Closest rwi: 0.461
# Processed row 663 - Closest rwi: 0.461
# Processed row 664 - Closest rwi: -0.104
# Processed row 665 - Closest rwi: 0.461
# Processed row 666 - Closest rwi: 0.461
# Processed row 667 - Closest rwi: 0.513
# Processed row 668 - Closest rwi: 0.513
# Processed row 669 - Closest rwi: 0.513
# Processed row 670 - Closest rwi: 0.513
# Processed row 671 - Closest rwi: 0.513
# Processed row 672 - Closest rwi: 0.513
# Processed row 673 - Closest rwi: 0.574
# Processed row 674 - Closest rwi: 0.574
# Processed row 675 - Closest rwi: 0.574
# Processed row 676 - Closest rwi: -0.401
# Processed row 677 - Closest rwi: -0.401
# Processed row 678 - Closest rwi: -0.401
# Processed row 679 - Closest rwi: -0.401
# Processed row 680 - Closest rwi: -0.401
# Processed row 681 - Closest rwi: -0.401
# Processed row 682 - Closest rwi: -0.401
# Processed row 683 - Closest rwi: -0.401
# Processed row 684 - Closest rwi: -0.401
# Processed row 685 - Closest rwi: 0.662
# Processed row 686 - Closest rwi: 0.662
# Processed row 687 - Closest rwi: 0.662
# Processed row 688 - Closest rwi: 0.809
# Processed row 689 - Closest rwi: 0.809
# Processed row 690 - Closest rwi: 0.809
# Processed row 691 - Closest rwi: 0.809
# Processed row 692 - Closest rwi: 0.809
# Processed row 693 - Closest rwi: 0.809
# Processed row 694 - Closest rwi: 0.699
# Processed row 695 - Closest rwi: 0.699
# Processed row 696 - Closest rwi: 0.699
# Processed row 697 - Closest rwi: 0.699
# Processed row 698 - Closest rwi: 0.699
# Processed row 699 - Closest rwi: 0.699
# Processed row 700 - Closest rwi: 0.699
# Processed row 701 - Closest rwi: 0.699
# Processed row 702 - Closest rwi: 0.699
# Processed row 703 - Closest rwi: 0.165
# Processed row 704 - Closest rwi: 0.165
# Processed row 705 - Closest rwi: 0.165
# Processed row 706 - Closest rwi: 0.165
# Processed row 707 - Closest rwi: 0.165
# Processed row 708 - Closest rwi: 0.165
# Processed row 709 - Closest rwi: 0.165
# Processed row 710 - Closest rwi: 0.165
# Processed row 711 - Closest rwi: 0.165
# Processed row 712 - Closest rwi: 0.304
# Processed row 713 - Closest rwi: 0.304
# Processed row 714 - Closest rwi: 0.304
# Processed row 715 - Closest rwi: 0.304
# Processed row 716 - Closest rwi: 0.304
# Processed row 717 - Closest rwi: 0.304
# Processed row 718 - Closest rwi: 0.304
# Processed row 719 - Closest rwi: 0.304
# Processed row 720 - Closest rwi: 0.304
# Processed row 721 - Closest rwi: 0.099
# Processed row 722 - Closest rwi: 0.099
# Processed row 723 - Closest rwi: 0.099
# Processed row 724 - Closest rwi: 0.099
# Processed row 725 - Closest rwi: 0.099
# Processed row 726 - Closest rwi: 0.099
# Processed row 727 - Closest rwi: 0.099
# Processed row 728 - Closest rwi: 0.099
# Processed row 729 - Closest rwi: 0.099
# Processed row 730 - Closest rwi: 0.942
# Processed row 731 - Closest rwi: 0.942
# Processed row 732 - Closest rwi: 0.942
# Processed row 733 - Closest rwi: 0.942
# Processed row 734 - Closest rwi: 0.942
# Processed row 735 - Closest rwi: 0.942
# Processed row 736 - Closest rwi: 0.942
# Processed row 737 - Closest rwi: 0.942
# Processed row 738 - Closest rwi: 0.942
# Processed row 739 - Closest rwi: 0.397
# Processed row 740 - Closest rwi: 0.397
# Processed row 741 - Closest rwi: -0.02
# Processed row 742 - Closest rwi: 0.397
# Processed row 743 - Closest rwi: 0.397
# Processed row 744 - Closest rwi: -0.02
# Processed row 745 - Closest rwi: 0.397
# Processed row 746 - Closest rwi: 0.397
# Processed row 747 - Closest rwi: -0.02
# Processed row 748 - Closest rwi: 0.312
# Processed row 749 - Closest rwi: 0.312
# Processed row 750 - Closest rwi: 0.312
# Processed row 751 - Closest rwi: 0.312
# Processed row 752 - Closest rwi: 0.312
# Processed row 753 - Closest rwi: 0.312
# Processed row 754 - Closest rwi: 0.312
# Processed row 755 - Closest rwi: 0.312
# Processed row 756 - Closest rwi: 0.312
# Processed row 757 - Closest rwi: 0.312
# Processed row 758 - Closest rwi: 0.312
# Processed row 759 - Closest rwi: 0.312
# Processed row 760 - Closest rwi: 0.312
# Processed row 761 - Closest rwi: 0.312
# Processed row 762 - Closest rwi: 0.312
# Processed row 763 - Closest rwi: 0.312
# Processed row 764 - Closest rwi: 0.312
# Processed row 765 - Closest rwi: 0.312
# Processed row 766 - Closest rwi: 0.015
# Processed row 767 - Closest rwi: 0.355
# Processed row 768 - Closest rwi: 0.355
# Processed row 769 - Closest rwi: 0.015
# Processed row 770 - Closest rwi: 0.355
# Processed row 771 - Closest rwi: 0.355
# Processed row 772 - Closest rwi: 0.015
# Processed row 773 - Closest rwi: 0.355
# Processed row 774 - Closest rwi: 0.355
# Processed row 775 - Closest rwi: 0.275
# Processed row 776 - Closest rwi: 0.112
# Processed row 777 - Closest rwi: 0.112
# Processed row 778 - Closest rwi: 0.275
# Processed row 779 - Closest rwi: 0.112
# Processed row 780 - Closest rwi: 0.112
# Processed row 781 - Closest rwi: 0.275
# Processed row 782 - Closest rwi: 0.112
# Processed row 783 - Closest rwi: 0.112
# Processed row 784 - Closest rwi: 0.358
# Processed row 785 - Closest rwi: 0.358
# Processed row 786 - Closest rwi: 0.358
# Processed row 787 - Closest rwi: 0.358
# Processed row 788 - Closest rwi: 0.358
# Processed row 789 - Closest rwi: 0.358
# Processed row 790 - Closest rwi: 0.501
# Processed row 791 - Closest rwi: 0.501
# Processed row 792 - Closest rwi: 0.501
# Processed row 793 - Closest rwi: 0.509
# Processed row 794 - Closest rwi: 0.139
# Processed row 795 - Closest rwi: 0.139
# Processed row 796 - Closest rwi: 0.509
# Processed row 797 - Closest rwi: 0.139
# Processed row 798 - Closest rwi: 0.139
# Processed row 799 - Closest rwi: 0.509
# Processed row 800 - Closest rwi: 0.139
# Processed row 801 - Closest rwi: 0.139
# Processed row 802 - Closest rwi: 0.369
# Processed row 803 - Closest rwi: 0.369
# Processed row 804 - Closest rwi: 0.369
# Processed row 805 - Closest rwi: 0.369
# Processed row 806 - Closest rwi: 0.369
# Processed row 807 - Closest rwi: 0.369
# Processed row 808 - Closest rwi: 0.369
# Processed row 809 - Closest rwi: 0.369
# Processed row 810 - Closest rwi: 0.369
# Processed row 811 - Closest rwi: 0.148
# Processed row 812 - Closest rwi: 0.17
# Processed row 813 - Closest rwi: 0.17
# Processed row 814 - Closest rwi: 0.148
# Processed row 815 - Closest rwi: 0.17
# Processed row 816 - Closest rwi: 0.17
# Processed row 817 - Closest rwi: 0.148
# Processed row 818 - Closest rwi: 0.17
# Processed row 819 - Closest rwi: 0.17
# Processed row 820 - Closest rwi: 0.407
# Processed row 821 - Closest rwi: 0.407
# Processed row 822 - Closest rwi: 0.407
# Processed row 823 - Closest rwi: 0.407
# Processed row 824 - Closest rwi: 0.407
# Processed row 825 - Closest rwi: 0.407
# Processed row 826 - Closest rwi: 0.407
# Processed row 827 - Closest rwi: 0.407
# Processed row 828 - Closest rwi: 0.407
# Processed row 829 - Closest rwi: 0.639
# Processed row 830 - Closest rwi: 0.639
# Processed row 831 - Closest rwi: 0.331
# Processed row 832 - Closest rwi: 0.639
# Processed row 833 - Closest rwi: 0.639
# Processed row 834 - Closest rwi: 0.331
# Processed row 835 - Closest rwi: -0.354
# Processed row 836 - Closest rwi: -0.354
# Processed row 837 - Closest rwi: -0.124
# Processed row 838 - Closest rwi: 0.829
# Processed row 839 - Closest rwi: 0.829
# Processed row 840 - Closest rwi: 0.829
# Processed row 841 - Closest rwi: 0.829
# Processed row 842 - Closest rwi: 0.829
# Processed row 843 - Closest rwi: 0.829
# Processed row 844 - Closest rwi: 0.829
# Processed row 845 - Closest rwi: 0.829
# Processed row 846 - Closest rwi: 0.829
# Processed row 847 - Closest rwi: 0.107
# Processed row 848 - Closest rwi: 0.523
# Processed row 849 - Closest rwi: 0.523
# Processed row 850 - Closest rwi: 0.539
# Processed row 851 - Closest rwi: 0.023
# Processed row 852 - Closest rwi: 0.023
# Processed row 853 - Closest rwi: 0.539
# Processed row 854 - Closest rwi: 0.023
# Processed row 855 - Closest rwi: 0.023
# Processed row 856 - Closest rwi: -0.155
# Processed row 857 - Closest rwi: -0.155
# Processed row 858 - Closest rwi: -0.155
# Processed row 859 - Closest rwi: -0.155
# Processed row 860 - Closest rwi: -0.155
# Processed row 861 - Closest rwi: -0.155
# Processed row 862 - Closest rwi: -0.155
# Processed row 863 - Closest rwi: -0.155
# Processed row 864 - Closest rwi: -0.155
# Processed row 865 - Closest rwi: 1.115
# Processed row 866 - Closest rwi: 1.115
# Processed row 867 - Closest rwi: 1.115
# Processed row 868 - Closest rwi: 1.115
# Processed row 869 - Closest rwi: 1.115
# Processed row 870 - Closest rwi: 1.115
# Processed row 871 - Closest rwi: 1.115
# Processed row 872 - Closest rwi: 1.115
# Processed row 873 - Closest rwi: 1.115
# Processed row 874 - Closest rwi: 0.692
# Processed row 875 - Closest rwi: 0.692
# Processed row 876 - Closest rwi: 0.692
# Processed row 877 - Closest rwi: 0.692
# Processed row 878 - Closest rwi: 0.692
# Processed row 879 - Closest rwi: 0.692
# Processed row 880 - Closest rwi: 0.692
# Processed row 881 - Closest rwi: 0.692
# Processed row 882 - Closest rwi: 0.692
# Processed row 883 - Closest rwi: 0.399
# Processed row 884 - Closest rwi: 0.399
# Processed row 885 - Closest rwi: 0.399
# Processed row 886 - Closest rwi: 0.399
# Processed row 887 - Closest rwi: 0.399
# Processed row 888 - Closest rwi: 0.399
# Processed row 889 - Closest rwi: 0.399
# Processed row 890 - Closest rwi: 0.399
# Processed row 891 - Closest rwi: 0.399
# Processed row 892 - Closest rwi: 0.167
# Processed row 893 - Closest rwi: 0.36
# Processed row 894 - Closest rwi: 0.36
# Processed row 895 - Closest rwi: 0.167
# Processed row 896 - Closest rwi: 0.36
# Processed row 897 - Closest rwi: 0.36
# Processed row 898 - Closest rwi: 0.167
# Processed row 899 - Closest rwi: 0.36
# Processed row 900 - Closest rwi: 0.36
# Processed row 901 - Closest rwi: 1.024
# Processed row 902 - Closest rwi: 1.024
# Processed row 903 - Closest rwi: 1.024
# Processed row 904 - Closest rwi: 1.024
# Processed row 905 - Closest rwi: 1.024
# Processed row 906 - Closest rwi: 1.024
# Processed row 907 - Closest rwi: 1.024
# Processed row 908 - Closest rwi: 1.024
# Processed row 909 - Closest rwi: 1.024
# Processed row 910 - Closest rwi: 0.294
# Processed row 911 - Closest rwi: -0.028
# Processed row 912 - Closest rwi: -0.028
# Processed row 913 - Closest rwi: -0.082
# Processed row 914 - Closest rwi: -0.487
# Processed row 915 - Closest rwi: -0.487
# Processed row 916 - Closest rwi: -0.082
# Processed row 917 - Closest rwi: -0.487
# Processed row 918 - Closest rwi: -0.487
# Processed row 919 - Closest rwi: 0.011
# Processed row 920 - Closest rwi: 0.011
# Processed row 921 - Closest rwi: 0.263
# Processed row 922 - Closest rwi: 0.011
# Processed row 923 - Closest rwi: 0.011
# Processed row 924 - Closest rwi: 0.263
# Processed row 925 - Closest rwi: 0.011
# Processed row 926 - Closest rwi: 0.011
# Processed row 927 - Closest rwi: 0.263
# Processed row 928 - Closest rwi: 0.958
# Processed row 929 - Closest rwi: 0.958
# Processed row 930 - Closest rwi: 0.958
# Processed row 931 - Closest rwi: 0.517
# Processed row 932 - Closest rwi: 0.517
# Processed row 933 - Closest rwi: 0.517
# Processed row 934 - Closest rwi: 0.517
# Processed row 935 - Closest rwi: 0.517
# Processed row 936 - Closest rwi: 0.517
# Processed row 937 - Closest rwi: 0.604
# Processed row 938 - Closest rwi: 0.604
# Processed row 939 - Closest rwi: 0.604
# Processed row 940 - Closest rwi: 0.604
# Processed row 941 - Closest rwi: 0.604
# Processed row 942 - Closest rwi: 0.604
# Processed row 943 - Closest rwi: 0.604
# Processed row 944 - Closest rwi: 0.604
# Processed row 945 - Closest rwi: 0.604
# Processed row 946 - Closest rwi: 0.665
# Processed row 947 - Closest rwi: 0.742
# Processed row 948 - Closest rwi: 0.742
# Processed row 949 - Closest rwi: 0.665
# Processed row 950 - Closest rwi: 0.742
# Processed row 951 - Closest rwi: 0.742
# Processed row 952 - Closest rwi: 0.665
# Processed row 953 - Closest rwi: 0.742
# Processed row 954 - Closest rwi: 0.742
# Processed row 955 - Closest rwi: 0.901
# Processed row 956 - Closest rwi: 0.901
# Processed row 957 - Closest rwi: 0.901
# Processed row 958 - Closest rwi: 0.901
# Processed row 959 - Closest rwi: 0.901
# Processed row 960 - Closest rwi: 0.901
# Processed row 961 - Closest rwi: 0.901
# Processed row 962 - Closest rwi: 0.901
# Processed row 963 - Closest rwi: 0.901
# Processed row 964 - Closest rwi: 0.528
# Processed row 965 - Closest rwi: 1.3
# Processed row 966 - Closest rwi: 1.3
# Processed row 967 - Closest rwi: 0.528
# Processed row 968 - Closest rwi: 1.3
# Processed row 969 - Closest rwi: 1.3
# Processed row 970 - Closest rwi: 0.528
# Processed row 971 - Closest rwi: 1.3
# Processed row 972 - Closest rwi: 1.3
# Processed row 973 - Closest rwi: 0.685
# Processed row 974 - Closest rwi: 0.685
# Processed row 975 - Closest rwi: 0.685
# Processed row 976 - Closest rwi: 0.102
# Processed row 977 - Closest rwi: 0.102
# Processed row 978 - Closest rwi: 0.102
# Processed row 979 - Closest rwi: 0.102
# Processed row 980 - Closest rwi: 0.102
# Processed row 981 - Closest rwi: 0.102
# Processed row 982 - Closest rwi: -0.005
# Processed row 983 - Closest rwi: -0.005
# Processed row 984 - Closest rwi: -0.005
# Processed row 985 - Closest rwi: -0.005
# Processed row 986 - Closest rwi: -0.005
# Processed row 987 - Closest rwi: -0.005
# Processed row 988 - Closest rwi: -0.005
# Processed row 989 - Closest rwi: -0.005
# Processed row 990 - Closest rwi: -0.005
# Processed row 991 - Closest rwi: -0.406
# Processed row 992 - Closest rwi: -0.406
# Processed row 993 - Closest rwi: -0.406
# Processed row 994 - Closest rwi: 0.056
# Processed row 995 - Closest rwi: 0.056
# Processed row 996 - Closest rwi: 0.056
# Processed row 997 - Closest rwi: 0.056
# Processed row 998 - Closest rwi: 0.056
# Processed row 999 - Closest rwi: 0.056
# Processed row 1000 - Closest rwi: 0.789
# Processed row 1001 - Closest rwi: 0.75
# Processed row 1002 - Closest rwi: 0.75
# Processed row 1003 - Closest rwi: 0.789
# Processed row 1004 - Closest rwi: 0.75
# Processed row 1005 - Closest rwi: 0.75
# Processed row 1006 - Closest rwi: 0.789
# Processed row 1007 - Closest rwi: 0.75
# Processed row 1008 - Closest rwi: 0.75
# Processed row 1009 - Closest rwi: -0.497
# Processed row 1010 - Closest rwi: -0.497
# Processed row 1011 - Closest rwi: -0.497
# Processed row 1012 - Closest rwi: -0.497
# Processed row 1013 - Closest rwi: -0.497
# Processed row 1014 - Closest rwi: -0.497
# Processed row 1015 - Closest rwi: -0.497
# Processed row 1016 - Closest rwi: -0.497
# Processed row 1017 - Closest rwi: -0.497
# Processed row 1018 - Closest rwi: -0.3
# Processed row 1019 - Closest rwi: -0.3
# Processed row 1020 - Closest rwi: 0.046
# Processed row 1021 - Closest rwi: -0.3
# Processed row 1022 - Closest rwi: -0.3
# Processed row 1023 - Closest rwi: 0.046
# Processed row 1024 - Closest rwi: -0.3
# Processed row 1025 - Closest rwi: -0.3
# Processed row 1026 - Closest rwi: 0.046
# Processed row 1027 - Closest rwi: 0.446
# Processed row 1028 - Closest rwi: 0.446
# Processed row 1029 - Closest rwi: 0.446
# Processed row 1030 - Closest rwi: 0.446
# Processed row 1031 - Closest rwi: 0.446
# Processed row 1032 - Closest rwi: 0.446
# Processed row 1033 - Closest rwi: 0.446
# Processed row 1034 - Closest rwi: 0.446
# Processed row 1035 - Closest rwi: 0.446
# Processed row 1036 - Closest rwi: -0.426
# Processed row 1037 - Closest rwi: -0.426
# Processed row 1038 - Closest rwi: 0.237
# Processed row 1039 - Closest rwi: -0.426
# Processed row 1040 - Closest rwi: -0.426
# Processed row 1041 - Closest rwi: 0.237
# Processed row 1042 - Closest rwi: -0.475
# Processed row 1043 - Closest rwi: -0.475
# Processed row 1044 - Closest rwi: -0.268
# Processed row 1045 - Closest rwi: 0.395
# Processed row 1046 - Closest rwi: 0.395
# Processed row 1047 - Closest rwi: 0.395
# Processed row 1048 - Closest rwi: 0.395
# Processed row 1049 - Closest rwi: 0.395
# Processed row 1050 - Closest rwi: 0.395
# Processed row 1051 - Closest rwi: 0.395
# Processed row 1052 - Closest rwi: 0.395
# Processed row 1053 - Closest rwi: 0.395
# Processed row 1054 - Closest rwi: -0.137
# Processed row 1055 - Closest rwi: -0.137
# Processed row 1056 - Closest rwi: -0.137
# Processed row 1057 - Closest rwi: -0.137
# Processed row 1058 - Closest rwi: -0.137
# Processed row 1059 - Closest rwi: -0.137
# Processed row 1060 - Closest rwi: -0.137
# Processed row 1061 - Closest rwi: -0.137
# Processed row 1062 - Closest rwi: -0.137
# Processed row 1063 - Closest rwi: 0.645
# Processed row 1064 - Closest rwi: 0.512
# Processed row 1065 - Closest rwi: 0.512
# Processed row 1066 - Closest rwi: 0.645
# Processed row 1067 - Closest rwi: 0.512
# Processed row 1068 - Closest rwi: 0.512
# Processed row 1069 - Closest rwi: 0.645
# Processed row 1070 - Closest rwi: 0.512
# Processed row 1071 - Closest rwi: 0.512
# Processed row 1072 - Closest rwi: 0.976
# Processed row 1073 - Closest rwi: 0.976
# Processed row 1074 - Closest rwi: 0.976
# Processed row 1075 - Closest rwi: 0.976
# Processed row 1076 - Closest rwi: 0.976
# Processed row 1077 - Closest rwi: 0.976
# Processed row 1078 - Closest rwi: 0.976
# Processed row 1079 - Closest rwi: 0.976
# Processed row 1080 - Closest rwi: 0.976
# Processed row 1081 - Closest rwi: 0.204
# Processed row 1082 - Closest rwi: 0.204
# Processed row 1083 - Closest rwi: 0.204
# Processed row 1084 - Closest rwi: 0.204
# Processed row 1085 - Closest rwi: 0.204
# Processed row 1086 - Closest rwi: 0.204
# Processed row 1087 - Closest rwi: 0.204
# Processed row 1088 - Closest rwi: 0.204
# Processed row 1089 - Closest rwi: 0.204
# Processed row 1090 - Closest rwi: -0.142
# Processed row 1091 - Closest rwi: -0.142
# Processed row 1092 - Closest rwi: -0.601
# Processed row 1093 - Closest rwi: -0.142
# Processed row 1094 - Closest rwi: -0.142
# Processed row 1095 - Closest rwi: -0.601
# Processed row 1096 - Closest rwi: -0.142
# Processed row 1097 - Closest rwi: -0.142
# Processed row 1098 - Closest rwi: -0.601
# Processed row 1099 - Closest rwi: 0.062
# Processed row 1100 - Closest rwi: 0.062
# Processed row 1101 - Closest rwi: 0.062
# Processed row 1102 - Closest rwi: 0.164
# Processed row 1103 - Closest rwi: 0.164
# Processed row 1104 - Closest rwi: 0.164
# Processed row 1105 - Closest rwi: 0.164
# Processed row 1106 - Closest rwi: 0.164
# Processed row 1107 - Closest rwi: 0.164
# Processed row 1108 - Closest rwi: -0.203
# Processed row 1109 - Closest rwi: -0.203
# Processed row 1110 - Closest rwi: -0.203
# Processed row 1111 - Closest rwi: -0.203
# Processed row 1112 - Closest rwi: -0.203
# Processed row 1113 - Closest rwi: -0.203
# Processed row 1114 - Closest rwi: -0.203
# Processed row 1115 - Closest rwi: -0.203
# Processed row 1116 - Closest rwi: -0.203
# Processed row 1117 - Closest rwi: 0.172
# Processed row 1118 - Closest rwi: 0.172
# Processed row 1119 - Closest rwi: 0.373
# Processed row 1120 - Closest rwi: 0.67
# Processed row 1121 - Closest rwi: 0.373
# Processed row 1122 - Closest rwi: 0.373
# Processed row 1123 - Closest rwi: 0.373
# Processed row 1124 - Closest rwi: 0.373
# Processed row 1125 - Closest rwi: 0.373
# Processed row 1126 - Closest rwi: 0.466
# Processed row 1127 - Closest rwi: 0.466
# Processed row 1128 - Closest rwi: 0.466
# Processed row 1129 - Closest rwi: 0.466
# Processed row 1130 - Closest rwi: 0.466
# Processed row 1131 - Closest rwi: 0.466
# Processed row 1132 - Closest rwi: 0.466
# Processed row 1133 - Closest rwi: 0.466
# Processed row 1134 - Closest rwi: 0.466
# Processed row 1135 - Closest rwi: 0.407
# Processed row 1136 - Closest rwi: 0.407
# Processed row 1137 - Closest rwi: 0.407
# Processed row 1138 - Closest rwi: 0.407
# Processed row 1139 - Closest rwi: 0.407
# Processed row 1140 - Closest rwi: 0.407
# Processed row 1141 - Closest rwi: 0.407
# Processed row 1142 - Closest rwi: 0.407
# Processed row 1143 - Closest rwi: 0.407
# Processed row 1144 - Closest rwi: 0.544
# Processed row 1145 - Closest rwi: 0.231
# Processed row 1146 - Closest rwi: 0.231
# Processed row 1147 - Closest rwi: 0.381
# Processed row 1148 - Closest rwi: 0.235
# Processed row 1149 - Closest rwi: 0.235
# Processed row 1150 - Closest rwi: 0.381
# Processed row 1151 - Closest rwi: 0.235
# Processed row 1152 - Closest rwi: 0.235
# Processed row 1153 - Closest rwi: 0.381
# Processed row 1154 - Closest rwi: 0.381
# Processed row 1155 - Closest rwi: 0.381
# Processed row 1156 - Closest rwi: 0.381
# Processed row 1157 - Closest rwi: 0.381
# Processed row 1158 - Closest rwi: 0.381
# Processed row 1159 - Closest rwi: 0.381
# Processed row 1160 - Closest rwi: 0.381
# Processed row 1161 - Closest rwi: 0.381
# Processed row 1162 - Closest rwi: -0.018
# Processed row 1163 - Closest rwi: -0.018
# Processed row 1164 - Closest rwi: 0.547
# Processed row 1165 - Closest rwi: -0.018
# Processed row 1166 - Closest rwi: -0.018
# Processed row 1167 - Closest rwi: 0.547
# Processed row 1168 - Closest rwi: -0.018
# Processed row 1169 - Closest rwi: -0.018
# Processed row 1170 - Closest rwi: 0.547
# Processed row 1171 - Closest rwi: 0.463
# Processed row 1172 - Closest rwi: 0.463
# Processed row 1173 - Closest rwi: 0.463
# Processed row 1174 - Closest rwi: 0.463
# Processed row 1175 - Closest rwi: 0.463
# Processed row 1176 - Closest rwi: 0.463
# Processed row 1177 - Closest rwi: 0.463
# Processed row 1178 - Closest rwi: 0.463
# Processed row 1179 - Closest rwi: 0.463
# Processed row 1180 - Closest rwi: -0.077
# Processed row 1181 - Closest rwi: 0.431
# Processed row 1182 - Closest rwi: 0.431
# Processed row 1183 - Closest rwi: -0.077
# Processed row 1184 - Closest rwi: 0.431
# Processed row 1185 - Closest rwi: 0.431
# Processed row 1186 - Closest rwi: -0.077
# Processed row 1187 - Closest rwi: 0.431
# Processed row 1188 - Closest rwi: 0.431
# Processed row 1189 - Closest rwi: -0.092
# Processed row 1190 - Closest rwi: -0.092
# Processed row 1191 - Closest rwi: -0.092
# Processed row 1192 - Closest rwi: -0.092
# Processed row 1193 - Closest rwi: -0.092
# Processed row 1194 - Closest rwi: -0.092
# Processed row 1195 - Closest rwi: -0.092
# Processed row 1196 - Closest rwi: -0.092
# Processed row 1197 - Closest rwi: -0.092
# Processed row 1198 - Closest rwi: 0.125
# Processed row 1199 - Closest rwi: 0.125
# Processed row 1200 - Closest rwi: 0.125
# Processed row 1201 - Closest rwi: 0.125
# Processed row 1202 - Closest rwi: 0.125
# Processed row 1203 - Closest rwi: 0.125
# Processed row 1204 - Closest rwi: 0.303
# Processed row 1205 - Closest rwi: 0.303
# Processed row 1206 - Closest rwi: 0.303
# Processed row 1207 - Closest rwi: 0.07
# Processed row 1208 - Closest rwi: 0.07
# Processed row 1209 - Closest rwi: 0.929
# Processed row 1210 - Closest rwi: 0.07
# Processed row 1211 - Closest rwi: 0.07
# Processed row 1212 - Closest rwi: 0.929
# Processed row 1213 - Closest rwi: 0.07
# Processed row 1214 - Closest rwi: 0.07
# Processed row 1215 - Closest rwi: 0.929
# Processed row 1216 - Closest rwi: 0.428
# Processed row 1217 - Closest rwi: 0.428
# Processed row 1218 - Closest rwi: -0.067
# Processed row 1219 - Closest rwi: 0.281
# Processed row 1220 - Closest rwi: 0.281
# Processed row 1221 - Closest rwi: -0.072
# Processed row 1222 - Closest rwi: 0.281
# Processed row 1223 - Closest rwi: 0.281
# Processed row 1224 - Closest rwi: -0.072
# Processed row 1225 - Closest rwi: 0.258
# ...
# Processed row 4104 - Closest rwi: 0.124
# Processed row 4105 - Closest rwi: 0.276
# Processed row 4106 - Closest rwi: 0.276
# Processed row 4107 - Closest rwi: 0.658
# Processed row 4108 - Closest rwi: 0.276
# Processed row 4109 - Closest rwi: 0.276
# Processed row 4110 - Closest rwi: 0.658
# Processed row 4111 - Closest rwi: 0.276
# Processed row 4112 - Closest rwi: 0.276
# Processed row 4113 - Closest rwi: 0.658
# Processed row 4114 - Closest rwi: 0.352
# Processed row 4115 - Closest rwi: 0.352
# Processed row 4116 - Closest rwi: 0.352
# Processed row 4117 - Closest rwi: 0.352
# Processed row 4118 - Closest rwi: 0.352
# Processed row 4119 - Closest rwi: 0.352
# Processed row 4120 - Closest rwi: 0.352
# Processed row 4121 - Closest rwi: 0.352
# Processed row 4122 - Closest rwi: 0.352
# Processed row 4123 - Closest rwi: 0.491
# Processed row 4124 - Closest rwi: 0.491
# Processed row 4125 - Closest rwi: 0.491
# Processed row 4126 - Closest rwi: 0.491
# Processed row 4127 - Closest rwi: 0.491
# Processed row 4128 - Closest rwi: 0.491
# Processed row 4129 - Closest rwi: 0.491
# Processed row 4130 - Closest rwi: 0.491
# Processed row 4131 - Closest rwi: 0.491
# Processed row 4132 - Closest rwi: 0.693
# Processed row 4133 - Closest rwi: 0.693
# Processed row 4134 - Closest rwi: 0.53
# Processed row 4135 - Closest rwi: 0.693
# Processed row 4136 - Closest rwi: 0.693
# Processed row 4137 - Closest rwi: 0.53
# Processed row 4138 - Closest rwi: 0.693
# Processed row 4139 - Closest rwi: 0.693
# Processed row 4140 - Closest rwi: 0.53
# Processed row 4141 - Closest rwi: 0.4
# Processed row 4142 - Closest rwi: 0.4
# Processed row 4143 - Closest rwi: 0.4
# Processed row 4144 - Closest rwi: 0.4
# Processed row 4145 - Closest rwi: 0.4
# Processed row 4146 - Closest rwi: 0.4
# Processed row 4147 - Closest rwi: 0.4
# Processed row 4148 - Closest rwi: 0.4
# Processed row 4149 - Closest rwi: 0.4
# Processed row 4150 - Closest rwi: 0.502
# Processed row 4151 - Closest rwi: 0.395
# Processed row 4152 - Closest rwi: 0.395
# Processed row 4153 - Closest rwi: 0.502
# Processed row 4154 - Closest rwi: 0.395
# Processed row 4155 - Closest rwi: 0.395
# Processed row 4156 - Closest rwi: 0.533
# Processed row 4157 - Closest rwi: 0.015
# Processed row 4158 - Closest rwi: 0.015
# Processed row 4159 - Closest rwi: 0.262
# Processed row 4160 - Closest rwi: 0.262
# Processed row 4161 - Closest rwi: 0.262
# Processed row 4162 - Closest rwi: 0.262
# Processed row 4163 - Closest rwi: 0.262
# Processed row 4164 - Closest rwi: 0.262
# Processed row 4165 - Closest rwi: 0.262
# Processed row 4166 - Closest rwi: 0.262
# Processed row 4167 - Closest rwi: 0.262
# Processed row 4168 - Closest rwi: 0.06
# Processed row 4169 - Closest rwi: 0.06
# Processed row 4170 - Closest rwi: 0.06
# Processed row 4171 - Closest rwi: 0.06
# Processed row 4172 - Closest rwi: 0.06
# Processed row 4173 - Closest rwi: 0.06
# Processed row 4174 - Closest rwi: 0.06
# Processed row 4175 - Closest rwi: 0.06
# Processed row 4176 - Closest rwi: 0.06
# Processed row 4177 - Closest rwi: 0.311
# Processed row 4178 - Closest rwi: 0.311
# Processed row 4179 - Closest rwi: -0.511
# Processed row 4180 - Closest rwi: 0.311
# Processed row 4181 - Closest rwi: 0.311
# Processed row 4182 - Closest rwi: -0.511
# Processed row 4183 - Closest rwi: 0.311
# Processed row 4184 - Closest rwi: 0.311
# Processed row 4185 - Closest rwi: -0.511
# Processed row 4186 - Closest rwi: 0.311
# Processed row 4187 - Closest rwi: 0.311
# Processed row 4188 - Closest rwi: 0.311
# Processed row 4189 - Closest rwi: -0.183
# Processed row 4190 - Closest rwi: -0.183
# Processed row 4191 - Closest rwi: -0.183
# Processed row 4192 - Closest rwi: -0.183
# Processed row 4193 - Closest rwi: -0.183
# Processed row 4194 - Closest rwi: -0.183
# Processed row 4195 - Closest rwi: 0.606
# Processed row 4196 - Closest rwi: 0.606
# Processed row 4197 - Closest rwi: 0.606
# Processed row 4198 - Closest rwi: 0.606
# Processed row 4199 - Closest rwi: 0.606
# Processed row 4200 - Closest rwi: 0.606
# Processed row 4201 - Closest rwi: 0.606
# Processed row 4202 - Closest rwi: 0.606
# Processed row 4203 - Closest rwi: 0.606
# Processed row 4204 - Closest rwi: 0.323
# Processed row 4205 - Closest rwi: 0.323
# Processed row 4206 - Closest rwi: 0.323
# Processed row 4207 - Closest rwi: 0.323
# Processed row 4208 - Closest rwi: 0.323
# Processed row 4209 - Closest rwi: 0.323
# Processed row 4210 - Closest rwi: 0.323
# Processed row 4211 - Closest rwi: 0.323
# Processed row 4212 - Closest rwi: 0.323
# Processed row 4213 - Closest rwi: 0.517
# Processed row 4214 - Closest rwi: 0.016
# Processed row 4215 - Closest rwi: 0.016
# Processed row 4216 - Closest rwi: -0.041
# Processed row 4217 - Closest rwi: 0.315
# Processed row 4218 - Closest rwi: 0.315
# Processed row 4219 - Closest rwi: -0.041
# Processed row 4220 - Closest rwi: 0.315
# Processed row 4221 - Closest rwi: 0.315
# Processed row 4222 - Closest rwi: 0.367
# Processed row 4223 - Closest rwi: 0.501
# Processed row 4224 - Closest rwi: 0.501
# Processed row 4225 - Closest rwi: 0.367
# Processed row 4226 - Closest rwi: 0.501
# Processed row 4227 - Closest rwi: 0.501
# Processed row 4228 - Closest rwi: 0.367
# Processed row 4229 - Closest rwi: 0.501
# Processed row 4230 - Closest rwi: 0.501
# Processed row 4231 - Closest rwi: 0.034
# Processed row 4232 - Closest rwi: 0.034
# Processed row 4233 - Closest rwi: 0.034
# Processed row 4234 - Closest rwi: 0.034
# Processed row 4235 - Closest rwi: 0.034
# Processed row 4236 - Closest rwi: 0.034
# Processed row 4237 - Closest rwi: 0.034
# Processed row 4238 - Closest rwi: 0.034
# Processed row 4239 - Closest rwi: 0.034
# Processed row 4240 - Closest rwi: 0.179
# Processed row 4241 - Closest rwi: 0.179
# Processed row 4242 - Closest rwi: 0.142
# Processed row 4243 - Closest rwi: 0.179
# Processed row 4244 - Closest rwi: 0.179
# Processed row 4245 - Closest rwi: 0.142
# Processed row 4246 - Closest rwi: 0.179
# Processed row 4247 - Closest rwi: 0.179
# Processed row 4248 - Closest rwi: 0.142
# Processed row 4249 - Closest rwi: 0.421
# Processed row 4250 - Closest rwi: 0.421
# Processed row 4251 - Closest rwi: 0.421
# Processed row 4252 - Closest rwi: 0.421
# Processed row 4253 - Closest rwi: 0.421
# Processed row 4254 - Closest rwi: 0.421
# Processed row 4255 - Closest rwi: 0.421
# Processed row 4256 - Closest rwi: 0.421
# Processed row 4257 - Closest rwi: 0.421
# Processed row 4258 - Closest rwi: 0.518
# Processed row 4259 - Closest rwi: 0.518
# Processed row 4260 - Closest rwi: 0.518
# Processed row 4261 - Closest rwi: 0.518
# Processed row 4262 - Closest rwi: 0.518
# Processed row 4263 - Closest rwi: 0.518
# Processed row 4264 - Closest rwi: 0.518
# Processed row 4265 - Closest rwi: 0.518
# Processed row 4266 - Closest rwi: 0.518
# Processed row 4267 - Closest rwi: 0.272
# Processed row 4268 - Closest rwi: 0.272
# Processed row 4269 - Closest rwi: 0.272
# Processed row 4270 - Closest rwi: 0.272
# Processed row 4271 - Closest rwi: 0.272
# Processed row 4272 - Closest rwi: 0.272
# Processed row 4273 - Closest rwi: 0.272
# Processed row 4274 - Closest rwi: 0.272
# Processed row 4275 - Closest rwi: 0.272
# Processed row 4276 - Closest rwi: 0.563
# Processed row 4277 - Closest rwi: 0.563
# Processed row 4278 - Closest rwi: 0.219
# Processed row 4279 - Closest rwi: 0.563
# Processed row 4280 - Closest rwi: 0.563
# Processed row 4281 - Closest rwi: 0.219
# Processed row 4282 - Closest rwi: 0.563
# Processed row 4283 - Closest rwi: 0.563
# Processed row 4284 - Closest rwi: 0.219
# Processed row 4285 - Closest rwi: -0.325
# Processed row 4286 - Closest rwi: -0.325
# Processed row 4287 - Closest rwi: -0.325
# Processed row 4288 - Closest rwi: -0.325
# Processed row 4289 - Closest rwi: -0.325
# Processed row 4290 - Closest rwi: -0.325
# Processed row 4291 - Closest rwi: -0.325
# Processed row 4292 - Closest rwi: -0.325
# Processed row 4293 - Closest rwi: -0.325
# Processed row 4294 - Closest rwi: 0.618
# Processed row 4295 - Closest rwi: 0.618
# Processed row 4296 - Closest rwi: 0.618
# Processed row 4297 - Closest rwi: 0.618
# Processed row 4298 - Closest rwi: 0.618
# Processed row 4299 - Closest rwi: 0.618
# Processed row 4300 - Closest rwi: 0.618
# Processed row 4301 - Closest rwi: 0.618
# Processed row 4302 - Closest rwi: 0.618
# Processed row 4303 - Closest rwi: 0.007
# Processed row 4304 - Closest rwi: 0.007
# Processed row 4305 - Closest rwi: 0.007
# Processed row 4306 - Closest rwi: 0.007
# Processed row 4307 - Closest rwi: 0.007
# Processed row 4308 - Closest rwi: 0.007
# Processed row 4309 - Closest rwi: 0.007
# Processed row 4310 - Closest rwi: 0.007
# Processed row 4311 - Closest rwi: 0.007
# Processed row 4312 - Closest rwi: -0.09
# Processed row 4313 - Closest rwi: -0.09
# Processed row 4314 - Closest rwi: -0.09
# Processed row 4315 - Closest rwi: 0.291
# Processed row 4316 - Closest rwi: 0.291
# Processed row 4317 - Closest rwi: 0.291
# Processed row 4318 - Closest rwi: 0.291
# Processed row 4319 - Closest rwi: 0.291
# Processed row 4320 - Closest rwi: 0.291
# Processed row 4321 - Closest rwi: 0.484
# Processed row 4322 - Closest rwi: 0.484
# Processed row 4323 - Closest rwi: 0.525
# Processed row 4324 - Closest rwi: 0.484
# Processed row 4325 - Closest rwi: 0.484
# Processed row 4326 - Closest rwi: 0.525
# Processed row 4327 - Closest rwi: 0.484
# Processed row 4328 - Closest rwi: 0.484
# Processed row 4329 - Closest rwi: 0.525
# Processed row 4330 - Closest rwi: -0.08
# Processed row 4331 - Closest rwi: -0.105
# Processed row 4332 - Closest rwi: -0.105
# Processed row 4333 - Closest rwi: -0.08
# Processed row 4334 - Closest rwi: -0.105
# Processed row 4335 - Closest rwi: -0.105
# Processed row 4336 - Closest rwi: 0.335
# Processed row 4337 - Closest rwi: 0.047
# Processed row 4338 - Closest rwi: 0.047
# Processed row 4339 - Closest rwi: 0.343
# Processed row 4340 - Closest rwi: 0.271
# Processed row 4341 - Closest rwi: 0.271
# Processed row 4342 - Closest rwi: 0.343
# Processed row 4343 - Closest rwi: 0.271
# Processed row 4344 - Closest rwi: 0.271
# Processed row 4345 - Closest rwi: 0.343
# Processed row 4346 - Closest rwi: 0.271
# Processed row 4347 - Closest rwi: 0.271
# Processed row 4348 - Closest rwi: 1.184
# Processed row 4349 - Closest rwi: 1.184
# Processed row 4350 - Closest rwi: 1.215
# Processed row 4351 - Closest rwi: 1.184
# Processed row 4352 - Closest rwi: 1.184
# Processed row 4353 - Closest rwi: 1.215
# Processed row 4354 - Closest rwi: 1.184
# Processed row 4355 - Closest rwi: 1.184
# Processed row 4356 - Closest rwi: 1.215
# Processed row 4357 - Closest rwi: 0.277
# Processed row 4358 - Closest rwi: 0.277
# Processed row 4359 - Closest rwi: 0.277
# Processed row 4360 - Closest rwi: 0.277
# Processed row 4361 - Closest rwi: 0.277
# Processed row 4362 - Closest rwi: 0.277
# Processed row 4363 - Closest rwi: 0.277
# Processed row 4364 - Closest rwi: 0.277
# Processed row 4365 - Closest rwi: 0.277
# Processed row 4366 - Closest rwi: 0.31
# Processed row 4367 - Closest rwi: 0.417
# Processed row 4368 - Closest rwi: 0.417
# Processed row 4369 - Closest rwi: 0.31
# Processed row 4370 - Closest rwi: 0.417
# Processed row 4371 - Closest rwi: 0.417
# Processed row 4372 - Closest rwi: 0.259
# Processed row 4373 - Closest rwi: 0.372
# Processed row 4374 - Closest rwi: 0.372
# Processed row 4375 - Closest rwi: 0.282
# Processed row 4376 - Closest rwi: 0.378
# Processed row 4377 - Closest rwi: 0.378
# Processed row 4378 - Closest rwi: 0.282
# Processed row 4379 - Closest rwi: 0.378
# Processed row 4380 - Closest rwi: 0.378
# Processed row 4381 - Closest rwi: 0.282
# Processed row 4382 - Closest rwi: 0.378
# Processed row 4383 - Closest rwi: 0.378
# Processed row 4384 - Closest rwi: 0.417
# Processed row 4385 - Closest rwi: 0.684
# Processed row 4386 - Closest rwi: 0.684
# Processed row 4387 - Closest rwi: 0.417
# Processed row 4388 - Closest rwi: 0.684
# Processed row 4389 - Closest rwi: 0.684
# Processed row 4390 - Closest rwi: 0.372
# Processed row 4391 - Closest rwi: 0.415
# Processed row 4392 - Closest rwi: 0.415
# Processed row 4393 - Closest rwi: 0.787
# Processed row 4394 - Closest rwi: 0.787
# Processed row 4395 - Closest rwi: 0.64
# Processed row 4396 - Closest rwi: 0.787
# Processed row 4397 - Closest rwi: 0.787
# Processed row 4398 - Closest rwi: 0.64
# Processed row 4399 - Closest rwi: 0.787
# Processed row 4400 - Closest rwi: 0.787
# Processed row 4401 - Closest rwi: 0.64
# Processed row 4402 - Closest rwi: 0.955
# Processed row 4403 - Closest rwi: 0.955
# Processed row 4404 - Closest rwi: 0.955
# Processed row 4405 - Closest rwi: 0.955
# Processed row 4406 - Closest rwi: 0.955
# Processed row 4407 - Closest rwi: 0.955
# Processed row 4408 - Closest rwi: 0.955
# Processed row 4409 - Closest rwi: 0.955
# Processed row 4410 - Closest rwi: 0.955
# Processed row 4411 - Closest rwi: 0.041
# Processed row 4412 - Closest rwi: 0.824
# Processed row 4413 - Closest rwi: 0.824
# Processed row 4414 - Closest rwi: 0.041
# Processed row 4415 - Closest rwi: 0.824
# Processed row 4416 - Closest rwi: 0.824
# Processed row 4417 - Closest rwi: 0.041
# Processed row 4418 - Closest rwi: 0.824
# Processed row 4419 - Closest rwi: 0.824
# Processed row 4420 - Closest rwi: 0.718
# Processed row 4421 - Closest rwi: 0.718
# Processed row 4422 - Closest rwi: 0.718
# Processed row 4423 - Closest rwi: 0.718
# Processed row 4424 - Closest rwi: 0.718
# Processed row 4425 - Closest rwi: 0.718
# Processed row 4426 - Closest rwi: 0.718
# Processed row 4427 - Closest rwi: 0.718
# Processed row 4428 - Closest rwi: 0.718
# Processed row 4429 - Closest rwi: 0.821
# Processed row 4430 - Closest rwi: 0.821
# Processed row 4431 - Closest rwi: -0.11
# Processed row 4432 - Closest rwi: 0.821
# Processed row 4433 - Closest rwi: 0.821
# Processed row 4434 - Closest rwi: -0.11
# Processed row 4435 - Closest rwi: 0.821
# Processed row 4436 - Closest rwi: 0.821
# Processed row 4437 - Closest rwi: -0.11
# Processed row 4438 - Closest rwi: 0.485
# Processed row 4439 - Closest rwi: 0.485
# Processed row 4440 - Closest rwi: 0.769
# Processed row 4441 - Closest rwi: 0.485
# Processed row 4442 - Closest rwi: 0.485
# Processed row 4443 - Closest rwi: 0.769
# Processed row 4444 - Closest rwi: 0.485
# Processed row 4445 - Closest rwi: 0.485
# Processed row 4446 - Closest rwi: 0.769
# Processed row 4447 - Closest rwi: 0.597
# Processed row 4448 - Closest rwi: 0.597
# Processed row 4449 - Closest rwi: 0.597
# Processed row 4450 - Closest rwi: 0.597
# Processed row 4451 - Closest rwi: 0.597
# Processed row 4452 - Closest rwi: 0.597
# Processed row 4453 - Closest rwi: 0.597
# Processed row 4454 - Closest rwi: 0.597
# Processed row 4455 - Closest rwi: 0.597
# Processed row 4456 - Closest rwi: 0.981
# Processed row 4457 - Closest rwi: 0.35
# Processed row 4458 - Closest rwi: 0.35
# Processed row 4459 - Closest rwi: 0.981
# Processed row 4460 - Closest rwi: 0.35
# Processed row 4461 - Closest rwi: 0.35
# Processed row 4462 - Closest rwi: 0.981
# Processed row 4463 - Closest rwi: 0.35
# Processed row 4464 - Closest rwi: 0.35
# Processed row 4465 - Closest rwi: 0.225
# Processed row 4466 - Closest rwi: 0.225
# Processed row 4467 - Closest rwi: 0.225
# Processed row 4468 - Closest rwi: 0.225
# Processed row 4469 - Closest rwi: 0.225
# Processed row 4470 - Closest rwi: 0.225
# Processed row 4471 - Closest rwi: 0.225
# Processed row 4472 - Closest rwi: 0.225
# Processed row 4473 - Closest rwi: 0.225
# Processed row 4474 - Closest rwi: -0.382
# Processed row 4475 - Closest rwi: -0.382
# Processed row 4476 - Closest rwi: 0.691
# Processed row 4477 - Closest rwi: -0.382
# Processed row 4478 - Closest rwi: -0.382
# Processed row 4479 - Closest rwi: 0.691
# Processed row 4480 - Closest rwi: -0.382
# Processed row 4481 - Closest rwi: -0.382
# Processed row 4482 - Closest rwi: 0.691
# Processed row 4483 - Closest rwi: 0.123
# Processed row 4484 - Closest rwi: 0.271
# Processed row 4485 - Closest rwi: 0.271
# Processed row 4486 - Closest rwi: 0.008
# Processed row 4487 - Closest rwi: -0.315
# Processed row 4488 - Closest rwi: -0.315
# Processed row 4489 - Closest rwi: 0.008
# Processed row 4490 - Closest rwi: -0.315
# Processed row 4491 - Closest rwi: -0.315
# Processed row 4492 - Closest rwi: 0.403
# Processed row 4493 - Closest rwi: 0.403
# Processed row 4494 - Closest rwi: 0.403
# Processed row 4495 - Closest rwi: 0.403
# Processed row 4496 - Closest rwi: 0.403
# Processed row 4497 - Closest rwi: 0.403
# Processed row 4498 - Closest rwi: 0.403
# Processed row 4499 - Closest rwi: 0.403
# Processed row 4500 - Closest rwi: 0.403
# CSV file saved to: /content/csv file with labels.csv
# Number of closest RWIs assigned: 4500
